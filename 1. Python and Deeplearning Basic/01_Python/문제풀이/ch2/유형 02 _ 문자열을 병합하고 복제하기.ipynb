# %% [markdown]
# # 유형 02 : 문자열을 병합하고 복제하기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ### 문제 01
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1, txt2 = '데이터', '분석'
result = txt1 + txt2
result
# Out:
# '데이터분석'

# %% [markdown]
# ###문제 02
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1, txt2, txt3, txt4 = '봄', '여름','가을','겨울'
result = txt1 + txt2 + txt3 + txt4
result
# Out:
# '봄여름가을겨울'

# %% [markdown]
# ###문제 03
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1, txt2, txt3, txt4 = '봄', '여름', '가을', '겨울'
result = txt1 + ',' + txt2 + ',' + txt3 + ',' + txt4
result
# Out:
# '봄,여름,가을,겨울'

# %% [markdown]
# ###문제 04
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1, txt2, txt3 = '2023', '01', '/'
result = txt1 + txt3 +  txt2  + txt3 + txt2
result
# Out:
# '2023/01/01'

# %% [markdown]
# ###문제 05
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '짝'
result = txt*3
result
# Out:
# '짝짝짝'

# %% [markdown]
# ###문제 06
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1, txt2 = '쿵', '짝'
result = txt1*2 + txt2*2
result
# Out:
# '쿵쿵짝짝'

# %% [markdown]
# ###문제 07
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1, txt2 = '쿵', '짝'
result = (txt1 + txt2)*2
result
# Out:
# '쿵짝쿵짝'

# %% [markdown]
# ###문제 08
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '택시아저씨'

t1, t2 = txt[0], txt[1]
result = t1 + t2
result
# Out:
# '택시'

# %% [markdown]
# ###문제 09
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '아이스크림'

result = txt[:2] + txt[3:]
result
# Out:
# '아이크림'

# %% [markdown]
# ###문제 10
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
name = '김철수'

last_name = name[0]
first_name = name[1:]
result = last_name + first_name
result
# Out:
# 김철수

# %% [markdown]
# ###문제 11
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
date = '2024.01.11'

month = date[6]
day = date[-2:]
result = month +'/'+ day
result
# Out:
# 1/11

# %% [markdown]
# ###문제 12
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
filename = 'apple.jpg'
ext = '.png'

result = filename[:5] + ext
result
# Out:
# 'apple.png'

# %% [markdown]
# ###문제 13
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
filepath = '/content/'
filename = 'cat.jpg'

cat = filename[:3]

result = filepath + cat + '/' + cat + '.txt'
result
# Out:
# '/content/cat/cat.txt'

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
filepath = '/content/images/flower/flower.jpg'
ext = '.png'

result = filepath[:-4] + ext
result
# Out:
# '/content/images/flower/flower.png'

# %% [markdown]
# ###문제 15
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
per_info = '박가을 27 여자'

name = per_info[:3]
age = per_info[4:6]
gender = per_info[-2]

print(name,age,gender)
# Out:
# 박가을 27 여

# %% [markdown]
# ###문제 16
# '딥러닝은 AI이다'라는 정답을 슬라이싱을 사용하여 빈칸을 채워보세요.

# %%
txt1 = '머신러닝은 AI이다'
txt2 = '딥러닝은 머신러닝이다'

t1 = (        )
t2 = (        )

result = t2 + ' ' +t1
result
# Out:
# '딥러닝은 AI이다'

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1 = '흰색이라 때 탈까봐 걱정했는데'
txt2 = '디자인이 귀엽고 이뻐서 만족스러워요'

t1 = txt1[:5]
t2 = txt2[-6:]

result = t1 + t2
result
# Out:
# '흰색이라 만족스러워요'

# %% [markdown]
# ###문제 18

# %% [markdown]
# 아래 코드를 읽고 '흰색이라정말정말이뻐요' 라는 값을 나타내기위해 t2,t4 변수를 인덱싱, 슬라이싱을 사용하여 빈칸을 채워보세요.

# %%
txt1 = '흰색이라 때 탈까봐 정말 걱정했는데'
txt2 = '디자인이 귀엽고 이뻐서 만족스러워요'

t1 = txt1[:4]
t2 = txt1[:]
t3 = txt2[9:11]
t4 = txt2[]

result = t1 + t2*2 + t3 + t4
result
# Out:
# '흰색이라정말정말이뻐요'

# %% [markdown]
# ###문제 19
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1 = '관광지와 거리가 가까워서 좋았어요'
txt2 = '직원분들이 불친절하셔서 비추천'

t1 = txt1[-4:]
t2 = txt2 [:6]
t3 = txt2 [7:-3]

result = t2 + t3 + t1
result
# Out:
# '직원분들이 친절하셔서 좋았어요'

# %% [markdown]
# ###문제 20
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt1 = '하루에도 여러번 고데기를 수시로 해서 극극손상모에요ㅠ'
txt2 = '트리트먼트하고 다른 에센스 안발라도 될 정도로 촉촉한 것 같아요'

t1 = txt1[-7:-2]
t2 = txt2[:5]
t3 = txt2[-9:-6]

result = t1 + t3 + t2
result
# Out:
# '극손상모에촉촉한트리트먼트'

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# 주어진 변수들을 활용하여 '한식/일식/중식/양식'가 나오도록 문자열을 병합해보세요.

# %%
txt1, txt2, txt3, txt4 = '한식', '일식','중식','양식'

# %%
# @title 정답
txt1, txt2, txt3, txt4 = '한식', '일식','중식','양식'
result = txt1 + '/' + txt2 + '/' + txt3 + '/' + txt4
result
# Out:
# '한식/일식/중식/양식'

# %% [markdown]
# ###문제 22
# 주어진 변수들을 활용하여 '학교종이땡땡땡'이 나오도록 문자열을 병합, 복제 해보세요.

# %%
txt1 = '학교종이'
txt2 = '땡'

# %%
# @title 정답
txt1 = '학교종이'
txt2 = '땡'

result = txt1 + txt2*3
result
# Out:
# '학교종이땡땡땡'

# %% [markdown]
# ###문제 23
# 주어진 변수들을 활용하여 '뚜벅뚜벅'이 나오도록 코드를 작성해보세요.

# %%
txt1, txt2 = '뚜', '벅'

# %%
# @title 정답
txt1, txt2 = '뚜', '벅'
result = (txt1 + txt2)*2
result

# %% [markdown]
# ###문제 24

# %% [markdown]
# 주어진 문자열에서 적절한 문자들을 인덱싱하고 병합하여 '딸기' 문자열을 만드는 코드를 작성해보세요.

# %%
txt = '딸기스무디'

# %%
# @title 정답
txt = '딸기스무디'
t1, t2 = txt[0], txt[1]

result = t1 + t2
result
# Out:
# '딸기'

# %% [markdown]
# ###문제 25
# 주어진 문자열을 활용하여 'orange01.txt    orange02.txt'가 나오도록 코드를 작성해보세요.

# %%
filename = 'orange.png'
extension = '.txt'
number = '0102'

# %%
# @title 정답
filename = 'orange.png'
extension = '.txt'
number = '0102'

result = filename[:6] + number[:2] + extension + ' ' + filename[:6] + number[2:4] + extension
result
# Out:
# 'orange01.txt orange02.txt'

# %% [markdown]
# ###문제 26
# 주어진 문자열을 활용하여 아래와 같이 출력해보세요.
#
#
#
# ```
# /content/images/strawberry/strawberry_01.jpg /content/images/strawberry/strawberry_02.jpg
# ```

# %%
filepath = '/content/images/'
category = 'strawberry'
extension = '.jpg'

# %%
# @title 정답
filepath = '/content/images/'
category = 'strawberry'
extension = '.jpg'

result = filepath + category + '/' + category + '_01' + extension +' ' + filepath + category + '/' + category + '_02' + extension
result
# Out:
# '/content/images/strawberry/strawberry_01.jpg /content/images/strawberry/strawberry_02.jpg'

# %% [markdown]
# ###문제 27
# 주어진 문자열을 활용하여 '카페라떼'가 출력되도록 코드를 작성해보세요.

# %%
txt1 = '그린티라떼'
txt2 = '카페모카'

# %%
# @title 정답
txt1 = '그린티라떼'
txt2 = '카페모카'

t1 = txt1[3:]
t2 = txt2[0:2]
result = t2 + t1
result
# Out:
# '카페라떼'

# %% [markdown]
# ###문제 28
# 주어진 문자열을 활용하여 'K.O.R.E.A KOREA 화이팅'을 출력해보세요.
# - 슬라이싱 활용
# - +" "를 통해 띄어쓰기를 표현해주세요.

# %%
txt1 = 'K.O.R.E.A'
txt2 = '화이팅'

# %%
# @title 정답
txt1 = 'K.O.R.E.A'
txt2 = '화이팅'

result = txt1+" "+txt1[::2]+" "+txt2
result
# Out:
# 'K.O.R.E.A KOREA 화이팅'

# %% [markdown]
# ###문제 29
# 주어진 문자열을 활용하여 '스토리아쉬운전개빠름'이 출력되도록 해보세요.

# %%
text = '스토리가 좀 아쉬운 느낌.. 대충 만든 느낌이라.. 전개가 되게 빠름ㅋㅋ'

# %%
# @title 정답
text = '스토리가 좀 아쉬운 느낌.. 대충 만든 느낌이라.. 전개가 되게 빠름ㅋㅋ'

subject1 = text[:3]
verb1 = text[7:10]
subject2 = text[-11:-9]
verb2 = text[-4:-2]

neutral = subject1 + verb1 + subject2 + verb2
print(neutral)

# %% [markdown]
# ###문제 30
# 주어진 문자열을 활용하여 아래와 같이 출력해보세요.
#
#
#
# ```
# 강남구는 20평당 10억 입니다
# ```

# %%
info = '강남구 20 1000000000'

# %%
# @title 정답
info = '강남구 20 1000000000'

district = info[:3]
area = info[4:6]
price = info[7:9]

print(district+'는', area+'평당',price+'억 입니다')
