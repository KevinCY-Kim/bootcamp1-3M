# %% [markdown]
# # 유형 03 : 문자열 메서드 활용하여 문자열 핸들링하기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '정치 경제 사회'

result = len(txt)

# %% [markdown]
# ###문제 02
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '정치.경제.사회'

result = txt.split(".")

# %% [markdown]
# ###문제 03
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '정치 경제 사회'
splitted_txt = txt.split()

result = ''.join(splitted_txt)
# Out:
# '정치경제사회문화IT/과학세계'

# %% [markdown]
# ###문제 04
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '정치 경제 사회'
splitted_txt = txt.split()

result = ','.join(splitted_txt)
# Out:
# '정치,경제,사회,문화,IT/과학,세계'

# %% [markdown]
# ###문제 05
#  아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "   AI is whatever hasn't been done yet   "

result = txt.rstrip()
# Out:
# "   AI is whatever hasn't been done yet"

# %% [markdown]
# ###문제 06
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "   AI is whatever hasn't been done yet   "

result = txt.lstrip()
# Out:
# "AI is whatever hasn't been done yet   "

# %% [markdown]
# ###문제 07
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "   AI is whatever hasn't been done yet   "

result = txt.strip()
# Out:
# "AI is whatever hasn't been done yet"

# %% [markdown]
# ###문제 08
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "   AI is whatever hasn't been done yet   "

result = txt.split()
# Out:
# ['AI', 'is', 'whatever', "hasn't", 'been', 'done', 'yet']

# %% [markdown]
# ###문제 09
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "   AI is whatever hasn't been done yet   "
splitted_txt = txt.split()

result = "".join(splitted_txt)
# Out:
# "AIiswhateverhasn'tbeendoneyet"

# %% [markdown]
# ###문제 10
# 다음은 07번 ~ 09번 문제를 보고 strip()과 split()의 기능을 설명한 것이다. 빈칸을 완성하세요.

# %%
#1. strip : 문자열 (앞뒤)에 있는 (공백)제거 => 문자열 (내부)의 (공백)은 제거할 수 없다.
#2. split : (파라미터)를 기준으로 문자열을 나눠줌 => 문자열 (내부)의 (공백)을 제거할 수 있다.

# %% [markdown]
# ###문제 11
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '  아 이 스 아 메 리 카 노  '

result = txt.strip().replace(' ','')
# Out:
# '아이스아메리카노'

# %% [markdown]
# ###문제 12
# 위의 result값과 동일하게 아래 코드를 읽고 빈칸을 완성하세요.

# %%
# split와 join을 사용하여 위와 동일한 코드로 변경
txt = '  아 이 스 아 메 리 카 노  '
splitted_txt = txt.  # strip().split()

result =             # "".join(splitted_txt)
# Out:
# '아이스아메리카노'

# %% [markdown]
# ###문제 13
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
text = 'The movie is amazing'

result = text[:9].replace('movie', 'song') + text[9:].replace('amazing', 'fantastic')
# Out:
# 'The song is fantastic'

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
string = "Happy New Year"

result = string.upper()
# Out:
# 'HAPPY NEW YEAR'

# %% [markdown]
# ###문제 15
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
string = "Happy New Year"

result = string.upper().islower()
# Out:
# False

# %% [markdown]
# ###문제 16
# 문자열 내부의 0을 제거 후 알파벳으로만 이루어져있는지 확인할 수 있도록 빈칸을 완성해주세요.

# %%
txt = '0S0l0i0c0i0n0g0s0t0e0p'
splitted_txt = txt.  # split("0")

result = "".join(splitted_txt). # isalpha()
# Out:
# True

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "It's almost 2am"

result = txt.isalnum()
# Out:
# False

# %% [markdown]
# ###문제 18
# isalnum()을 사용하여 위의 코드와 반대되는 결과값을 얻고자 한다. 빈칸을 완성해보세요.

# %%
txt = "It's almost 2am"
replaced_txt = txt.replace( , ).replace( , )  # txt.replace(" ",'').replace("'",'')

result = replaced_txt.isalnum()
# Out:
# Itsalmost2am
# True

# %% [markdown]
# ###문제 19
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "Simple is the best"
splitted_txt = txt.split()

t1 = splitted_txt[0].upper()
t2 = splitted_txt[1]
t3 = splitted_txt[2]
t4 = splitted_txt[3].upper()

new_txt = t1+' ' +t2+' '+t3+ ' '+t4

result = ''.join(new_txt)
# Out:
# SIMPLE is the BEST
# 'SIMPLE is the BEST'

# %% [markdown]
# ###문제 20
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = "Simple is the best"

t1 = txt[:6].upper()
t2 = txt[6:14]
t3 = txt[-4:].upper()

result = (t1 + t2 + t3).isalpha()
# Out:
# SIMPLE is the BEST

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# 주어진 문자열의 길이를 출력해보세요.

# %%
txt = '소설 시/에세이 인문 경제/경영 사회/정치 역사 자연/과학'

# %%
# @title 정답
txt = '소설 시/에세이 인문 경제/경영 사회/정치 역사 자연/과학'

result = len(txt)
# Out:
# 32

# %% [markdown]
# ###문제 22

# %% [markdown]
# 주어진 이메일 주소에서 첫번째 이메일주소 아이디만 출력해주세요

# %%
txt = 'asdf@naver.com / sdlkf@gmai.com / alksdpdk@naver.com'
# Out:
# 'asdf'

# %%
# @title 정답
txt = 'asdf@naver.com / sdlkf@gmai.com / alksdpdk@naver.com'

txt=txt.split('/')[0]
txt=txt.split('@')[0]
print(txt)
# Out:
# asdf

# %% [markdown]
# ###문제 23
# 주어진 문자열에서 공백 대신에 ','로 변경해보세요.

# %%
txt = '소설 시/에세이 인문 경제/경영 사회/정치 역사 자연/과학'

# %%
# @title 정답
txt = '소설 시/에세이 인문 경제/경영 사회/정치 역사 자연/과학'
splitted_txt = txt.split()

result = ','.join(splitted_txt)
# Out:
# '소설,시/에세이,인문,경제/경영,사회/정치,역사,자연/과학'

# %% [markdown]
# ###문제 24
# 주어진 문자열에서 앞뒤의 공백을 제거해보세요.

# %%
txt = '  Believe in yourself and you can do it    '

# %%
# @title 정답
txt = '  Believe in yourself and you can do it    '

result = txt.strip()
# Out:
# 'Believe in yourself and you can do it'

# %% [markdown]
# ###문제 25
# 주어진 문자열에서 위와 같은 결과 값이 나오도록 split()과 join()을 사용하여 코드를 작성해보세요.

# %%
txt = '  Believe in yourself and you can do it    '

# %%
# @title 정답
txt = '  Believe in yourself and you can do it    '
splitted_txt = txt.split()

result = " ".join(splitted_txt)
# Out:
# 'Believe in yourself and you can do it'

# %% [markdown]
# ###문제 26
# 주어진 문자열에서 공백을 모두 없애보세요.

# %%
txt = '  아 이 스 카 라 멜 마 끼 야 또  '

# %%
# @title 정답
txt = '  아 이 스 카 라 멜 마 끼 야 또  '

result = txt.strip().replace(' ','')
# Out:
# '아이스카라멜마끼야또'

# %% [markdown]
# ###문제 27
# 주어진 문자열에서 'No sweet, No sweet' 이 나오도록 코드를 작성해보세요.

# %%
text = 'No pain,No gain'

# %%
# @title 정답
text = 'No pain,No gain'

result = text.replace('pain', 'sweat').replace('gain', 'sweet')
# Out:
# 'No sweat,No sweet'

# %% [markdown]
# ###문제 28
# 주어진 문자열에서 '0'을 제거해보세요.

# %%
txt = '0S0l0i0c0i0n0g0s0t0e0p'

# %%
# @title 정답
txt = '0S0l0i0c0i0n0g0s0t0e0p'
splitted_txt = txt.split("0")

result = "".join(splitted_txt)
# Out:
# 'Slicingstep'

# %% [markdown]
# ###문제 29
# 주어진 문자열에서 isalnum()을 사용했을 때, result값이 True가 나오도록 코드를 작성하세요.

# %%
txt = "It's almost 2am"

# %%
# @title 정답
txt = "It's almost 2am"
replaced_txt = txt.replace(" ",'').replace("'",'')

result = replaced_txt.isalnum()
# Out:
# True

# %% [markdown]
# ###문제 30
# 주어진 문자열에서 simple과 best를 대문자로 강조하고 문자열이 알파벳으로만 이루어져 있는지 확인하는 코드를 작성해보세요.

# %%
txt = "Simple is the best"

# %%
# @title 정답
txt = "Simple is the best"

t1 = txt[:6].upper()
t2 = txt[6:14]
t3 = txt[-4:].upper()

result = (t1 + t2 + t3).isalpha()
# Out:
# False
