# %% [markdown]
# # 유형 01 : 문자열 원하는 일부만 지정하기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ### 문제 01
# 아래 코드를 읽고 dong의 값이 무엇일지 맞춰보세요.

# %%
code = 'A_001A'

dong = code[0]
dong
# Out:
# 'A'

# %% [markdown]
# ### 문제 02
# 아래 코드를 읽고 ho의 값이 무엇일지 맞춰보세요.

# %%
code = 'A_002B'

ho = code[4]
ho
# Out:
# '2'

# %% [markdown]
# ### 문제 03
# 아래 코드를 읽고 r_type의 값이 무엇일지 맞춰보세요.

# %%
code = "A_003C"

r_type = code[-1]
r_type
# Out:
# 'C'

# %% [markdown]
# ### 문제 04
# 아래 코드를 읽고 ho의 값이 무엇일지 맞춰보세요.

# %%
code = 'A_004D'

ho = int(code[-2])
ho
# Out:
# 4

# %% [markdown]
# ### 문제 05
# 아래 코드를 읽고 last1, last2, last3이 무엇일지 맞춰보세요.

# %%
name1 = '김철수'
name2 = '김미영'
name3 = '이영수'

last1, last2, last3 = name1[0], name2[0], name3[0]
print('고객1 last name :', last1)
print('고객2 last name :', last2)
print('고객3 last name :', last3)
# Out:
# 고객1 last name : 김
# 고객2 last name : 김
# 고객3 last name : 이

# %% [markdown]
# ### 문제 06
# 아래 코드를 읽고 id가 무엇일지 맞춰보세요.

# %%
email = 'dino@dinonet.com'

id = email[0:4]
id
# Out:
# 'dino'

# %% [markdown]
# ### 문제 07
# 아래 코드를 읽고 cat1, cat2가 무엇일지 맞춰보세요.

# %%
product = '상의-티셔츠'

cat1, cat2 = product[0:2], product[:2]
cat1, cat2
# Out:
# ('상의', '상의')

# %% [markdown]
# ### 문제 08
# 아래 코드를 읽고 item1, item2가 무엇일지 맞춰보세요.

# %%
product1 = '상의-티셔츠'
product2 = '하의-바지'

item1 = product1[3:]
item2 = product2[3:]
item1, item2
# Out:
# ('티셔츠', '바지')

# %% [markdown]
# ### 문제 09
# 아래 코드를 읽고 item1, item2, item3이 무엇일지 맞춰보세요.

# %%
product1 = '상의-티셔츠'
product2 = '하의-청바지'
product3 = '악세사리-목걸이'

item1 = product1[-3:]
item2 = product2[-3:]
item3 = product3[-3:]
item1, item2, item3
# Out:
# ('티셔츠', '청바지', '목걸이')

# %% [markdown]
# ### 문제 10
# 아래 코드를 읽고 ext가 무엇일지 맞춰보세요.

# %%
filename = 'airplane.jpg'

ext = filename[-3:]
ext
# Out:
# 'jpg'

# %% [markdown]
# ### 문제 11
# 아래 코드를 읽고 name이 무엇일지 맞춰보세요.

# %%
filename = 'dog_02.doc'

name = filename[:3]
name
# Out:
# 'dog'

# %% [markdown]
# ### 문제 12
# 아래 코드를 읽고 age가 무엇일지 맞춰보세요.

# %%
personal_info = '박가을 27 여자'

age = int(personal_info[4:-3])
age
# Out:
# 27

# %% [markdown]
# ### 문제 13
# 아래 코드를 읽고 year, month, date가 무엇일지 맞춰보세요.

# %%
ymd = '2024.01.11'

year, month, date = int(ymd[:4]), int(ymd[5:-3]), int(ymd[-2:])
print('연도 :', year)
print('월 :', month)
print('일 :', date)
# Out:
# 연도 : 2024
# 월 : 1
# 일 : 11

# %% [markdown]
# ### 문제 14
# 아래 코드를 읽고 key가 무엇일지 맞춰보세요.

# %%
review = "이 영화는 스릴러인데 스릴러영화 중에서도 명작이라고 생각해요"

key = review[6:9]
key
# Out:
# '스릴러'

# %% [markdown]
# ### 문제 15
# 아래 코드를 읽고  key가 무엇일지 맞춰보세요.

# %%
text = '스토리가 좀 아쉬운 느낌.. 대충 만든 느낌이라.. 전개가 되게 빠름ㅋㅋ'

key = text[-11:-9]
key
# Out:
# '전개'

# %% [markdown]
# ### 문제 16
# 아래 코드를 읽고 key1, key2가 무엇일지 맞춰보세요.

# %%
review = "품질이 너무 별로에요. 구매한 걸 후회해요"

key1, key2 = review[7:9], review[-4:-2]
print(key1)
print(key2)
# Out:
# 별로
# 후회

# %% [markdown]
# ### 문제 17
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
txt = '0S0l0i0c0i0n0g'

result = txt[1::2]
result
# Out:
# 'Slicing'

# %% [markdown]
# ### 문제 18
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
cipher = "_@p_@y_!t_dhs_ob_n"

result = cipher[2::3]
result

# %% [markdown]
# ### 문제 19
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
string ='##1###3###5##'

result = string[2::4]
result
# Out:
# '135'

# %% [markdown]
# ### 문제 20
# 아래 코드를 읽고 result가 무엇일지 맞춰보세요.

# %%
string = "토마토기러기우영우"

result = string[::-1]
result
# Out:
# '우영우기러기토마토'

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ### 문제 21
# 주어진 문자열에서 첫 알파벳을 출력해보세요.

# %%
s = "10 Z 20 Z 1"

# %%
# @title 정답
s = "10 Z 20 Z 1"

first_alpha = s[3]
print(first_alpha)
# Out:
# Z

# %% [markdown]
# ### 문제 22
# 주어진 문자열에서 공백을 출력해보세요.

# %%
s = "10Z20Z 1"

# %%
# @title 정답
s = "10Z20Z 1"

empty = s[-2]
print(empty)

# %% [markdown]
# ### 문제 23
# 주어진 문자열에서 아래와 같이 출력해보세요.
#
#
# ```
# Nike ZoomX
# ```

# %%
item = 'Nike - ZoomX Vaporfly NEXT%'

# %%
# @title 정답
item = 'Nike - ZoomX Vaporfly NEXT%'

brand = item[:4]
product = item[7:12]

print(brand, product)

# %% [markdown]
# ### 문제 24
# 주어진 문자열을 반대로 뒤집은 상태에서 'Love'를 출력해보세요.

# %%
title = 'I Will Always Love You'

# %%
# @title 정답
title = 'I Will Always Love You'

title_reversed = title[::-1]
love = title_reversed[4:8][::-1]
print(love)
# Out:
# Love

# %% [markdown]
# ### 문제 25

# %% [markdown]
#  주어진 문자열에서 '주인공!'을 출력해보세요.

# %%
text = '#광복절은#독립의날#8/15#대한민국#주인공!'

# %%
# @title 정답
text = '#광복절은#독립의날#8/15#대한민국#주인공!'

target_text = text[-4:]
print(target_text)
# Out:
# 주인공!

# %% [markdown]
# ### 문제 26
# 주어진 문자열에서 'comic'을 출력해보세요.

# %%
genre = 'action comic historical sensibility'

# %%
# @title 정답
genre = 'action comic historical sensibility'

comic = genre[7:13]
print(comic)

# %% [markdown]
# ### 문제 27

# %% [markdown]
#  주어진 문자열에서 카테고리를 출력해보세요.
# 1. pwd를 통해 현재 코랩 파일의 경로를 확인해보세요 -> '/content' (현재 내 코렙 파일의 경로는 /content 입니다)
# 2. 만약 내가 /content에서 images폴더를 만들게 되면, images 폴더(=카테고리)의 경로는 '/content/images'가 됩니다.
# 3. images 폴더안에 cat_02.png 파일이 있다면, 이 파일의 경로는 '/content/images/cat_02.png'입니다. 즉 코랩 파일이 있는 content에서 imgages 폴더 안에 cat_02.png가 있다는 것을 의미합니다.

# %%
pwd
# Out:
# '/content'

# %%
filepath = '/content/images/cat_02.png'

# %%
# @title 정답
filepath = '/content/images/cat_02.png'

category = filepath[-10:-7]
print(category)

# %% [markdown]
# ### 문제 28
# 주어진 문자열에서 '훌륭'을 출력해보세요.

# %%
review = "가격 대비 맛이 훌륭해요. 다시 방문하겠습니다."

# %%
# @title 정답
review = "가격 대비 맛이 훌륭해요. 다시 방문하겠습니다."

positive_word = review[9:11]
print(positive_word)

# %% [markdown]
# ### 문제 29
# 주어진 문자열에서 'K팝'을 출력해보세요.

# %%
text = "전세계 친구들 만나 K팝·김치 등 한국에 대해 알려줄래요"

# %%
# @title 정답
text = "전세계 친구들 만나 K팝·김치 등 한국에 대해 알려줄래요"

word = text[11:13]
print(word)

# %% [markdown]
# ### 문제 29
# 주어진 이미지 파일에서 이미지 파일 명만 출력해보세요.

# %%
image_path ='cat_02.png'

# %%
# @title 정답
image_path ='cat_02.png'

name=image_path[:-4]
print(name)
# Out:
# cat_02

# %% [markdown]
# ### 문제 30
# 주어진 문자에서 특정 부분을 추출하여 아래와 같이 출력해보세요.
#
#
#
# ```
# 10억 입니다
# ```

# %%
info = '강남구 20 1000000000'

# %%
# @title 정답
info = '강남구 20 1000000000'

price = info[7:9]
print(price+'억 입니다')
