# %% [markdown]
# # 유형 05 : 내장함수를 사용한 숫자 연산하기

# %% [markdown]
# ## 읽기 영역

# %%
# abs(-5) : 절대값
# round(5.114, 2) : 두번째 자리에서 반올림
# divmod(5, 3) : 첫번째 인자(5)를 두번째 인자(3)로 나눈 몫과 나머지를 tuple 형식으로 반환
# pow(5, 3) : 제곱 -> 5**3
# min(1, 2, 3) : 최소값
# max(1, 2, 3) : 최대값

# %% [markdown]
# ### 문제 01

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = -5, -10

result = abs(a) + abs(b)

# %% [markdown]
# ### 문제 02

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = 3.14, 2.717

result = round(a, 1) + round(b, 2)

# %% [markdown]
# ### 문제 03

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = 5, 3

result = divmod(a, b)

# %% [markdown]
# ### 문제 04

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a,b = 3,6

result = divmod(a+b,b-a)

# %% [markdown]
# ### 문제 05

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = 2, 3

result = pow(2,3)

# %% [markdown]
# ### 문제 06

# %% [markdown]
# 위의 코드를 읽고 제곱형식을 사용하여 result변수 값을 수정해보세요.

# %%
a, b = 2, 3
result = ??
# Out:
#   File "<ipython-input-5-5f054f470579>", line 2
#     result = ??
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 문제 07

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b, c = 1, 2, 3

result = min(1,2,3)

# %% [markdown]
# ### 문제 08

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b, c = 1, 2, 3

result = max(1,2,3)

# %% [markdown]
# ### 문제 09

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = -5, -2.717
a = abs(a)
b = abs(round(b, 1))

result = a + b

# %% [markdown]
# ### 문제 10

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = -10, -15

a = abs(a - b)
b = pow(a, 3)

result = b - a

# %% [markdown]
# ### 문제 11

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b, c = -6, -5, -1
a ,b, c = abs(a), abs(b), abs(c)

result = min(a,b,c) + max(a,b,c)

# %% [markdown]
# ### 문제 12

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = 2, 3.45
b = round(b,1)

result = divmod(b,a)

# %% [markdown]
# ### 문제 13

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = 2, 3.45
b = round(b,1)

result = pow(b,a)

# %% [markdown]
# ### 문제 14

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a,b,c,d = 2.45 , 4.253, 7.34 , 3.14
a,b,c,d = round(a), round(b), round(c), round(d)

result = min(a,b,c,d) * max(a,b,c,d)

# %% [markdown]
# ### 문제 15

# %% [markdown]
# 다음은 내장함수 round()에 대한 설명이다. 빈칸을 채우며 round함수의 기능을 숙지해보세요.

# %%
내장함수 round(number, ndigits = None)으로 최대 2개의 인수를 가지는데 두번째 인수는 생략이 (   )하며 default값이 (    ) 으로 설정되어있다.

# %% [markdown]
# ### 문제 16

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a, b = -5, 3.5
a, b = pow(abs(a),2), round(b)

result = divmod(a,b)

# %% [markdown]
# ### 문제 17

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a,b = 3,4
c = divmod(a,b)

result = min(c)

# %% [markdown]
# ### 문제 18

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a,b = -5, 5
a = abs(a)

result = max(divmod(a,b))

# %% [markdown]
# ### 문제 19

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a,b,c,d = 2,4,3,5

num1 = pow(a,b)
num2 = pow(c,d)
num3 = max(a,b,c,d) * 10

result = min(num1,num2,num3)

# %% [markdown]
# ### 문제 20

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a,b,c,d,e = 3, -5, -2.45, 7, 6
b,c = abs(b), abs(round(c))

num1 = max(a,b,c,d,e)
num2 = min(a,b,c,d,e)

result = divmod(num1,num2)

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ### 문제 21

# %% [markdown]
# a,b = -5, 3.157일 때, a의 절댓값에 b의 소숫점 첫번째 자리까지를 더하여 result값을 할당하세요.

# %%
a, b = -5, 3.157

# %%
#@title 정답
a, b = -5, 3.157

result = abs(a) + round(b,1)

# %% [markdown]
# ### 문제 22

# %% [markdown]
#  a,b = 3.14, 2.55일 때, a,b 모두 소숫점 첫번째까지 반올림 하고, 두 값을 곱하여 result값에 할당하세요.

# %%
a, b = 3.14, 2.55

# %%
#@title 정답
a, b = 3.14, 2.55

result = round(a,1) * round(b,1)

# %% [markdown]
# ### 문제 23

# %% [markdown]
#  a,b = 3,6일 때, a와 b를 더한 값에 b와 a를 뺀 값을 나누어 몫과 나머지를 한번에 구하세요.

# %%
a,b = 3,6

# %%
#@title 정답
a,b = 3,6

result = divmod(a+b,b-a)

# %% [markdown]
# ### 문제 24

# %% [markdown]
# a,b = -10,5일 때, a는 a-b의 절댓값이고, b는 b의 2제곱이다.
# result 값이 b에서 a를 뺀 값과 같음으로 이를 코드로 작성해보세요.

# %%
a, b = -10, 5

# %%
#@title 정답
a, b = -10, 5

a = abs(a - b)
b = pow(b, 2)

result = b - a

# %% [markdown]
# ### 문제 25

# %% [markdown]
# a,b,c = -6,-5,-1일 때, 각각의 절댓값을 구하고 절댓값들의 최소값과 최대값을 더하여 result값을 구하세요.

# %%
a, b, c = -6, -5, -1

# %%
#@title 정답
a, b, c = -6, -5, -1
a ,b, c = abs(a), abs(b), abs(c)

result = min(a,b,c) + max(a,b,c)

# %% [markdown]
# ### 문제 26

# %% [markdown]
# a,b = 2,3.45일 때, 두 변수의 값을 정수로 만들고 b의 a제곱을 result 변수에 할당하세요.

# %%
a, b = 2, 3.45

# %%
#@title 정답
a, b = 2, 3.45
b = round(b)

result = pow(b,a)

# %% [markdown]
# ### 문제 27

# %% [markdown]
# a,b = -5, 3.5 일 때, a는 a의 절댓값에 제곱, b는 한 자리의 정수이다. a에 b를 나눠 한번에 몫과 나머지를 구하고 이를 result 변수에 할당하세요.

# %%
a, b = -5, 3.5

# %%
#@title 정답
a, b = -5, 3.5
a, b = pow(abs(a),2), round(b)

result = divmod(a,b)

# %% [markdown]
# ### 문제 28

# %% [markdown]
# a,b = 3,4일 때, c는 a에서 b를 나눈 몫과 나머지이다. c의 최솟값을 구해보세요.

# %%
a,b = 3,4

# %%
#@title 정답
a,b = 3,4
c = divmod(a,b)

result = min(c)

# %% [markdown]
# ### 문제 29

# %% [markdown]
#  a,b,c,d = 2,3,4,5일 때,
# 1. num1은 a의 b제곱
# 2. num2는 c의 d제곱
# 3. num3는 a,b,c,d 의 최댓값 * 10
#
# result의 값은 num1,num2,num3의 최솟값이다. 최솟값을 구해보세요.

# %%
a,b,c,d = 2,4,3,5

# %%
#@title 정답
a,b,c,d = 2,4,3,5

num1 = pow(a,b)
num2 = pow(c,d)
num3 = max(a,b,c,d) * 10

result = min(num1,num2,num3)

# %% [markdown]
# ### 문제 30

# %% [markdown]
# a,b,c = -4, 3.24, 0.5 일 때,
# a,b,c 모두 양수이자 정수이다. 이때 num1은 a,b,c의 최솟값, num2는 a,b,c의 최댓값으로 최솟값에 최댓값을 나눈 몫과 나머지를 구해보세요.

# %%
a,b,c = -4, 3.24 , 0.5

# %%
#@title 정답
a,b,c = -4, 3.24 , 0.5
a,b,c = abs(a), round(b), c*10

num1 = min(a,b,c)
num2 = max(a,b,c)

result = divmod(num1,num2)
