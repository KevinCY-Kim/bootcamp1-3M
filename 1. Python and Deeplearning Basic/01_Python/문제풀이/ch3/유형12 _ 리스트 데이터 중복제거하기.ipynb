# %% [markdown]
# # 유형 12 : 리스트 데이터 중복제거하기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = ['1','1','3','2','4','3','5']
dataset = list(dataset)

print(dataset)

# %% [markdown]
# ###문제 02
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = ['1','1','3','2','4','3','5']
dataset = set(dataset)
print(dataset)
# Out:
# {'5', '1', '2', '4', '3'}

# %% [markdown]
# ###문제 03
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = ['1','1','3','2','4','3','5']

dataset = list(set(dataset))
print(dataset)

# %% [markdown]
# ###문제 04
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = ['1','1','3','2','4','3','5']

dataset.insert(5, '6')
dataset = list(set(dataset))
dataset = sorted(dataset)
print(dataset)

# %% [markdown]
# ###문제 05
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
genres = ['comics','comics','sports','sports','sports']
genres = list(set(genres))
genres

# %% [markdown]
# ###문제 06
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
genres = ['comics', 'comics', 'sports', 'sports', 'sports']

genres = list(set(genres))
genres.append('action')

print(genres)

# %% [markdown]
# ###문제 07
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
genres = ['comics', 'comics', 'sports', 'sports', 'sports']

genres.insert(2,'action')
genres = list(set(genres))

print(genres)
# Out:
# ['sports', 'action', 'comics']

# %% [markdown]
# ###문제 08
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
genres = ['comics','comics', 'action', 'sports','sports','sports']
genres = list(dict.fromkeys(genres))
genres # 순서 보존하면서 중복 제거 : 딕셔너리로 변환 -> 리스트 변환
# Out:
# ['comics', 'action', 'sports']

# %% [markdown]
# ###문제 09
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
genres = ['comics','comics','sports','sports','sports']

genres.append('action')
genres = list(dict.fromkeys(genres))
genres

# %% [markdown]
# ###문제 10
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
genres = ['comics','comics','sports','sports','sports']

genres.insert(2, 'action')
genres = list(dict.fromkeys(genres))
genres

# %% [markdown]
# ###문제 11
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
genres = ['adventure', 'adventure', 'fantasy', 'fantasy', 'sci-fi']
genres = list(dict.fromkeys(genres))
genres.extend(['comedy', 'drama', 'mystery', 'horror'])

sorted_genres = sorted(genres)
print(sorted_genres)

# %% [markdown]
# ###문제 12
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
company = ['네이버', '다음카카오', '삼성', 'LG', '네이버', '삼성', 'SK', 'SK', 'LG', '네이버', '롯데']
company = list(set(company))
company.append('현대')
company.index('현대')

# %% [markdown]
# ###문제 13
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
company = ['네이버', '다음카카오', '삼성', 'LG', '네이버', '현대','삼성', 'SK', 'SK', 'LG', '네이버', '롯데']
company.insert(3, '현대')
company = list(dict.fromkeys(company))
print(company)
company.index('현대')
# Out:
# ['네이버', '다음카카오', '삼성', '현대', 'LG', 'SK', '롯데']
# 3

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
company = ['네이버', '다음카카오','한화' '삼성', 'LG', '네이버','현대', '삼성', 'SK', 'SK', 'LG', '네이버', '롯데']
company.extend(['한화','현대','KT'])
company = list(dict.fromkeys(company))
print(company)
company.index('현대')

# %% [markdown]
# ###문제 15
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
filename = ['airplane_01.jpg','airplane_02.jpg','airplane_01.jpg','airplane_02.jpg','airplance_03.jpg']

filename = filename[:3]
filename = list(set(filename))
filename

# %% [markdown]
# ###문제 16

# %% [markdown]
# 아래 코드를 읽고 filename에서 airplane_01 이미지가 몇개 있을지 맞춰보세요

# %%
filename = ['airplane_01.jpg','airplane_02.jpg','airplane_01.jpg','airplane_02.jpg','airplance_03.jpg']

filename.extend(['airplane_01.jpg','airplane_01.jpg','airplane_01.jpg','airplane_05.jpg','airplance_04.jpg'])
filename = list(set(filename))
filename
# Out:
# ['airplane_05.jpg',
#  'airplance_04.jpg',
#  'airplane_02.jpg',
#  'airplance_03.jpg',
#  'airplane_01.jpg']

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
filename = ['airplane_01.jpg','airplane_02.jpg','airplane_01.jpg','airplane_02.jpg','airplance_03.jpg']

filename = filename[:3]
filename = list(dict.fromkeys(filename))
filename

# %% [markdown]
# ###문제 18

# %% [markdown]
# 아래 코드를 읽고 출력값이 총 몇개가 될 것인지 맞춰보세요.

# %%
filename = ['airplane_01.jpg','airplane_02.jpg','airplane_01.jpg','airplane_02.jpg','airplance_03.jpg']

filename[0]=filename[0].replace('jpg','png')
filename[-1]=filename[-1].replace('jpg','png')

print(filename)
filename = list(dict.fromkeys(filename))
filename
# Out:
# ['airplane_01.png', 'airplane_02.jpg', 'airplane_01.jpg', 'airplane_02.jpg', 'airplance_03.png']
# ['airplane_01.png', 'airplane_02.jpg', 'airplane_01.jpg', 'airplance_03.png']

# %% [markdown]
# ###문제 19
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
filename = ['airplane_01.jpg','airplane_02.jpg','airplane_01.jpg','airplane_02.jpg','airplance_03.jpg']

filename.insert(2, 'airplane_03.jpg')
filename = list(set(filename))
print('/content/airplane/'+filename[0],'/content/airplane/'+filename[1])
# Out:
# /content/airplane/airplane_03.jpg /content/airplane/airplane_02.jpg /content/airplane/airplane_01.jpg

# %% [markdown]
# ###문제20
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
filename = ['airplane_01.jpg','airplane_02.jpg','airplane_01.jpg','airplane_02.jpg','airplance_03.jpg']

filename.insert(1, 'airplane_03.jpg')
filename = list(dict.fromkeys(filename))
print('/content/airplane/'+filename[0],'/content/airplane/'+filename[1])
# Out:
# /content/airplane/airplane_01.jpg /content/airplane/airplane_03.jpg

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# 주어진 리스트를 활용하여 아래와 같이 작업을 수행했을 때 최종결과를 출력하는 코드를 작성해보세요.
#
# 1. 리스트에 중복된 값을 제거하세요. (단 set을 사용해주세요.)
# 2. 새로운 값 6을 리스트에 추가하세요.
# 3. 리스트를 오름차순으로 정렬하세요.
#
#
#
# ```
# [2, 4, 5, 6, 8, 10, 15]
# ```

# %%
dataset = [10,5,4,5,2,8,2,15]

# %%
#@title 정답
dataset = [10,5,4,5,2,8,2,15]

dataset = list(set(dataset))
dataset.append(6)
dataset = sorted(dataset)
print(dataset)

# %% [markdown]
# ###문제 22
# 주어진 리스트를 활용하여 아래와 같이 작업을 수행해보세요.
#
# 1. 리스트에서 중복된 과일을 제거하세요.
# 2. 새로운 과일 'grape'를 리스트에 추가하세요.
#
#
#
# ```
# ['apple', 'orange', 'grape']
# ```

# %%
fruits = ['orange', 'apple', 'orange', 'apple', 'orange']

# %%
#@title 정답
fruits = ['orange', 'apple', 'orange', 'apple', 'orange']

fruits = list(set(fruits))
fruits.append('grape')

print(fruits)

# %% [markdown]
# ###문제 23
# 주어진 리스트를 활용하여 아래와 같이 작업을 수행해보세요.
#
# 1. 'grape'라는 과일을 리스트의 두 번째 위치에 추가하세요.
# 2. 리스트에서 중복된 과일을 제거하세요.
#
#
#
# ```
# ['apple', 'grape', 'orange']
# ```

# %%
fruits = ['orange', 'apple', 'orange', 'apple', 'orange']

# %%
#@title 정답
fruits = ['orange', 'apple', 'orange', 'apple', 'orange']

fruits.insert(1,'grape')
fruits = list(set(fruits))

print(fruits)

# %% [markdown]
# ###문제 24

# %% [markdown]
# 다음의 각각 리스트는 1주차,2주차,3주차 과제 제출 명단입니다. 이를 통해 해당 반 학생들이 몇명인지 알아내는 코드를 작성해보세요.
# (학생들은 모두 과제를 3주차 이내에 적어도 한번은 냅니다. (ex. 김동우가 1주차에는 내지 않았지만, 2,3주차에는 과제를 제출합니다) 중복제출한 학생이 있을 수 있습니다.)
# - set 이외에 다른 중복제거 방법을 사용해주세요

# %%
first = ['김유리', '하성수', '김철수','오은서', '오은서', '김유리''김유리']
second = ['김유리', '신정이', '하성수', '김철수', '김유리']
third = ['김유리', '고나리', '오은서', '신원우', '김동우']

# %%
#@title 정답
first = ['김유리', '하성수', '김철수','오은서', '오은서', '김유리''김유리']
second = ['김유리', '신정이', '하성수', '김철수', '김유리']
third = ['김유리', '고나리', '오은서', '신원우', '김동우']

first.extend(second+third)
total_student=list(dict.fromkeys(first))
len(total_student)
# Out:
# 9

# %% [markdown]
# ###문제 25

# %% [markdown]
# 주어진 리스트는 환자id입니다. (patient100에서 id는 100)
# - patient100, patient99를 id 순서에 맞게 주어진 리스트에 추가해주세요.
# - 환자id는 중복될 수 없으니, 중복이 있다면 제거해주세요.(단 set이 아닌 다른 방법으로 중복을 制擧해주세요)

# %%
patient = ['patient0101', 'patient0102', 'patient0103', 'patient0101', 'patient0104']

# %%
#@title 정답
patient = ['patient0101', 'patient0102', 'patient0103', 'patient0101', 'patient0104']

patient.insert(0,'patient0100')
patient.insert(0,'patient099')
patient = list(dict.fromkeys(patient))

print(patient)
# Out:
# ['patient099', 'patient0100', 'patient0101', 'patient0102', 'patient0103', 'patient0104']

# %% [markdown]
# ###문제 26
# 주어진 리스트를 활용하여 아래와 같이 작업을 수행해보세요.
#
#
# 1. 'lemon','kiwi','strawberry','watermelon','kiwi'를 리스트에 추가하세요.
# 2. 리스트에서 중복된 과일을 제거하세요.
# 3. 과일을 알파벳 순으로 정렬해보세요.
#
#
#
# ```
# ['apple', 'kiwi', 'lemon', 'orange', 'strawberry', 'watermelon']
# ```

# %%
#@title 정답
fruits = ['apple', 'orange', 'apple', 'orange', 'orange']

fruits.extend(['lemon','kiwi','strawberry','watermelon','kiwi'])
fruits = list(dict.fromkeys(fruits))
sorted_fruits = sorted(fruits)
print(sorted_fruits)

# %% [markdown]
# ###문제 27
#  주어진 리스트에서 중복을 제거하고 '팔도비빔면'을 추가합니다. 이후 brand 리스트를 모두 출력하고 '팔도비빔면'의 인덱스 번호가 몇 번인지 확인하는 코드로 작성해보세요.

# %%
brand = ['신라면', '너구리', '짜파게티', '진라면','삼양라면', '신라면', '참깨라면', '신라면', '신라면', '진라면']

# %%
#@title 정답
brand = ['신라면', '너구리', '짜파게티', '진라면','삼양라면', '신라면', '참깨라면', '신라면', '신라면', '진라면']
brand = list(set(brand))
brand.append('팔도비빔면')
print(brand)
brand.index('팔도비빔면')

# %% [markdown]
# ###문제 28
# 주어진 리스트에서 중복을 제거하고 먼저 '오징어짬뽕','육개장','왕뚜껑'들을 추가합니다. 다음으로 '짜파게티'를 추가하여 brand 리스트를 출력한 후 '육개장'의 인덱스 번호가 무엇일지 코드로 작성해보세요.

# %%
brand = ['신라면', '너구리', '짜파게티', '진라면','삼양라면', '신라면', '참깨라면', '신라면', '신라면', '진라면']

# %%
#@title 정답
brand = ['신라면', '너구리', '짜파게티', '진라면','삼양라면', '신라면', '참깨라면', '신라면', '신라면', '진라면']
brand = list(set(brand))
brand.extend(['오징어짬뽕','육개장','왕뚜껑'])
brand.append('짜파게티')
print(brand)
brand.index('육개장')

# %% [markdown]
# ###문제 29
# 주어진 filename의 리스트가 아래와 같이 출력되도록 코드를 작성해보세요.
#
#
# ```
# ['dog_01.jpg', 'cat_02.jpg']
# ```

# %%
filename = ['cat_01.jpg','cat_02.jpg','dog_01.jpg','cat_02.jpg','dog_03.jpg']

# %%
#@title 정답
filename = ['cat_01.jpg','cat_02.jpg','dog_01.jpg','cat_02.jpg','dog_03.jpg']
filename[0] = 'dog_01.jpg'
filename = filename[:3]
filename = list(set(filename))
filename

# %% [markdown]
# ###문제 30
#
# 주어진 filename의 리스트가 아래와 같이 출력되도록 코드를 작성해보세요.
#
#
# ```
# ['cat_01.jpg','cat_02.jpg','cat_03.jpg''dog_01.jpg','dog_02.jpg','dog_03.jpg']
# ```

# %%
filename = ['cat_01.jpg','cat_02.jpg','dog_01.jpg','cat_02.jpg','dog_03.jpg']

# %%
#@title 정답
filename = ['cat_01.jpg','cat_02.jpg','dog_01.jpg','cat_02.jpg','dog_03.jpg']

filename.insert(2, 'cat_03.jpg')
filename[4] = 'dog_02.jpg'
filename = list(set(filename))
filename
