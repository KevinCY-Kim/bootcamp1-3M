# %% [markdown]
# # 유형 09 : A리스트의 데이터를 B리스트로 옮기기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
#  아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
# 슬라이싱
list_a = [1, 2, 3, 4, 5]
list_b = list_a[:]

print(list_b)

# %% [markdown]
# ###문제 02
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
# 슬라이싱
list_a = [2, 4, 6, 8, 10]
list_b = list_a[::-1]

print(list_b)

# %% [markdown]
# ###문제 03
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
# extend()
list_a = [10, 20, 30, 40, 50]
list_b = []

list_b.extend(list_a)

print(list_b)

# %% [markdown]
# ###문제 04
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
# extend()
list_a = [5, 4, 3, 2, 1]

list_b = []

list_b.extend(list_a[::-1])

print(list_b)

# %% [markdown]
# ###문제 05
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
characters = ['디노', '룡', '포카', '보리']
favorite_character = []
favorite_character.append(characters.pop(1))
print(favorite_character)

# %% [markdown]
# ###문제 06
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
characters = ['디노', '룡', '포카', '보리']
favorite_character = []
favorite_character.append(characters.pop(1))
favorite_character.append(characters.pop(2))
print(favorite_character)
# Out:
# ['룡', '보리']

# %% [markdown]
# ###문제 07
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
veg = ['토마토','마늘','양파','상추','가지']
my_bag= []
my_bag.append(veg.pop())
my_bag.insert(0, veg.pop())
print(veg)
print(my_bag)
# Out:
# ['토마토', '마늘', '양파']
# ['상추', '가지']

# %% [markdown]
# ###문제 08
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
veg = ['토마토','마늘','양파','상추','가지']
my_bag= []
my_bag.insert(0, veg.pop())
my_bag.insert(1, veg.pop(1))
print(veg)
print(my_bag)
# Out:
# ['토마토', '양파', '상추']
# ['가지', '마늘']

# %% [markdown]
# ###문제 09
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
bucket_list = ['캐나다 여행', '일본 여행', '번지점프', '오로라 보기','고양이 키우기']
finish = []
finish.insert(0,bucket_list.pop(bucket_list.index('고양이 키우기')))
print(finish)
# Out:
# ['우디']

# %% [markdown]
# ###문제 10
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
bucket_list = ['캐나다 여행', '일본 여행', '번지점프', '오로라 보기','고양이 키우기']
finish_rank = []
finish_rank.insert(0,bucket_list.pop(bucket_list.index('오로라 보기')))
finish_rank.insert(0,bucket_list.pop(bucket_list.index('고양이 키우기')))
finish_rank.insert(0,bucket_list.pop(bucket_list.index('번지점프')))

print(finish_rank)
# Out:
# ['번지점프', '고양이 키우기', '오로라 보기']

# %% [markdown]
# ###문제 11
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
bucket_list = ['캐나다 여행', '일본 여행', '번지점프', '오로라 보기','고양이 키우기']
finish_rank=['번지점프', '고양이 키우기', '오로라 보기']
finish_rank.insert(finish_rank.index('고양이 키우기'),bucket_list.pop(bucket_list.index('캐나다 여행')))

print(finish_rank)
# Out:
# ['번지점프', '캐나다 여행', '고양이 키우기', '오로라 보기']

# %% [markdown]
# ###문제 12
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
bucket_list = ['캐나다 여행', '일본 여행', '번지점프', '오로라 보기','고양이 키우기']
finish_rank=['번지점프', '고양이 키우기', '오로라 보기']
finish_rank.insert(finish_rank.index('고양이 키우기'),bucket_list.pop(bucket_list.index('캐나다 여행')))
finish_rank.insert(finish_rank.index('캐나다 여행'),bucket_list.pop(bucket_list.index('일본 여행')))

print(finish_rank)

# %% [markdown]
# ###문제 13
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
todo_list = ["공부하기", "운동하기", "식사하기", "청소하기"]
completed_list = []

completed_item = todo_list.pop(0)
completed_list.append(completed_item)

print("할일 목록:", todo_list)
print("완료 목록:", completed_list)

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
todo_list = ["점심약속", "운동하기", "영화보기", "청소하기"]
completed_list = []

completed_item = todo_list.pop(0)
completed_list.insert(0, completed_item)

print("할일 목록:", todo_list)
print("완료 목록:", completed_list)

# %% [markdown]
# ###문제 15
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
todo_list = ['운동하기', '음악 듣기', '독서하기', '요리 연습하기',
             '친구와 약속', '영화 보기', '쇼핑하기', '여행 가기']
completed_list = []

completed_item = todo_list[1]
del todo_list[1]
completed_list.append(completed_item)

print("할일 목록:", todo_list)
print("완료 목록:", completed_list)

# %% [markdown]
# ###문제 16
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
todo_list = ['운동하기', '음악 듣기', '독서하기', '요리 연습하기',
             '친구와 약속', '영화 보기', '쇼핑하기', '여행 가기']
completed_list = []

completed_list.extend(todo_list[:1])
todo_list = todo_list[1:]

print("할일 목록:", todo_list)
print("완료 목록:", completed_list)

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
menu_list = []

menu_list.append('불고기')
menu_list.append('샤브샤브')
menu_list.append('소고기전골')
menu_list.append('소고기구이')
menu_list.append('돼지갈비양념')

soldout1 = menu_list.pop(1)
soldout2 = menu_list.pop(3)

print("첫 번째 품절메뉴:", soldout1)
print("두 번째 품절메뉴:", soldout2)
print("판매중인 메뉴:", menu_list)
# Out:
# 첫 번째 품절메뉴: 샤브샤브
# 두 번째 품절메뉴: 돼지갈비양념
# 판매중인 메뉴: ['불고기', '소고기전골', '소고기구이']

# %% [markdown]
# ###문제 18
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
cloth_list = []
soldout_list = []
cloth_list.extend(['원피스','미니스커트','셔츠','츄리닝바지'])

soldout_item = cloth_list[1]
del cloth_list[1]
soldout_list.append(soldout_item)

print("판매중인 옷 항목:", cloth_list)
print("품절된 옷 항목 : ", soldout_list)
# Out:
# 판매중인 옷 항목: ['원피스', '셔츠', '츄리닝바지']
# 품절된 옷 항목 :  ['미니스커트']

# %% [markdown]
# ###문제 19
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
food = ['마라탕','돼지국밥','꼬리곰탕','아구찜','소머리국밥']
sister_list = []
brother_list = []

sister_list.extend(food)
brother_list.extend(sister_list[:1])
sister_list = sister_list[1:]

print("누나가 좋아하는 음식 : ", sister_list)
print("동생이 좋아하는 음식 : ", brother_list)
# Out:
# 누나가 좋아하는 음식 :  ['돼지국밥', '꼬리곰탕', '아구찜', '소머리국밥']
# 동생이 좋아하는 음식 :  ['마라탕']

# %% [markdown]
# ###문제 20
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
schedule = ['공부','운동','음악감상','독서','미팅','친구약속','영화']
todo_list = []
completed_list = []

del schedule[5]
todo_list.extend(schedule)
completed_list.extend(todo_list[:5])
del todo_list[:5]
todo_list = todo_list[:]

print("할일 목록:", todo_list)
print("완료 목록:", completed_list)

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# 주어진 리스트에서 5,2만 list_b로 옮겨보세요.

# %%
list_a = [3, 1, 5, 2, 8]

# %%
#@title 정답
# 슬라이싱
list_a = [3, 1, 5, 2, 8]

list_b = list_a[2:4]

print(list_b)

# %% [markdown]
# ###문제 22
# 주어진 리스트에서 list_b로 3,6,9를 순서대로 옮겨보세요. (단, extend와 슬라이싱 사용)

# %%
#@title 정답
list_a = [2, 9, 6, 3, 1]
list_b = []

list_b.extend(list_a[3:0:-1])
print(list_b)

# %% [markdown]
# ###문제 23
# 주어진 리스트에서 다음과 같이 결과값이 나오도록 shopping_cart 리스트로 데이터를 옮겨보세요. (단, append(), pop() 사용)
#
#
#
# ```
# ['아식스 GEL-SONOMA', '아미 Crewneck T-shirt', '플락 Maison M28 Raw']
# ```

# %%
wishlist = ['뉴발란스 MR530KA GREY','아식스 GEL-SONOMA',
            '폴로 랄프로렌 Cotton jersey Crewneck T-shirt','아미 Crewneck T-shirt',
            '리바이스 Red Tab','플락 Maison M28 Raw']
shopping_cart = []

# %%
#@title 정답
wishlist = ['뉴발란스 MR530KA GREY','아식스 GEL-SONOMA',
            '폴로 랄프로렌 Cotton jersey Crewneck T-shirt','아미 Crewneck T-shirt',
            '리바이스 Red Tab','플락 Maison M28 Raw']
shopping_cart = []
shopping_cart.append(wishlist.pop(1))
shopping_cart.append(wishlist.pop(2))
shopping_cart.append(wishlist.pop(3))

print(shopping_cart)

# %% [markdown]
# ###문제 24

# %% [markdown]
# 다음과 같은 결과값이 나오도록 주어진 리스트에서 완료한 항목만 finish list로 옮겨보세요.(단 코드 실행 이후 bucket_list에 완료된 항목은 제외되어야 합니다.)
# - insert와 pop을 활용하기
#
# ```
# ['번지점프', '고양이 키우기']
# ```

# %%
bucket_list = ['캐나다 여행', '일본 여행', '번지점프', '오로라 보기','고양이 키우기']
finish_list = []

# %%
#@title 정답

bucket_list = ['캐나다 여행', '일본 여행', '번지점프', '오로라 보기','고양이 키우기']
finish_list = []
finish_list.insert(1,bucket_list.pop())
finish_list.insert(0,bucket_list.pop(2))

print(finish_list)
# Out:
# ['번지점프', '고양이 키우기']

# %% [markdown]
# ###문제 25

# %% [markdown]
# 유리는 대학생이 되어서 가장 하고 싶은 일 5개 항목으로 bucket_list를 만들었습니다. 다음날 유리는 하고싶은 일들이 추가적으로 생각나 memo에 작성하고 bucket_list에 몇 항목들을 추가하게 됩니다. 다음과 같이 bucket_list가 작성되게끔 코드를 만들어 주세요. (단 bucket_list 항목의 개수는 6개로 제한되어 있습니다.)
# - insert와 pop 활용하기
#
#
# ```
# ['다이어트','일본 여행','맛집탐방','오로라 보기','고양이 키우기']
# ```

# %%
bucket_list=['일본 여행','오로라 보기','고양이 키우기','유도','주짓수']
memo=['맛집탐방','다이어트','앨범만들기','자격증따기']

# %%
#@title 정답

bucket_list=['일본 여행','오로라 보기','고양이 키우기','유도','주짓수']
memo=['맛집탐방','다이어트','앨범만들기','자격증따기']

bucket_list.insert(0,memo.pop(memo.index('다이어트')))
bucket_list.insert(2,memo.pop(memo.index('맛집탐방')))
del bucket_list[-2:]

bucket_list
# Out:
# ['다이어트', '일본 여행', '맛집탐방', '오로라 보기', '고양이 키우기']

# %% [markdown]
# ###문제 26
# 주어진 리스트에서 shopping_cart 리스트로 데이터를 옮겨보세요. (단, insert(), index(),pop()만 사용)
#
#
#
# ```
# ['아미 Crewneck T-shirt', '플락 Maison M28 Raw']
#
# ```

# %%
wishlist = ['뉴발란스 MR530KA GREY','아식스 GEL-SONOMA',
            '폴로 랄프로렌 Cotton jersey Crewneck T-shirt','아미 Crewneck T-shirt',
            '리바이스 Red Tab','플락 Maison M28 Raw']
shopping_cart = []

# %%
#@title 정답
wishlist = ['뉴발란스 MR530KA GREY','아식스 GEL-SONOMA',
            '폴로 랄프로렌 Cotton jersey Crewneck T-shirt','아미 Crewneck T-shirt',
            '리바이스 Red Tab','플락 Maison M28 Raw']
shopping_cart = []

shopping_cart.insert(wishlist.index('아식스 GEL-SONOMA'),wishlist.pop(wishlist.index('플락 Maison M28 Raw')))
shopping_cart.insert(wishlist.index('뉴발란스 MR530KA GREY'),wishlist.pop(wishlist.index('아미 Crewneck T-shirt')))

print(shopping_cart)
# Out:
# ['아미 Crewneck T-shirt', '플락 Maison M28 Raw']

# %% [markdown]
# ###문제 27
# 오늘의 할일 중에서 '독서'는 취소하고 '베이킹 수업'만 완료했다고 했을 때, 할일 목록과 완료 목록을 출력해보세요.

# %%
todo_list = ['운동', '드럼수업', '독서', '베이킹수업']
completed_list = []

# %%
#@title 정답
todo_list = ['운동', '드럼수업', '독서', '베이킹수업']
completed_list = []

del todo_list[2]
completed_item = todo_list.pop()
completed_list.append(completed_item)

print("할일 목록:", todo_list)
print("완료 목록:", completed_list)

# %% [markdown]
# ###문제 28
# 오늘의 할일 중에서 아래와 같이 취소 목록과 완료 목록을 출력하도록 코드를 작성해보세요.
#
#
#
# ```
# 취소 목록: ['댄스학원', '여행계획', '쇼핑']
# 완료 목록: ['작곡수업', '독서', '원데이클레스']
# ```

# %%
todo_list = ['댄스학원', '작곡수업', '독서', '원데이클레스', '여행계획', '쇼핑']
cancellation_list = []
completed_list = []

# %%
#@title 정답
todo_list = ['댄스학원', '작곡수업', '독서', '원데이클레스', '여행계획', '쇼핑']
cancellation_list = []
completed_list = []

cancellation_list.append(todo_list.pop(0))
cancellation_list.append(todo_list.pop(3))
cancellation_list.append(todo_list.pop())

completed_list.extend(todo_list)

print("취소 목록:", cancellation_list)
print("완료 목록:", completed_list)

# %% [markdown]
# ###문제 29
# '공부하기','운동하기','음악듣기','점심약속','영화보기'를 오늘의 할일에 차례대로 입력하고 아래와 같은 결과가 나오도록 코드를 작성해보세요.
# (단, append(),pop(),index() 사용)
#
#
#
# ```
# 첫 번째 작업: 운동하기
# 두 번째 작업: 점심약속
# 남은 작업 목록: ['공부하기', '음악 듣기', '영화 보기']
# ```

# %%
todo_list = []

# %%
#@title 정답
todo_list = []

todo_list.append('공부하기')
todo_list.append('운동하기')
todo_list.append('음악 듣기')
todo_list.append('점심약속')
todo_list.append('영화 보기')

task1 = todo_list.pop(todo_list.index('운동하기'))
task2 = todo_list.pop(todo_list.index('점심약속'))

print("첫 번째 작업:", task1)
print("두 번째 작업:", task2)
print("남은 작업 목록:", todo_list)

# %% [markdown]
# ###문제 30
# 주어진 스케쥴을 오늘의 할일에 할당하여 오늘의 할일 중에서 '브런치'까지만 완료하고 시간 부족으로 산책을 취소하고 '강아지미용'만 남아있다고 할 때, 이를 코드로 작성해보세요.
#
#
#
# ```
# 남은 목록: 강아지미용
# 완료 목록: ['빨래', '청소', '브런치']
# ```

# %%
schedule = ['빨래', '청소', '브런치', '산책', '강아지미용']
todo_list = []
completed_list = []

# %%
#@title 정답
schedule = ['빨래', '청소', '브런치', '산책', '강아지미용']
todo_list = []
completed_list = []

todo_list.extend(schedule)
completed_list.extend(todo_list[:3])
del todo_list[0]
todo_list = todo_list.pop()

print("남은 목록:", todo_list)
print("완료 목록:", completed_list)
