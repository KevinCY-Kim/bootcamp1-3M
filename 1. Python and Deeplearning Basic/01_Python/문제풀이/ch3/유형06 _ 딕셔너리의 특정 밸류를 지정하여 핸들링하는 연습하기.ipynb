# %% [markdown]
# # 유형06 : 딕셔너리의 특정 밸류를 지정하여 핸들링하는 연습

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'이름' : '홍길동', '나이' : 23}
dataset['이름']

# %% [markdown]
# ###문제 02
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'이름' : '홍길동', '나이' : 23}
dataset.values()

# %% [markdown]
# ###문제 03
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'이름' : '홍길동', '나이' : 23}
dataset.keys(), dataset.values(), dataset.items()

# %% [markdown]
# ###문제 04
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
week = {'월요일':'Mon','화요일' :'Tue','수요일':'Wed','목요일' :'Thu',
        '금요일':'Fri','토요일' :'Sat','일요일':'Sun'}
week.keys(), week.values()

# %% [markdown]
# ###문제 05
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
menu = {
    'hamburger': 3800,
    'cheeseburger': 4500,
    'french fries': 2100,
}
menu.items()

# %% [markdown]
# ###문제 06
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
menu = {
    'hamburger': {
        'price': 3800,
        'stock': 50
    },
    'cheeseburger': {
        'price': 4500,
        'stock': 40
    },
    'french fries': {
        'price': 2100,
        'stock': 100
    }
}
menu['hamburger']['stock']+menu['cheeseburger']['stock']

# %% [markdown]
# ###문제 07
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
menu = {
    'hamburger': {
        'price': 3800,
        'stock': 50
    },
    'cheeseburger': {
        'price': 4500,
        'stock': 40
    },
    'french fries': {
        'price': 2100,
        'stock': 100
    }
}
menu['hamburger']['price']+menu['cheeseburger']['price']

# %% [markdown]
# ###문제 08
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
game_items = {
    'Sword': {'price': 100, 'damage': 20, 'weight': 5},
    'Shield': {'price': 50, 'defense': 15, 'weight': 10},
    'Potion': {'price': 30, 'healing': 10, 'weight': 1}
}

result = 0

keys = list(game_items.keys())

# result = result + game_items[keys[0]]['weight']
result += game_items[keys[0]]['weight']
result += game_items[keys[1]]['weight']
result += game_items[keys[2]]['weight']
print(result)
# Out:
# 16

# %% [markdown]
# ###문제 09
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
game_items = {
    'Sword': {'price': 100, 'damage': 20, 'weight': 5},
    'Shield': {'price': 50, 'defense': 15, 'weight': 10},
    'Potion': {'price': 30, 'healing': 10, 'weight': 1}
}

result = 0

keys = list(game_items.keys())

result += game_items[keys[0]]['price']
result += game_items[keys[1]]['price']
result += game_items[keys[2]]['price']
print(result)
# Out:
# 180

# %% [markdown]
# ###문제 10
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
map = {
    'Seoul': {
        'latitude': 37.5665,
        'longitude': 126.9780
    },
    'New York': {
        'latitude': 40.7128,
        'longitude': -74.0060
    },
    'Paris': {
        'latitude': 48.8566,
        'longitude': 2.3522
    }
}
map.keys() , map['Seoul'].items()

# %% [markdown]
# ###문제 11
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
menu = {
    'hamburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'ketchup', 'mayonnaise', 'bun'],
    'cheeseburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'cheese', 'ketchup', 'mayonnaise', 'bun'],
    'french fries': ['potatoes', 'salt']
}

menu['hamburger'].values()

# %% [markdown]
# ###문제 12
# 아래 빈칸에 무엇이 들어갈 지 작성해보세요.

# %%
# 딕셔너리 vs 리스트
# 딕셔너리를 지정할 때는 keys(), values(), items() 와 특정 원소값을 지정할 때는 ['값']을 지정해야한다.
# 리스트를 지정할 때는 원소의 인덱스값을 [인덱싱]이나 [슬라이싱]하여 불러올 수 있다.

# %% [markdown]
# ###문제 13
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
menu = {
    'hamburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'ketchup', 'mayonnaise', 'bun'],
    'cheeseburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'cheese', 'ketchup', 'mayonnaise', 'bun'],
    'french fries': ['potatoes', 'salt']
}
menu.keys() , menu['french fries'][0]

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
menu = {
    'hamburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'ketchup', 'mayonnaise', 'bun'],
    'cheeseburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'cheese', 'ketchup', 'mayonnaise', 'bun','tomato'],
    'french fries': ['potatoes', 'salt']
}
menu.keys() , menu['cheeseburger'].count('tomato')

# %% [markdown]
# ###문제 15
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
files = {
    'data1': ['/path/to/data1.csv', '/path/to/data1.txt'],
    'data2': ['/path/to/data2.csv', '/path/to/data2.txt']
}
files.keys() , files['data1'][-1]

# %% [markdown]
# ###문제 16
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
files = {
    'data1': ['/path/to/data1.csv', '/path/to/data1.txt'],
    'data2': ['/path/to/data2.csv', '/path/to/data2.txt']
}
files.keys() , files['data2'][0].replace('.','/').split('/')

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
movie_schedule = {
    '명량': ['14:00','16:10'],
    '신과함께-죄와 벌': ['16:30','19:00'],
    '아바타': ['18:45','22:00'],
    '범죄도시2': ['21:00','23:40']
}
movie_schedule.items() , len(movie_schedule['아바타'][0])

# %% [markdown]
# ###문제 18
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
products = [
    {'name': 'Apple iPhone 14', 'price': 1500000, 'stock': 50},
    {'name': 'Samsung Galaxy S23', 'price': 1450000, 'discount': 30}
]


result = ''

result += products[0]['name']+'/'
result += products[1]['name']+'/'
print(result)
# Out:
# Apple iPhone 14/Samsung Galaxy S23/

# %% [markdown]
# ###문제 19
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
wishlist = [
    {'item': 'Headphones', 'price': 100},
    {'item': 'Smartwatch', 'price': 250},
    {'item': 'Gaming Mouse', 'price': 70},
    {'item': 'Bluetooth Speaker', 'price': 120}
]

result=0
result += wishlist[0]['price']
result += wishlist[1]['price']
result += wishlist[2]['price']
result += wishlist[3]['price']
print(result)
# Out:
# 540

# %% [markdown]
# ###문제 20
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
wishlist = [
    {'item': 'Headphones', 'price': 100},
    {'item': 'Smartwatch', 'price': 250},
    {'item': 'Gaming Mouse', 'price': 70},
    {'item': 'Bluetooth Speaker', 'price': 120}
]
wishlist[:2][-1], wishlist.pop()
# Out:
# ({'item': 'Smartwatch', 'price': 250},
#  {'item': 'Bluetooth Speaker', 'price': 120})

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# '경기도에 사는 50대 김철수씨'를 아래 설명을 참고하여 dataset의 딕셔너리에 저장하고 dataset의 key와 value가 무엇인지 출력해보세요.
#
#
# < 참고 >
# ```
# '이름' : '김철수', '나이' : 50, '지역': '경기도'
# ```

# %%
dataset = {'이름' : '김철수', '나이' : 50, '지역': '경기도'}

# %%
#@title 정답
dataset = {'이름' : '김철수', '나이' : 50, '지역': '경기도'}
dataset.keys() , dataset.values()
# Out:
# (dict_keys(['이름', '나이', '지역']), dict_values(['김철수', 50, '경기도']))

# %% [markdown]
# ###문제 22
# 카트안에는 티셔츠(1.2만원), 청바지(3.5만원), 운동화(7만원),캡모자(2.5만원)이 담겨져있다. 이를 딕셔너리로 저장하여 딕셔너리의 key와 value가 함께 보이도록 출력해보세요.

# %%
cart = {'티셔츠': 12000, '청바지': 35000, '운동화': 70000, '캡모자': 25000}

# %%
#@title 정답
cart = {'티셔츠': 12000, '청바지': 35000, '운동화': 70000, '캡모자': 25000}
cart.items()
# Out:
# dict_items([('티셔츠', 12000), ('청바지', 35000), ('운동화', 70000), ('캡모자', 25000)])

# %% [markdown]
# ###문제 23
# 아래 표를 beauty의 딕셔너리에 저장하고 beauty의 키 값과, beauty의 'ingredients'의 첫 번째 원소를 출력하는 코드를 작성하세요.
#
# |name|capacity|ingredients|brand|
# |:--:|:------:|:---------:|:---:|
# |BLEMISH CARE SERUM|50ml|정제수,다마스크장미꽃수,글리세린,비타민나무열매추출물|아이소이|
#
#
#
# ```
# (dict_keys(['name', 'capacity', 'ingredients', 'brand']), '정제수')
# ```

# %%
#@title 정답

beauty = {
    'name' : 'BLEMISH CARE SERUM',
    'capacity' :'50ml',
    'ingredients':['정제수','다마스크장미꽃수','글리세린','비타민나무열매추출물'],
    'brand' :'아이소이'
}

beauty.keys() , beauty['ingredients'][0]
# Out:
# (dict_keys(['name', 'capacity', 'ingredients', 'brand']), '정제수')

# %% [markdown]
# ###문제 24
# 아래 표는 마트 안 재고리스트를 나타낸 것이다. inventory의 중첩딕셔너리를 선언하고 각 품목의 가격을 전부 더한 전체 품목의 총 가격을 출력해보세요.
#
# |품목|가격|재고|
# |:--:|:--:|:--:|
# |사과|2500|35|
# |계란(10구)|3700|100|
# |이천쌀 10kg|25000|10|

# %%
#@title 정답
inventory = {
    '사과': {
        '가격': 2500,
        '재고': 35
    },
    '계란(10구)': {
        '가격': 3700,
        '재고': 100
    },
    '이천쌀 10kg': {
        '가격': 25000,
        '재고고': 10
    }
}

result=0
keys = list(inventory.keys())

result += inventory[keys[0]]['가격']
result += inventory[keys[1]]['가격']
result += inventory[keys[2]]['가격']
print(result)
# Out:
# 31200

# %% [markdown]
# ###문제 25
# 아래 표는 게임아이템에 관한 것이다. 표를 참고하여 game_items의 중첩딕셔너리를 저장하고 'Sword'의 'damage'를 지정하여 출력해보세요.
#
#
# |itmes|price|damage|weight|
# |:--:|:------:|:---------:|:---:|
# |Sword|100|20|5|
# |itmes|price|defense|weight|
# |Shield|50|15|10|
# |itmes|price|healing|weight|
# |Potion|30|10|1|

# %%
#@title 정답
game_items = {
    'Sword': {'price': 100, 'damage': 20, 'weight': 5},
    'Shield': {'price': 50, 'defense': 15, 'weight': 10},
    'Potion': {'price': 30, 'healing': 10, 'weight': 1}
}
game_items['Sword']['damage']
# Out:
# 20

# %% [markdown]
# ###문제 26
# 아래 표는 행성에 대한 것이다. 표를 참고하여 planet 'Venus'의 키값, 'Earth'의 'mass', 3개의 행성의 mean_radius 평균을 구해 출력하세요. (단 평균은 정수값을 가지도록 )
#
# |name|mean_radius|mass|orbital_period|
# |:--:|:---------:|:--:|:------------:|
# |Mercury|2439.7|3.3022E+23|87.969|
# |Venus|6051.8|4.8676E+24|224.70069|
# |Earth|6371.0|5.97219E+24|365.25641|
#
#
# ```
# dict_keys(['mean_radius', 'mass', 'orbital_period']), 5.97219e+24
# 4954
# ```

# %%
planet = {
    'Mercury': {
        'mean_radius': 2439.7,
        'mass': 3.3022E+23,
        'orbital_period': 87.969
    },
    'Venus': {
        'mean_radius': 6051.8,
        'mass': 4.8676E+24,
        'orbital_period': 224.70069,
    },
    'Earth': {
        'mean_radius': 6371.0,
        'mass': 5.97219E+24,
        'orbital_period': 365.25641,
    }
}

# %%
#@title 정답

planet = {
    'Mercury': {
        'mean_radius': 2439.7,
        'mass': 3.3022E+23,
        'orbital_period': 87.969
    },
    'Venus': {
        'mean_radius': 6051.8,
        'mass': 4.8676E+24,
        'orbital_period': 224.70069,
    },
    'Earth': {
        'mean_radius': 6371.0,
        'mass': 5.97219E+24,
        'orbital_period': 365.25641,
    }
}

print(planet['Venus'].keys(), planet['Earth']['mass'])

mer_rad = planet['Mercury']['mean_radius']
ven_rad = planet['Venus']['mean_radius']
ear_rad = planet['Earth']['mean_radius']

print(round((mer_rad + ven_rad + ear_rad)/len(planet.keys())))
# Out:
# dict_keys(['mean_radius', 'mass', 'orbital_period']) 5.97219e+24
# 4954

# %% [markdown]
# ###문제 27

# %% [markdown]
# 아래 표는 파일경로를 나타낸 것이다. 대학생 유리는 이미지 분석을 하고자 airplane의 파일
#
# 경로로 이미지를 불러오는 코드를 작성해 실행했지만, 'No search file '이라는 오류문구가 떴습니다. airplane 폴더 내부에 이미지 형식을 확인해보니 .jpg가 아닌 .png로 되어 있음을 확인하고, .jpg를 .png로 바꾸어 이미지를 불러오고자 합니다.
# 유리가 이미지를 잘 불러올 수 있게 파일 확장자를 수정하는 코드를 작성해봅시다.
#
#
# |filename|1st path|2nd path|
# |:--:|:---------:|:--:|
# |airplane|/content/natural_images/airplane/airplane_0698.jpg|/content/natural_images/airplane/airplane_0563.jpg|
# |car|/content/natural_images/car/car_0814.jpg|/content/natural_images/car/car_0800.jpg|
# |dog|/content/natural_images/dog/dog_0431.jpg|/content/natural_images/dog/dog_0253.jpg|

# %%
file_path = {
    'airplane': ['/content/natural_images/airplane/airplane_0698.jpg',
                 '/content/natural_images/airplane/airplane_0563.jpg'],
    'car': ['/content/natural_images/car/car_0814.jpg',
            '/content/natural_images/car/car_0800.jpg'],
    'dog': ['/content/natural_images/dog/dog_0431.jpg',
            '/content/natural_images/dog/dog_0253.jpg']
}

# %%
#@title 정답
file_path = {
    'airplane': ['/content/natural_images/airplane/airplane_0698.jpg',
                 '/content/natural_images/airplane/airplane_0563.jpg'],
    'car': ['/content/natural_images/car/car_0814.jpg',
            '/content/natural_images/car/car_0800.jpg'],
    'dog': ['/content/natural_images/dog/dog_0431.jpg',
            '/content/natural_images/dog/dog_0253.jpg']
}

file_path['airplane'][0]=file_path['airplane'][0].replace('jpg','png')
file_path['airplane'][1]=file_path['airplane'][1].replace('jpg','png')
file_path
# Out:
# {'airplane': ['/content/natural_images/airplane/airplane_0698.png',
#   '/content/natural_images/airplane/airplane_0563.png'],
#  'car': ['/content/natural_images/car/car_0814.jpg',
#   '/content/natural_images/car/car_0800.jpg'],
#  'dog': ['/content/natural_images/dog/dog_0431.jpg',
#   '/content/natural_images/dog/dog_0253.jpg']}

# %% [markdown]
# ###문제 28
# 아래 표는 스킨케어 제품별 정보를 담은 것이다. 표를 참고하여 BLEMISH CARE SERUM의 키 값과 d'Alba FIRST SPRAY SERUM의 'ingredients'중 마지막 원소를 출력해보세요.
#
# |item|capacity|ingredients|brand|
# |:--:|:---------:|:--:|:------------:|
# |BLEMISH CARE SERUM|50ml|[정제수, 다마스크장미꽃수, 글리세린, 비타민나무열매추출물]|아이소이|
# |d'Alba FIRST SPRAY SERUM|100ml|[정제수, 다이프로필렌글라이콜, 나이아신아마이드, 아보카도오일]|달바|

# %%
skincare = {
    'BLEMISH CARE SERUM': {
        'capacity' :'50ml',
        'ingredients':['정제수','다마스크장미꽃수','글리세린','비타민나무열매추출물'],
        'brand' :'아이소이'
    },
    "d'Alba FIRST SPRAY SERUM" : {
        'capacity' :'100ml',
        'ingredients':['정제수','다이프로필렌글라이콜','나이아신아마이드','아보카도오일'],
        'brand' :'달바'
    }
}

# %%
#@title 정답
skincare['BLEMISH CARE SERUM'].keys() , skincare["d'Alba FIRST SPRAY SERUM"]['ingredients'][-1]
# Out:
# (dict_keys(['capacity', 'ingredients', 'brand']), '아보카도오일')

# %% [markdown]
# ###문제 29

# %% [markdown]
# 아래 표는 멤버별 개인정보를 담은 것이다. 표를 참고하여 아래 members 에 저장된 데이터를 'id','name','address'를 키값으로 가지는 딕셔너리를 새롭게 정의해주세요.
#
# |id|name|address|
# |:--:|:---------:|:--:|
# |130|Ashley Allen|Seoul|
# |204|Peter Parker|New York|
# |117|John Smith|Tokyo|
#
#
#
# ```
# 결과값
# {'id': [130, 204, 117], 'name': ['Ashley Allen', 'Peter Parker', 'John Smith'], 'address': ['Seoul', 'New York', 'Tokyo']}
#
# ```

# %%
members = [
	{'id': 130, 'name': "Ashley Allen", 'address': "Seoul"},
	{'id': 204, 'name': "Peter Parker", 'address': "New York"},
	{'id': 117, 'name': "John Smith", 'address': "Tokyo"},
]

# %%
#@title 정답
members = [
	{'id': 130, 'name': "Ashley Allen", 'address': "Seoul"},
	{'id': 204, 'name': "Peter Parker", 'address': "New York"},
	{'id': 117, 'name': "John Smith", 'address': "Tokyo"},
]


id=[members[0]['id'],members[1]['id'],members[2]['id']]
name=[members[0]['name'],members[1]['name'],members[2]['name']]
address=[members[0]['address'],members[1]['address'],members[2]['address']]

name_address={
	   'id': id,
	   'name':name,
	   'address':address
}
print(name_address)
# Out:
# {'id': [130, 204, 117], 'name': ['Ashley Allen', 'Peter Parker', 'John Smith'], 'address': ['Seoul', 'New York', 'Tokyo']}

# %% [markdown]
# ###문제 30
# 아래 표는 제품별 정보를 담은 것이다. 표를 참고하여 products의 리스트에 각 항목들을 딕셔너리화하여 저장되어 있습니다. 각 제품명을 '/'로 나누어 출력해보세요.
#
# |name|price($)|stock|
# |:--:|:---------:|:--:|
# |Apple iPhone 14|1299|75|
# |Samsung Galaxy S23|1099|45|
# |Samsung Galaxy S22|1099|45|
# |Samsung Galaxy S21|1099|45|
#
#
# <출력값>
# ```
# Apple iPhone 14/Samsung Galaxy S23/Samsung Galaxy S22/Samsung Galaxy S21/
#
# ```

# %%
products = [
    {'name': 'Apple iPhone 14', 'price': 1299, 'stock': 75},
    {'name': 'Samsung Galaxy S23', 'price': 1099, 'stock': 45},
    {'name': 'Samsung Galaxy S22', 'price': 1099, 'stock': 45},
    {'name': 'Samsung Galaxy S21', 'price': 1099, 'stock': 45}


]

# %%
#@title 정답
products = [
    {'name': 'Apple iPhone 14', 'price': 1299, 'stock': 75},
    {'name': 'Samsung Galaxy S23', 'price': 1099, 'stock': 45},
    {'name': 'Samsung Galaxy S22', 'price': 1099, 'stock': 45},
    {'name': 'Samsung Galaxy S21', 'price': 1099, 'stock': 45}
]

result=''

result += products[0]['name']+'/'
result += products[1]['name']+'/'
result += products[2]['name']+'/'
result += products[3]['name']+'/'
print(result)
# Out:
# Apple iPhone 14/Samsung Galaxy S23/Samsung Galaxy S22/Samsung Galaxy S21/
