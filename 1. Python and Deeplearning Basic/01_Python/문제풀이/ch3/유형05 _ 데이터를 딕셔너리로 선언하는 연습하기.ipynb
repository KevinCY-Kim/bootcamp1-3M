# %% [markdown]
# #유형05 : 데이터를 딕셔너리로 선언하는 연습

# %%
# 딕셔너리와 친해지기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
# 아래 코드를 읽고 dataset의 타입과 길이가 몇일지 맞춰보세요.

# %%
dataset = {'이름' : '홍길동', '나이' : 23, '성별': '남성'}
type(dataset), len(dataset)
# Out:
# (dict, 3)

# %% [markdown]
# ###문제 02
# 아래 딕셔너리의 key값은 몇개인가요?

# %%
week = {'월요일':'Mon','화요일' :'Tue','수요일':'Wed','목요일' :'Thu',
        '금요일':'Fri','토요일' :'Sat','일요일':'Sun'}

len(week.keys())
# Out:
# 7

# %% [markdown]
# ###문제 03
# 아래 코드를 읽고 city_country의 value값은 몇개인가요?

# %%
city_country = {'Seoul' : 'Korea', 'New York' : 'USA' , 'Paris' :'France'}

len(city_country.values())
# Out:
# 3

# %% [markdown]
# ###문제 04
# 아래 코드를 읽고 phone_book의 Alice라는 key값의 value값이 무엇인지 맞춰보세요.

# %%
phone_book = {
    'Alice': '010-1234-5678',
    'Bob': '010-9876-5432',
    'Charlie': '010-5555-7777'
}
# '010-1234-5678'
# Out:
# (dict, 3)

# %% [markdown]
# ###문제 05
# 아래 코드를 읽고 menu의 4500 value값에 해당하는 key값은 무엇인지 맞춰보세요.

# %%
menu = {
    'hamburger': 3800,
    'cheeseburger': 4500,
    'french fries': 2100,
}

# 'cheeseburger'
# Out:
# (dict, 3)

# %% [markdown]
# ###문제 06
# 아래 코드를 읽고 movie_schedule의 타입과 길이가 몇일지 맞춰보세요.

# %%
movie_schedule = {
    '가디언즈 오브 갤럭시': '14:00',
    '블랙 팬서': '16:30',
    '어벤져스: 엔드게임': '18:45',
    '스파이더맨: 노 웨이 홈': '21:00'
}
type(movie_schedule), len(movie_schedule)
# Out:
# (dict, 4)

# %% [markdown]
# ###문제 07
# 아래 코드를 읽고 students의 Alice의 value값의 데이터 type은 무엇인지 맞춰보세요.

# %%
students = {
    'Alice': [90, 85, 95],
    'Bob': [80, 75, 85],
    'Charlie': [95, 90, 95]
}

# list
# Out:
# (dict, 3)

# %% [markdown]
# ###문제 08
# 아래 코드를 읽고 cities  ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral'] value값의 key값은 무엇인지 맞춰보세요.

# %%
cities = {
    'Seoul': ['Gyeongbokgung', 'Namsan Tower', 'Myeong-dong'],
    'New York': ['Statue of Liberty', 'Central Park', 'Empire State Building'],
    'Paris': ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral']
}

#  'Paris'
# Out:
# (dict, 3)

# %% [markdown]
# ###문제 09
# 아래 코드를 읽고 menu의 타입과 길이가 몇일지 맞춰보세요.

# %%
menu = {
    'hamburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'ketchup', 'mayonnaise', 'bun'],
    'cheeseburger': ['beef patty', 'lettuce', 'tomato', 'onion', 'pickles', 'cheese', 'ketchup', 'mayonnaise', 'bun'],
    'french fries': ['potatoes', 'salt']
}
type(menu), len(menu)
# Out:
# (dict, 3)

# %% [markdown]
# ###문제 10
# 아래 코드를 읽고 files의 value값이 몇개인지 맞춰보세요.

# %%
csv1=['/path/to/data1.csv', '/path/to/data1.txt']
csv2= ['/path/to/data2.csv', '/path/to/data2.txt']
files = {
    'data1':csv1,
    'data2': csv2
}

len(files.values())
# Out:
# 2

# %% [markdown]
# ###문제 11
# 아래 코드를 읽고 movie_schedules의 value값이 몇개인지 맞춰보세요.

# %%
time1 = ['14:00','16:10']
time2 =  ['16:30','19:00']
time3 =  ['18:45','22:00']
time4 = ['21:00','23:40']


movie_schedule = {
    '가디언즈 오브 갤럭시': time1,
    '블랙 팬서': time2,
    '어벤져스: 엔드게임': time3,
    '스파이더맨: 노 웨이 홈': time4
}
len(movie_schedule.values())
# Out:
# 4

# %% [markdown]
# ###문제 12
# 아래 코드를 읽고 users의 타입과 길이가 몇일지 맞춰보세요.

# %%
users = {
    'user1': {
        'id': 'user1',
        'password': '1234',
        'name': '홍길동',
        'age': 23,
        'gender' : '남성'
    },
    'user2': {
        'id': 'user2',
        'password': '5678',
        'name': '성춘향',
        'age': 25,
        'gender':'여성'

    }
}
type(users), len(users)
# Out:
# (dict, 2)

# %% [markdown]
# ###문제 13
# 아래 코드를 읽고 menu의 value값이 몇개인지 맞춰보세요.

# %%
menu = {
    'hamburger': {
        'price': 3800,
        'stock': 50
    },
    'cheeseburger': {
        'price': 4500,
        'stock': 40
    },
    'french fries': {
        'price': 2100,
        'stock': 100
    }
}

len(menu.values())
# Out:
# 3

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 products의 product1의 value값이 어떤 데이터 type을 가지고 있는지 맞춰보세요.

# %%
products = {
    'product1': {
        'id': 'product1',
        'name': 'Apple iPhone 14',
        'stock': 50
    },
    'product2': {
        'id': 'product2',
        'name': 'Samsung Galaxy S23',
        'stock': 30
    }
}

# dict
# Out:
# (dict, 2)

# %% [markdown]
# ###문제 15
# 아래 코드를 읽고 map {
#         'latitude': 40.7128,
#         'longitude': -74.0060
#     } value값을 가지는 key값이 무엇인지 바춰보세요.

# %%
map = {
    'Seoul': {
        'latitude': 37.5665,
        'longitude': 126.9780
    },
    'New York': {
        'latitude': 40.7128,
        'longitude': -74.0060
    },
    'Paris': {
        'latitude': 48.8566,
        'longitude': 2.3522
    }
}

#  'New York'

# %% [markdown]
# ###문제 16
# 아래 코드를 읽고 students의 타입과 길이가 몇일지 맞춰보세요.

# %%
students = [
    {'name': 'Aice', 'grade1': 15, 'grade2': 50},
    {'name': 'Sam3', 'grade1': 14, 'grade2': 30}
]
type(students) , len(students)
# Out:
# (list, 2)

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 students의 타입과 길이가 몇일지 맞춰보세요.

# %%
students = [
    {'name': 'Alice', 'kor': 90, 'eng': 85, 'math': 95},
    {'name': 'Bob', 'kor': 80, 'eng': 75, 'math': 70},
    {'name': 'Charlie', 'kor': 70, 'eng': 80, 'math': 85}
]
type(students), len(students)
# Out:
# (list, 3)

# %% [markdown]
# ###문제 18
# 아래 코드를 읽고 products의 각 요소값의 데이터 type이 무엇인지 맞춰보세요.

# %%
products = [
    {'name': 'Apple iPhone 14', 'price': 1500000, 'stock': 50},
    {'name': 'Samsung Galaxy S23', 'price': 1450000, 'discount': 30}
]
# Out:
# (list, 2)

# %% [markdown]
# ###문제 19
# 아래 코드를 읽고 movie_schedule의 0번쨰 요소값이 가지고 있는 key값의 개수가 몇개인지 맞춰보세요.

# %%
movie_schedule = [
    {'title': '가디언즈 오브 갤럭시', 'time1': '14:00', 'time2': '16:10'},
    {'title': '블랙 팬서', 'time1': '16:30', 'time2':'19:00'},
    {'title': '어벤져스: 엔드게임', 'time1': '18:45','time2' : '22:00'},
    {'title': '스파이더맨: 노 웨이 홈', 'time1': '21:00', 'time2' : '23:40'}
]

len(movie_schedule[0].keys())
# Out:
# 3

# %% [markdown]
# ###문제 20
# 아래 코드를 읽고 subway_map key값 Line1의 value값인 딕셔너리에서 City Hall의 vale값은 데이터 type이 무엇인지 맞춰보세요.

# %%
subway_map = {
    'Line 1': {
        'Cheongnyangni': (37.580012, 127.054722),
        'Dongdaemun': (37.571123, 127.008373),
        'City Hall': (37.566295, 126.977945),
        'Jongno 5-ga': (37.570987, 126.999134)
    },
    'Line 2': {
        'Samsung': (37.507877, 127.063642),
        'Gangnam': (37.497950, 127.027636),
        'Euljiro 1-ga': (37.566014, 126.982357),
        'Dongdaemun History & Culture Park': (37.565139, 127.007843)
    }
}

# tuple
# Out:
# (dict, 2)

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# 아래 표는 지역별 지역번호를 나타낸 표이다.표를 참고하여 area_code의 딕셔너리를 코드로 작성해보세요.
#
# |지역|지역번호|
# |:--:|:------:|
# |서울특별시|02|
# |인천광역시|032|
# |대전광역시|042|
# |부산광역시|051|
# |울산광역시|052|
# |대구광역시|053|
# |광주광역시|062|

# %%
#@title 정답

area_code = { '서울특별시' : '02', '인천광역시' :'032','대전광역시' :'042',
              '부산광역시' :'051', '울산광역시' :'052','대구광역시' :'053','광주광역시':'062'}

# %% [markdown]
# ###문제 22
# 아래는 레스토랑 메뉴판이다. 메뉴판대로 menu의 딕셔너리를 코드로 작성해보세요.
#
# |음식|가격(원)|
# |:--:|:--:|
# |Spaghetti|13000|
# |Pizza|18000|
# |Burger|7000|
# |Salad|6000|

# %%
#@title 정답
menu = {
    'Spaghetti': 13000,
    'Pizza': 18000,
    'Burger': 7000,
    'Salad': 6000
}

# %% [markdown]
# ###문제 23
# 아래 표는 쇼핑카트에 담겨진 제품명과 가격이다. 표를 참고하여 cart의 딕셔너리를 코드로 작성해보세요.
#
# |제품명|가격(달러)|
# |:----:|:--------:|
# |T-shirt|10.99|
# |Jeans|29.99|
# |Sneakers|49.99|
# |Watch|79.99|

# %%
#@title 정답
cart = {
    'T-shirt': 10.99,
    'Jeans': 29.99,
    'Sneakers': 49.99,
    'Watch': 79.99
}

# %% [markdown]
# ###문제 24
# 아래 표는 사용자의 개인정보를 나타낸 것이다. 표를 참고하여 user2의 중첩 딕셔너리를 코드로 작성해보세요.
#
# |사용자|아이디|비밀번호|이름|이메일|
# |:----:|:----:|:------:|:--:|:----:|
# |user1|user1|1234|John Doe|john.doe@example.com|
# |user2|user2|5678|Jane Smith|jane.smith@example.com|
#
# ```
# 'user1': {'id': 'user1',
#   'password': '1234',
#   'name': 'John Doe',
#   'email': 'john.doe@example.com'},
#  'user2': {'id': 'user2',
#   'password': '5678',
#   'name': 'Jane Smith',
#   'email': 'jane.smith@example.com'}}
#
# ```

# %%
users = {
    'user1': {
        'id': 'user1',
        'password': '1234',
        'name': 'John Doe',
        'email': 'john.doe@example.com'
    },

}

# %%
#@title 정답
users = {
    'user1': {
        'id': 'user1',
        'password': '1234',
        'name': 'John Doe',
        'email': 'john.doe@example.com'
    },
    'user2': {
        'id': 'user2',
        'password': '5678',
        'name': 'Jane Smith',
        'email': 'jane.smith@example.com'
    }
}

users
# Out:
# {'user1': {'id': 'user1',
#   'password': '1234',
#   'name': 'John Doe',
#   'email': 'john.doe@example.com'},
#  'user2': {'id': 'user2',
#   'password': '5678',
#   'name': 'Jane Smith',
#   'email': 'jane.smith@example.com'}}

# %% [markdown]
# ###문제 25
# 아래 표는 제품별 정보를 나타낸 것이다. 표를 참고하여 product2의 중첩 딕셔너리를 코드로 작성해보세요.
#
# |품목|아이디|이름|가격(달러)|재고|
# |:----:|:----:|:------:|:--:|:----:|
# |product1|product1|Apple iPhone 14|1099|50|
# |product2|product2|Samsung Galaxy S23|999|30|
#
# ```
# {'product1': {'id': 'product1',
#   'name': 'Apple iPhone 14',
#   'price': 1099,
#   'stock': 50},
#  'product2': {'id': 'product2',
#   'name': 'Samsung Galaxy S23',
#   'price': 999,
#   'stock': 30}}
# ```

# %%
products = {
    'product1': {
        'id': 'product1',
        'name': 'Apple iPhone 14',
        'price': 1099,
        'stock': 50
    },

}

# %%
#@title 정답

products = {
    'product1': {
        'id': 'product1',
        'name': 'Apple iPhone 14',
        'price': 1099,
        'stock': 50
    },
    'product2': {
        'id': 'product2',
        'name': 'Samsung Galaxy S23',
        'price': 999,
        'stock': 30
    }
}

products
# Out:
# {'product1': {'id': 'product1',
#   'name': 'Apple iPhone 14',
#   'price': 1099,
#   'stock': 50},
#  'product2': {'id': 'product2',
#   'name': 'Samsung Galaxy S23',
#   'price': 999,
#   'stock': 30}}

# %% [markdown]
# ###문제 26
# 아래 표는 학생별 국어, 영어,수학 점수를 나타낸 것이다. 표를 참고하여 students의 딕셔너리 안에 국어,영어,수학 점수를 리스트화하여 코드를 작성해보세요.
#
# |학생|국어|영어|수학|
# |:----:|:----:|:------:|:--:|
# |Alice|90|100|95|
# |Bob|80|70|90|
# |Charlie|85|80|95|

# %%
#@title 정답
students = {
    'Alice': [90, 100, 95],
    'Bob': [80, 70, 90],
    'Charlie': [85, 80, 95]
}

# %% [markdown]
# ###문제 27
# 아래 표는 영화상영표를 나타낸 것이다. 표를 참고하여 영화별 상영시간을 리스트화하여 movie_schedule의 딕셔너리에 저장해보세요. 단 리스트를 각각의 변수에 할당해 이를 활용하여 딕셔너리를 완성해주세요.
#
# |영화제목|1번째 상영시간|2번째 상영시간|
# |:----:|:----:|:------:|
# |명량|14:00|16:10|
# |신과함께-죄와 벌|16:30|19:00|
# |아바타|18:45|22:00|
# |범죄도시2|21:00|23:40|

# %%
movie_schedule={}

# %%
# @title 정답
movie_schedule = {
    '명량': ['14:00','16:10'],
    '신과함께-죄와 벌': ['16:30','19:00'],
    '아바타': ['18:45','22:00'],
    '범죄도시2': ['21:00','23:40']
}

# %% [markdown]
# ###문제 28
# 아래 표는 학생별 점수표이다. 표를 참고하여 students의 리스트 안에 표를 딕셔너리화하여 저장해보세요.
#
# |이름|점수|
# |:----:|:----:|
# |Alice|90|
# |Bob|85|
# |Charlie|80|

# %%
# @title 정답

students = [
    {'name': 'Alice', 'score': 90},
    {'name': 'Bob', 'score': 85},
    {'name': 'Charlie', 'score': 80}
]

# %% [markdown]
# ###문제 29
# 아래 표는 과일별 가격과 할인율이다. 표를 참고하여 fruits의 리스트 안에 표를 딕셔너리화하여 저장해보세요.
#
# |과일이름|가격|할인율|
# |:----:|:----:|:----:|
# |Apple|1000|0.1|
# |Banana|2000|0.2|
# |Orange|1500|0.15|

# %%
# @title 정답

fruits = [
    {'name': 'Apple', 'price': 1000, 'discount': 0.1},
    {'name': 'Banana', 'price': 2000, 'discount': 0.2},
    {'name': 'Orange', 'price': 1500, 'discount': 0.15}
]

# %% [markdown]
# ###문제 30
# 아래 표는 위시리스트에 있는 제품과 가격을 나타낸 것이다. 표를 참고하여 wishlist의 리스트 안에 표를 딕셔너리화하여 저장해보세요.
#
# |item|price($)|
# |:----:|:----:|
# |Headphones|100|
# |Smartwatch|250|
# |Gaming Mouse|70|
# |Bluetooth Speaker|120|

# %%
# @title 정답

wishlist = [
    {'item': 'Headphones', 'price': 100},
    {'item': 'Smartwatch', 'price': 250},
    {'item': 'Gaming Mouse', 'price': 70},
    {'item': 'Bluetooth Speaker', 'price': 120}
]
