# %% [markdown]
# # 유형 10 : 리스트 정렬하기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
number = [2, 10, 3, 5, 12]

number.sort()
print(number)

# %% [markdown]
# ###문제 02
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
number = [2, 10, 3, 5, 12]

number_sorted = sorted(number)
print(number_sorted)

# %% [markdown]
# ###문제 03
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
number = [12, 5, 3, 7, 10]

number.sort(reverse = False)
print(number)

# %% [markdown]
# ###문제 04
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
number = [12, 5, 3, 7, 10]

number.sort(reverse = True)
print(number)

# %% [markdown]
# ###문제 05
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
number = [10, 23, 5, 46, 75]

number_sorted = sorted(number, reverse=True)
print(number_sorted)

# %% [markdown]
# ###문제 06
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
number = [10, 23, 5, 46, 75]

number_sorted = sorted(number, reverse=False)
print(number_sorted)

# %% [markdown]
# ###문제 07
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero.sort()
hero # 사전식 기준 정렬

# %% [markdown]
# ###문제 08
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero_sorted = sorted(hero)  #reversed(hero)도 가능

print('hero:', hero)
print('sorted:', hero_sorted)

# %% [markdown]
# ###문제 09
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
# sorted(reverse = False) : 정렬과 함께 역순으로 출력
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero_sorted = sorted(hero, reverse = True)  #reversed(hero)도 가능

print('hero:', hero)
print('sorted:', hero_sorted)

# %% [markdown]
# ###문제 10
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
# reverse() : 정렬은 수행되지 않고 리스트의 역순을 출력
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero.reverse()
hero

# %% [markdown]
# ###문제 11
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero[::-1].reverse()
hero
# Out:
# ['토르', '아이언맨', '헐크', '스파이더맨', '캡틴아메리카', '블랙 위도우', '블랙 팬서']

# %% [markdown]
# ###문제 12
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero_revsd = list(reversed(hero))
print(hero_revsd)
# Out:
# ['블랙 팬서', '블랙 위도우', '캡틴아메리카', '스파이더맨', '헐크', '아이언맨', '토르']

# %% [markdown]
# ###문제 13
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
# key = len 길이
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero.sort(key=len)
hero
# Out:
# ['토르', '헐크', '아이언맨', '스파이더맨', '블랙 팬서', '캡틴아메리카', '블랙 위도우']

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
hero = ['토르', '아이언맨', '헐크', '스파이더맨','캡틴아메리카','블랙 위도우','블랙 팬서']

hero.sort(key=len, reverse = True)
hero

# %% [markdown]
# ###문제 15
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
array = [1,2,7,10,20]

mid = len(array) // 2
array.sort()
answer = array[mid]
print(answer)

# %% [markdown]
# ###문제 16
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
array = [1,2,7,10,20]

mid = len(array) // 2
array.sort(reverse = False)
answer = array[mid]
print(answer)

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
array = [149, 190, 182, 170]
height = 167

sorted(array+[height], reverse= True)
# Out:
# [190, 182, 170, 167, 149]

# %% [markdown]
# ###문제 18
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
array = [149, 190, 182, 170]
height = 167

sorted(array+[height], reverse=False).index(height)
# Out:
# 1

# %% [markdown]
# ###문제 19
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
name = ['서연','민수','슬기','창민','지은']
student = '병철'

sorted_list = sorted(name + [student])
class_A = sorted_list[:3]
class_B = sorted_list[3:]

print(class_A)
print(class_B)

# %% [markdown]
# ###문제 20
# 아래 코드를 읽고 출력결과가 무엇일지 맞춰보세요.

# %%
name = ['서연','민수','슬기','창민','지은']
student = '병철'

sorted_list = sorted(name + [student],reverse = True)
class_A = sorted_list[:3]
class_B = sorted_list[3:]

print(class_A)
print(class_B)

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# 주어진 리스트에서 아래와 같은 결과가 나오도록 코드를 작성해보세요.
#
#
#
# ```
# [1, 2, 5, 6, 7]
# ```

# %%
numbers = [5, 2, 8, 1, 6]

# %%
#@title 정답
numbers = [5, 2, 8, 1, 6]
numbers[2] = 7

numbers.sort()
print(numbers)

# %% [markdown]
# ###문제 22
# 주어진 리스트에서 아래와 같이 출력해보세요.
#
#
#
# ```
# [1, 3, 5, 4, 7, 9]
# ```

# %%
numbers = [1, 3, 4, 5, 4, 7, 9]

# %%
#@title 정답
numbers = [1, 3, 4, 5, 4, 7, 9]
numbers.remove(4)

numbers_sorted = sorted(numbers, reverse = True)
print(numbers)

# %% [markdown]
# ###문제 23
# 주어진 리스트에서 sort(reverse = ) 를 사용하여 아래와 같이 출력되도록 작성해보세요.
#
#
#
# ```
# ['Sining', 'Reading', 'Photography', 'Painting', 'Hiking', 'Dancing', 'Cooking']
# ```

# %%
hobbies = ['Reading','Painting','Photography','Cooking','Hiking','Dancing','Sining']

# %%
#@title 정답
hobbies = ['Reading','Painting','Photography','Cooking','Hiking','Dancing','Sining']

hobbies.sort(reverse = True)
print(hobbies)

# %% [markdown]
# ###문제 24

# %% [markdown]
# 다음 리스트는 고객들의 명단입니다. ㄱ,ㄴ,ㄷ 오름차순으로 이름을 다시 정렬해 출력해보세요.

# %%
names = ['김유리','하성수','최다빈','오은서','왕박사','나동근','신금비']

# %%
#@title 정답
names = ['김유리','하성수','최다빈','오은서','왕박사','나동근','신금비']

names_sorted = sorted(names, reverse = False)
print(names_sorted)
# Out:
# ['김유리', '나동근', '신금비', '오은서', '왕박사', '최다빈', '하성수']

# %% [markdown]
# ###문제 25

# %% [markdown]
# 주어진 리스트는 과제를 제출한 순으로 작성된 학생들의 명단이다. 과제를 늦게 제출한 순으로 리스트가 출력될 수 있게끔 reverse()를 사용해 코드를 작성해주세요.
# - 조건 : 오은서, 하성수 제외

# %%
names = ['김유리','하성수','최다빈','오은서','왕박사','나동근','신금비']

# %%
#@title 정답
names = ['김유리','하성수','최다빈','오은서','왕박사','나동근','신금비']

names.remove('오은서')
names.remove('하성수')

names.reverse()
names
# Out:
# ['신금비', '나동근', '왕박사', '최다빈', '김유리']

# %% [markdown]
# ###문제 26
# 주어진 리스트에서 reversed()를 사용하여 아래와 같이 출력해보세요.
#
#
#
# ```
# ['Sining', 'Dancing', 'Cooking', 'Photography', 'Reading']
# ```

# %%
#@title 정답
hobbies = ['Reading','Painting','Photography','Cooking','Hiking','Dancing','Sining']

del hobbies[1]
hobbies.remove('Hiking')

hobbies_reversed = list(reversed(hobbies))
print(hobbies_reversed)
# Out:
# ['Sining', 'Dancing', 'Cooking', 'Photography', 'Reading']

# %% [markdown]
# ###문제 27

# %% [markdown]
# 한 출판사에서 고객들이 책 제목이 길면 책 판매량이 저조한다는 소문을 들었다. 이 소문이 사실인지 확인하기 위해 출판사에서는 책 제목 리스트에서 제목 길이가 가장 긴 것부터 작은것까지 정렬하는 코드를 작성하고자 한다. .sort()를 이용해 코드를 작성해주세요.(단 '이세계로 회귀했던 사건에 대해서' 책은 제외한다)

# %%
book_names = ['공작가','아라비아 궁전','이세계로 회귀했던 사건에 대해서','눈떠보니 공작가의 하인이 되어 남주를 꼬시게 되었다.','행복한 낮잠','밤',
              '어느날 내가 공주가 되었다','공주였던 내가 평행세계의 최고 일진이 되었던 사건에 대해서','달무티','부엉',
              '공주가 되고 싶어 소원을 빌었지만 퇴폐왕자님이 되었던 순간']

# %%
book_names = ['공작가','아라비아 궁전','이세계로 회귀했던 사건에 대해서','눈떠보니 공작가의 하인이 되어 남주를 꼬시게 되었다.','행복한 낮잠','밤',
              '어느날 내가 공주가 되었다','공주였던 내가 평행세계의 최고 일진이 되었던 사건에 대해서','달무티','부엉',
              '공주가 되고 싶어 소원을 빌었지만 퇴폐왕자님이 되었던 순간']

del book_names[2]

book_names.sort(key = len,reverse=True)
book_names
# Out:
# ['공주였던 내가 평행세계의 최고 일진이 되었던 사건에 대해서',
#  '공주가 되고 싶어 소원을 빌었지만 퇴폐왕자님이 되었던 순간',
#  '눈떠보니 공작가의 하인이 되어 남주를 꼬시게 되었다.',
#  '어느날 내가 공주가 되었다',
#  '아라비아 궁전',
#  '행복한 낮잠',
#  '공작가',
#  '달무티',
#  '부엉',
#  '밤']

# %% [markdown]
# ###문제 28
# 주어진 리스트의 중간값을 찾을 수 있도록 코드를 작성해보세요.

# %%
#@title 정답
array = [10,45,14,36,17]

mid = len(array) // 2
array.sort()
answer = array[mid]
print(answer)

# %% [markdown]
# ###문제 29
# 주어진 리스트에 score를 포함하여 score는 몇 번째로 높은 점수인지 확인할 수 있는 코드를 작성해보세요.

# %%
#@title 정답
array = [68, 76, 88, 95]
score = 92

sorted(array+[score], reverse= True).index(score) + 1

# %% [markdown]
# ###문제 30

# %% [markdown]
# 다음과 같이 이름, 점수 리스트가 주어져 있다(ex.김유리 학생은 85점, 오은서 학생은 79 점 ..) rank에 점수가 높은 순으로 이름을 2명만 넣는 코드를 작성해주세요.
# - 새로운 리스트에 score를 역순으로 정렬하기  (sort를 사용할지, sorted를 사용할지 잘 고민해보기)
# - 새로운 리스트 인덱싱, score.index(), name 리스트 인덱싱을 통해 점수가 높은 사람의 이름을 구하기
# - 구해진 이름을 rank리스트에 넣기
#
#
# ```
# 결과값
# ['신주영', '김유리']
# ```

# %%
rank=[]
name= ['김유리','오은서','고라니','하성수','최동구','이동건','신주영']
score=[85,79,15,25,85,46,95]

# %%
#@title 정답
rank=[]
name= ['김유리','오은서','고라니','하성수','최동구','이동건','신주영']
score=[85,79,15,25,85,46,95]
best=sorted(score,reverse=True)
rank.append(name[score.index(best[0])])
rank.append(name[score.index(best[1])])
print(rank)
# Out:
# ['신주영', '김유리']
