# %% [markdown]
# # 알라딘 베스트셀러 정보 크롤링

# %% [markdown]
# ## 1. 알라딘 베스트셀러 1위 도서 책 제목 가져오기

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

bestsales = {'title' : []}

url = f'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0%27'
resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'lxml')
    # 2-1) 태그 파싱
bestsales_tags = soup.select('a.bo3')
    # 2-2) 데이터 파싱
for bestsale in bestsales_tags:
    bestsales['title'].append(bestsale.text)

print(bestsales['title'][0])
# Out:
# 결국 국민이 합니다 : 이재명의 인생과 정치철학

# %%
()
# Out:
# '소년이 온다'

# %% [markdown]
# select의 반환은 리스트다.

# %% [markdown]
# ## 2. 알라딘 베스트셀러 top50 종합 도서 _ 제목, 작가, 가격

# %% [markdown]
# ### 2-1. 종합 top50 도서 _ 제목과 가격 정보만 가져오기
# - 작가 정보가 까다로움

# %%
import requests
from bs4 import BeautifulSoup

# %%
bestsales = {'title' : []}
costs = {'cost': []}
authors = {'author': []}

url = f'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0'
resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'lxml')

bestsales_tags = soup.select('a.bo3')
    # 2-2) 데이터 파싱
for bestsale in bestsales_tags:
    bestsales['title'].append(bestsale.text)
print(bestsales)

cost_tags = soup.select('span.ss_p2')
for cost in cost_tags:
    costs['cost'].append(cost.text)
print(costs)

authors_tags = soup.select('div.ss_book_list a')
for author in authors_tags:
    authors['author'].append(author.text)
print(authors['author'][2::7])
# Out:
# {'title': ['결국 국민이 합니다 : 이재명의 인생과 정치철학', '청춘의 독서 (특별증보판)', '빛과 실', '이재명의 길', '단 한 번의 삶', '소년이 온다', '혼모노', '흔한남매 19', '첫 여름, 완주', '이로운 보수 의로운 진보', '싯다르타 (먼슬리 클래식）', '행동은 불안을 이긴다', '바움가트너', '모순', '파과 (리커버, 영화표지)', '밥을 지어요', '스토너', '2025 제16회 젊은작가상 수상작품집', '백날 지워봐라, 우리가 사라지나', '2025 큰별쌤 최태성의 별★별한국사 기출 500제 한국사능력검정시험 심화 (1, 2, 3급)', '대통령 윤석열 탄핵 사건 선고 결정문', '작별하지 않는다', '40세 정신과 영수증', '초역 부처의 말', '듀얼 브레인', '위버멘쉬', '채식주의자 (리마스터판)', '흔한남매 과학 탐험대 14 : 화학 반응', '2025 큰별쌤 최태성의 별★별한국사 한국사능력검정시험 심화(1, 2, 3급) 하', '2025 큰별쌤 최태성의 별★별한국사 한국사능력검정시험 심화(1, 2, 3급) 상', '내일도 흔들릴 나에게', '과자 사면 과학 드립니다', '급류', 'ETS 토익 정기시험 기출문제집 1000 Vol. 4 Reading (리딩)', '비밀 맛집 크앙 식당 1', '파쇄', '넥서스', '쇼펜하우어 인생수업 (리커버 에디션)', '원펀맨 One Punch Man 32', 'ETS 토익 정기시험 기출문제집 1000 Vol. 4 Listening (리스닝)', '주술회전 29 트리플 특장판', '줬으면 그만이지', '흔한남매의 흔한 호기심 13', '책문, 이 시대가 묻는다', '내 마음의 위험한 녀석 11 (한정판)', '함께 가는 길은 외롭지 않습니다', '나쁜 유적지들', '흔한남매 18', '읽으면서 바로 써먹는 어린이 OX 퀴즈', '부서지는 아이들']}
# {'cost': ['19,800원', '17,010원', '13,500원', '16,200원', '15,120원', '13,500원', '16,200원', '14,220원', '15,300원', '18,000원', '8,100원', '18,000원', '16,020원', '11,700원', '14,220원', '16,020원', '15,120원', '6,930원', '18,900원', '17,550원', '3,510원', '15,120원', '16,200원', '16,020원', '18,900원', '16,020원', '13,500원', '15,120원', '14,400원', '14,850원', '19,800원', '13,500원', '12,600원', '17,820원', '12,150원', '11,700원', '25,020원', '15,750원', '5,400원', '17,820원', '5,400원', '18,000원', '13,500원', '19,800원', '22,500원', '12,600원', '15,120원', '14,220원', '11,700원', '19,800원']}
# ['이재명', '유시민', '한강', '비아북', '김영하', '한강', 'Choice', '흔한남매 19', '45', '무제', '9', '문학동네', '8', '85', '양탄자배송', '양탄자배송', '양탄자배송', '알에이치코리아(RHK)', '백온유', '문학동네', '양소영', '큰별쌤 최태성의 별★별한국사 한국사능력검정시험 시리즈 ', '더휴먼', '한강', '정신과 영수증 ', '양탄자배송', '양탄자배송', '상상스퀘어', '어나니머스', '창비 리마스터 소설선 ', '흔한남매 흔들 키링(2종 중 택1)', '흔한컴퍼니', '양탄자배송', '양탄자배송', '양탄자배송', '양탄자배송', '14', '민음사', 'ETS', '홍그림', '구병모', '김명주', '인생수업 ', '원펀맨 One Punch Man 32', 'ETS 토익 정기시험 기출문제집 ', '아쿠타미 게게', '김주완', '안치현', '양탄자배송', '\r\n화제의 책 + 알라딘 굿즈 (이벤트 도서 포함 국내도서 3만원 이상)', '위즈덤하우스 로고 머그 · 플립 노트 (대상 도서 구매 시)', '나쁜 유적지들', '흔한남매 쟁반 (1권 이상 구매 시)', '미래엔아이세움', '파란정원', '6']

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 2-2. 첫번째 도서의 작가 정보만 가져오기
# - 까다로운 이유 : li태그가 여러개 있다. 그 중 세번째 li태그에 작가정보가 있다.
# - 인덱싱을 이용해 각 묶음의 3번째꺼만 뽑아내보자.

# %%
bbox_tags = soup.select('div.ss_book_box') # 상위 클래스에서 가져옴
print(len(bbox_tags)) # 50개가 맞는지 확인
# Out:
# 50

# %%
for bbox_tag in bbox_tags: # 상위 클래스의 것을 for문으로 순회
    blist_tag = bbox_tag.select('div.ss_book_list')[0] # div에서 첫번째 것에 해당하여 지정
    li_author_tag = blist_tag.select('li')[-3] # ul> li 아래에서 3번째 것 확인하여 지정
    author_tag = li_author_tag.select('a')[0] # li tag에서 작가명은 첫번째 것
    author = author_tag.text #각 작가명 text로 추출
    print(author)
# Out:
# 이재명
# 유시민
# 한강
# 박시백
# 최강욱
# 김영하
# 성해나
# 한강
# 김금희
# 헤르만 헤세
# 흔한남매
# 구병모
# 폴 오스터
# 롭 다이얼
# 양귀자
# 최나현
# 존 윌리엄스
# 최태성
# 백온유
# 김혜경
# 정신
# 코이케 류노스케
# 김태완
# 헌법재판소
# 한강
# 프리드리히 니체
# 한강
# 정윤선
# 이선 몰릭
# 흔한남매
# 최태성
# ETS
# 최태성
# 정대건
# ETS
# 아르투어 쇼펜하우어
# 구병모
# 권태영(탱로그)
# 유발 하라리
# 애비게일 슈라이어
# 김주완
# 남디디
# 박민경
# 안치현
# 망둥어
# ONE
# 아쿠타미 게게
# 김종원
# 이재명
# 한강

# %%
for bbox_tag in bbox_tags: # 상위 클래스의 것을 for문으로 순회
    blist_tag = bbox_tag.select('div.ss_book_list')[0] # div에서 첫번째 것에 해당하여 지정
    li_author_tag = blist_tag.select('li')[-3] # ul> li 아래에서 3번째 것 확인하여 지정
    author_tags = li_author_tag.select('a')[0] # a에 해당하는 자료 전체 추출
    authors = [] # 다중 작가 묶음을 위해 리스트 항목 생성
    for author_tag in author_tags:
        authors.append(author_tag.text)
    author = '|'.join(authors[:1])
print(authors)
# Out:
# ['한강']

# %%
authors = {'author': []}

url = f'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0'
resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'lxml')

authors_tags = soup.select('div.ss_book_list a')
for author in authors_tags:
    authors['author'].append(author.text)
print(authors['author'][2:3])
# Out:
# ['이재명']

# %% [markdown]
# ### 2-3. 모든 도서의 작가 정보만 가져오기
# - 더 까다로운 이유 : div.ss_book_list도 한 블럭에 2개씩 있으며, 어떤 블럭에는 li가 4개, 어떤 블럭에는 5개가 있다.
# - 한번에 select하려고 하지말고, 나눠서 select를 여러번 하자.

# %%
import requests
from bs4 import BeautifulSoup

# %%
aladins = {}

titles = []
costs = []
authors = []

url = f'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0'
resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'lxml')

authors_tags = soup.select('div.ss_book_list a')
for author in authors_tags:
    authors.append(author.text[2:18:7])
print(authors)
# Out:
# ['화  ', ' 다의', '명', '이', '3', '자', ' ', '카', '의별', '민', '지', '', '임 >', ' ', ' ', 'o', '', '과', '', '자', '화  ', '명', '백', '북', '4', '자', ' ', '운운', '욱', '혁', '레', '', '자', '   ', '한', 'o', '하', '서', '', '자', '  상', '노', 'o', '나', '', '', '자', ' ', '  상', '이', 'o', '', '', '9', '자', ' ', '모( ', '여', ' ', 'o', '희', '', '', '자', '화  ', '르 ', '리', '만', '준', '동', '', '남단2', '남', '남', '남', '도', '희', '컴', '엔', '', '자', '  상', ' 영', 'o', '모', '덤', '', '자', ' ', '오(함', '가', '오', '목', '책', '', ' ', '   ', '은긴', '다', '준', '독', '', '자', '  상', '', 'o', '자', '', '5', '자', '화  ', ' 우나', '현', '영', '희', '의', '', '자', '  상', '너', 'o', '윌', '욱', '이H', '6', '자', '본 ', '링머공', '2최별', '쌤별한', '성', '스', '자', ' 2가', '2 수', 'o', '유', '라', '원', '나', '령', '주', '정', '동', '', '자', ' ', ' ', 'o', '경', '사', '', '자', ' ', '증그트', '세수', '과', 'o', '', '이', '선', '기', '', '자', '화  ', ' ', '케', '현', '스', '', '자', ' ', '화  ', ', ', 'o', '완', '의', '', '민화', '령핵 ', '재', '먼', '', '자', ' ', '별>지', '하', 'o', '', '동', '1', '자', ' ', '화  ', '멘', '드', '니', 'S', '3', '자', ' ', '  상', '주스', ' 설', 'o', '', '', '7', '자', ' ', '점', ' 드', 'o', '선', '씨', '', '', '자', '릭 포', ' ', 'o', ' ', '숙', '스', '', '자', ' ', '남링택', '남험 ', '남험', '남', '정', '경', '영', '컴', '수', '철', '목', '아', '어', '', '자', '링머공', '2최별', '쌤별한', '성', '스', '', '자', '링머공', 'S시집', 'S시집', 'S', ')비', '', '자', '링머공', '2최별', '쌤별한', '성', '스', '', '자', '류 급', '', '의 ', 'o', '건', '사', '', '자', ' ', '링머공', 'S시집', 'S시집', 'S', ')비', '', '자', '화  ', '하업에', '수', '투어', '민', '스', '', '자', '덤 립', '', ' ', '모', '덤', '', ' ', '화  ', '식아', '영', '시', '자', ' ', '릭 포', '스', ' ', '주', '사', '', '자', ' ', '   ', '지', '게', '경', '지', '', '자', ' ', '화  ', '면', '완', '파', '', '자', '톡니', '도에', 'o', '디', 't', '', '자', '화  ', ' ', '이1', 'o', '경', '', '', '자', '츠로(', '남호', '남', '현', '남', '희', '모', '컴', '엔', '', '자', ' ', '식', '어', '', '퀘', '스스 ', '맨un', 'E', '타', '씨', '자', '크탠 ', '회리', '타', '운', '미서', '', '자', ' 트 ', '의우 ', '원', 'L', '', '자', '덤 립', ' 외다', '명', '덤', '', ' ', '  상', '에어', '과 ', 'o', '', '과', '3', '자', ' ']

# %%
bestsales = {'title' : []}
costs = {'cost': []}
authors = {'author': []}

url = f'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0'
resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'lxml')

authors_tags = soup.select('div.ss_book_list a')
for author in authors_tags:
    authors['author'].append(author.text)
print(authors['author'][2:18:7])
print(authors['author'][22:32:8])
print(authors['author'][37:50:8])
print(authors['author'][53:57:1])
print(authors['author'][64:65:1])
print(authors['author'][69:71:1])
print(authors['author'][77:79:1])
print(authors['author'][83:85:1])
print(authors['author'][90:92:1])
print(authors['author'][97:115:7])
print(authors['author'][119:121:1])
print(authors['author'][128:135:1])
print(authors['author'][141:144:1])
print(authors['author'][150:160:5])
print(authors['author'][163:164:1])
print(authors['author'][172:175:1])
print(authors['author'][180:182:1])
print(authors['author'][189:191:1])
print(authors['author'][197:199:1])
print(authors['author'][207:208:1])
print(authors['author'][215:224:1])
print(authors['author'][230:255:7])
print(authors['author'][260:270:8])
print(authors['author'][282:283:1])
print(authors['author'][288:290:1])
print(authors['author'][297:299:1])
print(authors['author'][304:306:1])
print(authors['author'][311:312:1])
print(authors['author'][317:319:1])
print(authors['author'][324:325:1])
print(authors['author'][331:336:1])
print(authors['author'][342:343:1])
print(authors['author'][347:349:1])
print(authors['author'][353:354:1])
print(authors['author'][361:362:1])
print(authors['author'][368:372:1])
print(authors['author'][378:379:1])
print(authors['author'][383:385:1])
# Out:
# ['이재명', '유시민', '한강']
# ['박시백', '한겨레출판']
# ['복복서가', '50']
# ['959', '양탄자배송', '보러 가기', '책 모양 보관함 (<첫 여름, 완주> 포함 국내도서 2만원 이상)']
# ['\r\n화제의 책 + 알라딘 굿즈 (이벤트 도서 포함 국내도서 3만원 이상)']
# ['문학동네', '16']
# ['흔한컴퍼니', '미래엔아이세움']
# ['Choice', '구병모']
# ['바움가트너', '폴 오스터']
# ['행동은 불안을 이긴다', '모순', '백날 지워봐라, 우리가 사라지나']
# ['스토너', 'Choice']
# ['2025 큰별쌤 최태성의 별★별한국사 기출 500제 한국사능력검정시험 심화 (1, 2, 3급)', '큰별쌤 최태성의 별★별한국사 한국사능력검정시험 시리즈 ', '최태성', '이투스북', '양탄자배송', '키캡 키링 (2025년 젊은작가상 포함 소설/시 15,000원 이상)', '2025 제16회 젊은작가상 수상작품집']
# ['이희주', '현호정', '문학동네']
# ['김영사', '40세 정신과 영수증']
# ['양탄자배송']
# ['\r\n화제의 책 + 알라딘 굿즈 (이벤트 도서 포함 국내도서 3만원 이상)', '책문, 이 시대가 묻는다', 'Choice']
# ['헌법재판소', '더휴먼']
# ['문학동네', '271']
# ['RISE(떠오름)', '123']
# ['167']
# ['풀빛', '14', '양탄자배송', '패브릭 금박 노트 (대상도서 포함 국내도서 3만원 이상)', '듀얼 브레인', 'Choice', '이선 몰릭', '신동숙', '상상스퀘어']
# ['흔한남매', '김희목', '큰별쌤 최태성의 별★별한국사 한국사능력검정시험 시리즈 ', 'ETS 토익 정기시험 기출문제집 ']
# ['이투스북', '민음사']
# ['아르투어 쇼펜하우어']
# ['파쇄', '위픽 ']
# ['빅피시', '양탄자배송']
# ['김영사', '38']
# ['이수경']
# ['줬으면 그만이지', '김주완']
# ['Choice']
# ['교양이 더 십대 17', 'Choice', '박민경', '다른', '6']
# ['유난희']
# ['양탄자배송', '투명 북마크']
# ['일러스트 종이 코스터 (32권 포함, 만화 분야 1.5만원 이상 구매 시)']
# ['아쿠타미 게게']
# ['김종원', '청림Life', '17', '양탄자배송']
# ['책의 날. NFC 책 키링(대상도서 포함 국내도서 2만 원 이상 구매 시)']
# ['문학과지성사', '103']

# %% [markdown]
# ### 2-4. 종합 top50 모든 도서의 제목, 작가, 가격 정보 csv로 저장하기
# - 가격은 숫자로 변환하여 저장하자.

# %%
import pandas as pd
df_aladin = pd.DataFrame(alradins)
df_aladin.to_csv('aladin_종합50.csv', encording ='utf-8-sig, index=False')

# %%
bestsales = {'title' : []}
costs = {'cost': []}
authors = {'author': []}

url = f'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0'
resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'lxml')

bestsales_tags = soup.select('a.bo3')
    # 2-2) 데이터 파싱
for bestsale in bestsales_tags:
    bestsales['title'].append(bestsale.text)
print(bestsales)

cost_tags = soup.select('span.ss_p2')
for cost in cost_tags:
    costs['cost'].append(cost.text)
print(costs)

authors_tags = soup.select('div.ss_book_list a')
for author in authors_tags:
    authors['author'].append(author.text)
print(authors['author'][2::7])

# %% [markdown]
# ## 3. 알라딘 모든 카테고리 top 50 도서 정보가져오기
# - 페이지 좌측에 있는 카테고리 목록 중 최상위 카테고리 기준으로 각 top 50 도서 가져오기

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = f"https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=53516"

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'lxml')

bbox_tags = soup.select('div.ss_book_box') # 상위 클래스에서 가져옴
print(len(bbox_tags)) # 50개가 맞는지 확인
# Out:
# 50

# %%
aladins = {}
titles, authors, prices = [], [], []

for bbox_tag in bbox_tags:
    blist_tag = bbox_tag.select('div.ss_book_list')[0]

    # 제목
    li_tit_tag = blist_tag.select('li')[-4]
    tit_tag = li_tit_tag.select('a')[0]
    titles.append(tit_tag.text)

    # 작가
    li_aut_tag = blist_tag.select('li')[-3]
    aut_tags = li_aut_tag.select('a')[:-1]
    author = []
    for aut_tag in aut_tags:
        author.append(aut_tag.text)
    author = '|'.join(author)
    authors.append(author)

    # 가격
    li_prc_tag = blist_tag.select('li')[-2]
    prc_tag = li_prc_tag.select('em')[0]
    prices.append(int(prc_tag.text[:-1].replace(',', '')))
prices
# Out:
# [17100,
#  20700,
#  39600,
#  16020,
#  22500,
#  34200,
#  17820,
#  26600,
#  31350,
#  26100,
#  22500,
#  15750,
#  22500,
#  25200,
#  14400,
#  14400,
#  14400,
#  12600,
#  13500,
#  22500,
#  39600,
#  22500,
#  18000,
#  43200,
#  35000,
#  15120,
#  14400,
#  16200,
#  24300,
#  20000,
#  23750,
#  12600,
#  12600,
#  25000,
#  20000,
#  18000,
#  10800,
#  29450,
#  25200,
#  15030,
#  17910,
#  27550,
#  16200,
#  36000,
#  15300,
#  22500,
#  22500,
#  14400,
#  30400,
#  22500]

# %%
aladins['제목'] = titles
aladins['작가'] = authors
aladins['가격'] = prices

# %%
import pandas as pd
df_aladin = pd.DataFrame(aladins)
df_aladin
# Out:
#                                 제목                                 작가     가격
# 0                     80대20 러닝 훈련법                        맷 피츠제럴드|최보배  17100
# 1                 스포츠의학으로 읽는 발의 과학                            손성준|이재훈  20700
# 2              호주물리치료사의 13가지 체형교정법                         라이프에이드 연구소  39600
# 3         마음이 요동칠 때, 기꺼이 나는 혼자가 된다                                김지호  16020
# 4               스포츠의학이 쉬워지는 해부학 도감              우에하라 다케시|이진원|이시이 나오카타  22500
# 5              그림으로 요가하자 : 아사나 600                                오연진  34200
# 6        매일매일 암과 멀어지는 힐링 푸드, 근력 운동                                오유경  17820
# 7                           요가 디피카                    B. K. S. 아헹가|현천  26600
# 8                그림으로 요가하자 : 궁금해요가                                오연진  31350
# 9                            운동 독립                                구현경  26100
# 10                        스트레칭의 과학                          리다 말렉|권기호  22500
# 11                   생존근육 3가지만 키워라                                이상모  15750
# 12                          요가의 과학                          앤 스완슨|권기호  22500
# 13  데스런 + 석가, 근육의 생김새를 알면 운동이 쉬워진다                            조성준|석정현  25200
# 14                       달리기의 모든 것                                남혁우  14400
# 15                      30일 5분 달리기                                김성우  14400
# 16                      초보자를 위한 단학                                윤홍식  14400
# 17                           요가 말라              스리 K. 파타비 조이스|김소연|이승은  12600
# 18                      요가와 명상 건강법                          딘 오니시|장현갑  13500
# 19                       맨발걷기 바로하기                                권오룡  22500
# 20           근막경선 실전 응용 10가지 체형교정법                    장원석|전하윤|이동률|이승훈  39600
# 21                        60초 스트레칭                           오픽스(오민규)  22500
# 22                         움직임의 법칙                      운동하는 데이브(최충식)  18000
# 23        요가 인문학 + 요가 해부학 세트 - 전2권                            이정수|이동환  43200
# 24                          요가아나토미        Stu Girling|Bug Fawcett|서하린  35000
# 25                       상체 밸런스 리셋                       네고로 히데유키|이지현  15120
# 26       뻣뻣한 몸이 빠르게 유연해지는 12초 스트레칭                       무라야마 다쿠미|문혜원  14400
# 27      파리지엔의 특별한 코어 운동 프랑스 발레 바오솔                            가나미|이은혜  16200
# 28                         인요가 가이드                       버니 클락|이상희|지문  24300
# 29                         키즈 필라테스                            노수연|오정하  20000
# 30                       필라테스 아나토미  라엘 아이자코비츠|캐런 클리핑어|오재근|최세환|이지혜|한유창  23750
# 31                     1일 20분 셀프PT                                이용현  12600
# 32                   Ageless 에이지레스                 샤랏 조이스|이샤 싱 소흐니|유신  12600
# 33                            소마틱스                         토마스 한나|최광석  25000
# 34                      요가해부학 컬러링북                        켈리 솔로웨이|최우석  20000
# 35                    윤홍식의 용호비결 강의                             정렴|윤홍식  18000
# 36                     소피아의 임산부 요가                                박서희  10800
# 37                아사나 쁘라나야마 무드라 반다                    스와미 싸띠아난다 사라스와띠  29450
# 38                  요가 수트라 - 원전 주해                                박지명  25200
# 39                탁상용 스트레칭북 (스프링북)                 브레이니 피트니스 랩|피지컬갤러리  15030
# 40                         초관절 자세력                                윤제필  17910
# 41               엘리 허먼의 필라테스 운다 체어                    엘리 허먼|수지 메이|조미영  27550
# 42                      운동의 진실과 기쁨                                강윤규  16200
# 43                  소메틱 재활소도구 필라테스                                김혜진  36000
# 44                 걷기가 노화 속도를 결정한다                    이가세 미치야|장지현|정순영  15300
# 45                          바레 교과서                            이가람|홍정기  22500
# 46                      움직임을 통한 자각                  하바 셸하브|김득란|달리아 골롬  22500
# 47                3가지 체액이 내 몸을 살린다                       가타히라 에츠코|박정임  14400
# 48                         요가 아나토미       레슬리 카미노프|에이미 매튜스|한유창|이종하|오재근  30400
# 49                    나를 위한 아쉬탕가요가                                김경석  22500

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = f"https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=1196"

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'lxml')

bbox_tags = soup.select('div.ss_book_box')
print(len(bbox_tags))
# Out:
# 50

# %%
aladins = {}
titles, authors, prices = [], [], []

for bbox_tag in bbox_tags:
    blist_tag = bbox_tag.select('div.ss_book_list')[0]

    #제목
    li_tit_tag = blist_tag.select('li')[-4]
    tit_tag = li_tit_tag.select('a')[0]
    titles.append(tit_tag.text)

    #작가
    li_aut_tag = blist_tag.select('li')[-3]
    aut_tags = li_aut_tag.select('a')[:-1]
    author = []
    for aut_tag in aut_tags:
        author.append(aut_tag.text)
    author = '|'.join(author)
    authors.append(author)

    #가격
    li_prc_tag = blist_tag.select('li')[-2]
    prc_tag = li_prc_tag.select('em')[0]
    prices.append(int(prc_tag.text[:-1].replace(',', '')))
print(prices)
# Out:
# [16200, 16200, 21420, 3920, 4500, 15120, 16200, 22320, 19800, 4500, 4320, 15750, 17820, 17820, 17820, 18900, 18900, 19800, 17820, 16020, 18000, 16200, 17100, 18000, 18900, 17820, 4320, 18000, 19800, 27000, 16920, 19800, 17100, 17820, 18000, 19800, 21600, 17820, 18900, 22500, 15750, 18000, 17100, 21420, 17820, 14850, 20700, 16200, 19800, 15300]

# %%
aladins['순위'] = [f"{i+1}위" for i in range(len(titles))]
aladins['제목'] = titles
aladins['작가'] = authors
aladins['가격'] = prices

# %%
import pandas as pd
df_aladin = pd.DataFrame(aladins)
df_aladin
# Out:
#                                  제목  \
# 0                      일본 현지 반찬 대백과
# 1                             줍는 순간
# 2                         버터밀크 그래피티
# 3                   일본에서 한 달을 산다는 것
# 4                              교토커피
# 5                    여행의 이유 (개정증보판)
# 6            일본 명물 간식 백과 : 과자·디저트 편
# 7            일상이 고고학, 나 혼자 서울 사찰 여행
# 8         디스 이즈 이탈리아 This is Italia
# 9                  어느 중년의 일상 탈출 고백서
# 10                            유럽 예약
# 11                          한 달의 고베
# 12                      우리가 반짝이는 계절
# 13           디스 이즈 도쿄 This Is Tokyo
# 14          디스 이즈 오사카 This Is Osaka
# 15          디스 이즈 스페인 This is Spain
# 16                          리얼 이탈리아
# 17            걷는 이의 축복 코리아둘레길 : 입문편
# 18       에이든 우리나라 전국 여행지도 2025-2026
# 19                         결혼보다 시코쿠
# 20                     죽기 전엔 가보고 싶어
# 21                      홋카이도 셀프 트래블
# 22      리얼 오키나와 : 미야코 케라마 2025~2026
# 23           디스 이즈 파리 This is PARIS
# 24         디스 이즈 타이완 This Is Taiwan
# 25                         도쿄 호텔 도감
# 26                     잘할 거예요, 어디서든
# 27                    이탈리아 수도원 기행 1
# 28  디스 이즈 미국 동부 This Is Eastern USA
# 29                          트레킹의 원리
# 30                       오사카 디저트 여행
# 31                          리얼 국내여행
# 32            무작정 따라하기 오사카·교토·고베·나라
# 33                      무작정 따라하기 도쿄
# 34                 리얼 스페인 2025~2026
# 35                           프렌즈 뉴욕
# 36                에이든 아이와 국내여행 가이드북
# 37      디스 이즈 홋카이도 This is Hokkaido
# 38                            리얼 뉴욕
# 39                             홍콩백끼
# 40           프렌즈 후쿠오카 : 유후인.벳부.키타큐슈
# 41                          리얼 포르투갈
# 42                     대만 현지 쇼핑 대백과
# 43                    프랑스, 예술로 여행하기
# 44     디스 이즈 싱가포르 This Is Singapore
# 45                            기후여행자
# 46  디스 이즈 미국 서부 This Is Western USA
# 47                  일본 현지 맛집 체인 대백과
# 48   에이든 인스타 핫플 국내여행 가이드북 2025-2026
# 49                         프렌즈 오키나와
#
#                                                    작가     가격   순위
# 0                                        스가와라 요시미|김정원  16200   1위
# 1                                                 안희연  16200   2위
# 2                                          에드워드 리|박아람  21420   3위
# 3   양영은|김민주|김일숙|임지현|한정규|전지혜|이다슬|박장희|이채안|최정은|우소연|손경...   3920   4위
# 4                                                 심재범   4500   5위
# 5                                                 김영하  15120   6위
# 6                                      여행과 철도 편집부|김나랑  16200   7위
# 7                                                  황윤  22320   8위
# 8                                         전혜진|윤도영|박기남  19800   9위
# 9                                        하이디 엘리어슨|이길태   4500  10위
# 10                                               청춘유리   4320  11위
# 11                                                한예리  15750  12위
# 12                                                장류진  17820  13위
# 13                                            박설희|김민정  17820  14위
# 14                                                호밀씨  17820  15위
# 15                                                전혜진  18900  16위
# 16                                            양미석|김혜지  18900  17위
# 17                                            이화규|이세원  19800  18위
# 18                                      타블라라사 편집부|이정기  17820  19위
# 19                                             김환|김자람  16020  20위
# 20                                                진민성  18000  21위
# 21                                                신연수  16200  22위
# 22                                                전명윤  17100  23위
# 23                                김민준|박영희|윤유림|임현승|정희태  18000  24위
# 24                                                신서희  18900  25위
# 25                                          엔도 케이|서하나  17820  26위
# 26                                           멍작가(강지명)   4320  27위
# 27                                                이관술  18000  28위
# 28                                            제이민|진혜은  19800  29위
# 29                                            이환종|조태봉  27000  30위
# 30                                                김소정  16920  31위
# 31                                                배나영  19800  32위
# 32                                            오원호|정숙영  17100  33위
# 33                                                정숙영  17820  34위
# 34                                                성혜선  18000  35위
# 35                                                이주은  19800  36위
# 36                                      타블라라사 편집부|이정기  21600  37위
# 37                                            권예나|김민정  17820  38위
# 38                                                맹지나  18900  39위
# 39                                            손민호|백종현  22500  40위
# 40                                          정꽃나래|정꽃보라  15750  41위
# 41                                                우지경  18000  42위
# 42                                        오가와 지에코|김정원  17100  43위
# 43                                                함혜리  21420  44위
# 44                                                이광훈  17820  45위
# 45                                                임영신  14850  46위
# 46                                            제이민|민고은  20700  47위
# 47                             일본 추억의 대백과 시리즈 편집부|김정원  16200  48위
# 48                                      타블라라사 편집부|이정기  19800  49위
# 49                                                이주영  15300  50위

# %%
df_aladin.to_excel("aladin_여행 베스트셀러.xlsx", index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 여러 카테고리 페이지 url 가져오기
# - 해당 url을 href 속성으로 갖고 있는 a_tag들을 먼저 가져오자
# - a_tag에서 href 속성을 파싱하자

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 한가지 더 주의할 점
#     - href가 full_url이 아님(리소스경로+쿼리스트링 뿐)
#     - 이유 : 내부 이동이므로 (프로토콜 + 주소값 생략)
#     - 대처 : 프로토콜 + 주소값은 따로 가져오기

# %%
urls = {}

url = f'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0'

# %% [markdown]
# #### 저장된 url 리스트를 이용하여 반복 시행

# %% [markdown]
# ## 4. 알라딘 도서 섬네일 가져오기

# %% [markdown]
# #### 이미지 크롤링의 이해
# html 안에 이미지는 없다. 이미지의 src만 있을 뿐.
#
# - 1단계 : 섬네일 이미지 태그에서 img src 가져오기
# - 2단계 : 이미지 src에 requests get하여 img 가져오기

# %% [markdown]
# #### 4-1) 하나의 도서를 정하여 해당 도서의 섬네일 이미지 저장하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&start=we"

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'lxml')

img_tags = soup.select('img.front_cover')

# %%
len(img_tags)
#print(img_tags)
img_tags
# Out:
# [<img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36209/99/cover200/899778062x_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36286/32/cover200/s372039570_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36292/22/cover200/8932043566_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36292/90/cover200/k502038145_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36101/66/cover200/893643974x_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36114/12/cover200/s602038067_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36159/64/cover200/k012038787_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36275/58/cover200/k692038832_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/4086/97/cover200/8936434128_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/6157/39/cover200/k222433722_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/2584/37/cover200/8998441012_3.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36208/50/cover200/k712038303_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36236/28/cover200/8932925046_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/35408/5/cover200/k912035329_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36196/71/cover200/k362038594_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36386/32/cover200/k872039670_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36167/43/cover200/k292038190_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36127/91/cover200/k632038378_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36143/59/cover200/k742038673_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36348/53/cover200/k292039966_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/5100/19/cover200/8925554992_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36303/64/cover200/k592038346_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/33973/70/cover200/k682930444_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/35873/90/cover200/k762037781_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/35902/54/cover200/k962037084_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36254/57/cover200/k372038526_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/27877/5/cover200/8954682154_3.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36304/48/cover200/k542038448_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/33010/94/cover200/8917239501_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/29137/2/cover200/8936434594_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/35398/19/cover200/k842035019_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/35398/17/cover200/k432035019_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/30769/24/cover200/8937473402_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36373/83/cover200/k472039475_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36185/11/cover200/k592038492_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36215/39/cover200/k562038627_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/33464/3/cover200/k082938849_3.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/33010/92/cover200/8917239498_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36281/48/cover200/8901294699_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/17048/25/cover200/8932473900_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/35809/29/cover200/k572036659_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/31273/29/cover200/k592832565_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36202/24/cover200/k462038693_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/34917/23/cover200/k022933254_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36374/35/cover200/k512039477_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36387/35/cover200/k172039674_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36224/77/cover200/k562038604_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/30727/3/cover200/k592830441_1.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/36144/16/cover200/k852038674_2.jpg"/>,
#  <img class="front_cover i_cover" src="https://image.aladin.co.kr/product/35323/86/cover200/k242035376_1.jpg"/>]

# %%
srcs = []
for i in range(len(img_tags)):
    img_src = img_tags[i]
    srcs.append(img_src['src'])
# print(srcs)
for s in range(len(srcs)):
    resp = requests.get(srcs[s])

# %%
with open (f"/content/img_tag{s:02}.jpg", 'wb') as f:
    f.write(resp.content)

# %% [markdown]
# 새폴더 만들기

# %%
# !mkdir content

# %% [markdown]
# #### 4-2) 종합 top50 페이지의 섬네일 이미지 저장하기
#
# - 종합_top50이라는 폴더에 저장

# %% [markdown]
# #### 4-3) 모든 카테고리의 모든 도서 섬네일 이미지 저장하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&start=we"

resp = requests.get(url)
resp
# Out:
# 0

# %%
bbox_categorys = soup.select('best_left') # 상위 클래스에서 가져옴
print(len(bbox_categorys))
#len(img_tags)
#print(img_tags)
#img_tags
# Out:
# 0
