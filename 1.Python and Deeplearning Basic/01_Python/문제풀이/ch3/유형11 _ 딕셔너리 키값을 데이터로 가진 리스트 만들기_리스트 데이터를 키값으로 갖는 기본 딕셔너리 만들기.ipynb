# %% [markdown]
# # 유형 11 : 딕셔너리 키를 리스트로/리스트를 딕셔너리 키로 만들기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
# 아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'a': 0 , 'b': 1, 'c': 2, 'd':3}
result = list(dataset)
print(result)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ###문제 02
# 아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'이름': '손흥민', '나이': 32, '국적': '대한민국'}
result = list(dataset)
print(result)

# %% [markdown]
# ###문제03
# 아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'apple': 5, 'banana': 2, 'kiwi': 2}
result = list(dataset)
print(result)

# %% [markdown]
# ###문제 04
# 아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'서울': '경복궁', '뉴욕': '자유의 여신상', '파리': '에펠탑'}
result = list(dataset)
print(result)

# %% [markdown]
# ###문제 05
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
label2idx = {'cat': 0, 'dog': 1}
label = list(label2idx)
print(label)

# %% [markdown]
# ###문제 06
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
data = ['cat', 'dog']
result = dict.fromkeys(data)
result
# Out:
# {'cat': None, 'dog': None}

# %% [markdown]
# ###문제 07
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
data = ['cat','dog']
result = dict.fromkeys(data, 0)
print(result)
# Out:
# {'cat': 0, 'dog': 0}

# %% [markdown]
# ###문제 08
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
keys =['apple', 'banana', 'kiwi']
value = 3

result = dict.fromkeys(keys,value)
print(result)
# Out:
# {'apple': 3, 'banana': 3, 'kiwi': 3}

# %% [markdown]
# ###문제 09
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
keys = ['라이언', '어피치','프로도','네오','무지','콘','튜브','제이지']
value = 'default'
result  = dict.fromkeys(keys, value)
result
# Out:
# {'라이언': 'default',
#  '어피치': 'default',
#  '프로도': 'default',
#  '네오': 'default',
#  '무지': 'default',
#  '콘': 'default',
#  '튜브': 'default',
#  '제이지': 'default'}

# %% [markdown]
# ###문제 10
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
keys = ['airplane', 'bus', 'car']
value = []
result = dict.fromkeys(keys, value)
print(result)
# Out:
# {'airplane': [], 'bus': [], 'car': []}

# %% [markdown]
# ###문제 11
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {'아메리카노': 3500, '카푸치노': 4000, '카페라떼': 4500, '카페모카': 5000}
menu = list(dataset)
result = dict.fromkeys(menu)
print(result)
# Out:
# {'아메리카노': None, '카푸치노': None, '카페라떼': None, '카페모카': None}

# %% [markdown]
# ###문제 12
# 아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
letter2index = {'zero': 0, 'one': 1, 'two': 2, 'three': 3, 'four': 4,
                'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9}
num = list(letter2index)
result = dict.fromkeys(num, True)
print(result)
# Out:
# {'zero': True, 'one': True, 'two': True, 'three': True, 'four': True, 'five': True, 'six': True, 'seven': True, 'eight': True, 'nine': True}

# %% [markdown]
# ###문제 13
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
kor2eng = {
    '1월' : 'January','2월' : 'February','3월' : 'March','4월' : 'April','5월' : 'May','6월' : 'June',
    '7월' : 'July','8월' : 'August','9월' : 'September','10월' : 'October','11월' : 'November','12월' : 'December'}

months = list(kor2eng)
result = dict.fromkeys(months, '')
print(result)
# Out:
# {'1월': '', '2월': '', '3월': '', '4월': '', '5월': '', '6월': '', '7월': '', '8월': '', '9월': '', '10월': '', '11월': '', '12월': ''}

# %% [markdown]
# ###문제 14
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = { '일상': 'daily','개그': 'comic','판타지': 'fantasy','액션': 'action','드라마': 'drama',
           '순정': 'pure','감성': 'sensibility','스릴러': 'thrill','무협/사극': 'historical','스포츠': 'sports'}

genres = list(dataset)
num = 0
result = dict.fromkeys(genres, num)
print(result)

# %% [markdown]
# ###문제 15
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {
    'data1': ['/path/to/data1.csv', '/path/to/data1.txt'],
    'data2': ['/path/to/data2.csv', '/path/to/data2.txt']
}

keys = list(dataset)
values = dataset['data1'], dataset['data2']

result = dict.fromkeys(keys, values)
print(result)
# Out:
# {'data1': (['/path/to/data1.csv', '/path/to/data1.txt'], ['/path/to/data2.csv', '/path/to/data2.txt']), 'data2': (['/path/to/data1.csv', '/path/to/data1.txt'], ['/path/to/data2.csv', '/path/to/data2.txt'])}

# %% [markdown]
# ###문제 16
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {
    'airplane': ['/content/natural_images/airplane/airplane_0698.jpg',
                 '/content/natural_images/airplane/airplane_0563.jpg'],
    'car': ['/content/natural_images/car/car_0814.jpg',
            '/content/natural_images/car/car_0800.jpg'],
    'dog': ['/content/natural_images/dog/dog_0431.jpg',
            '/content/natural_images/dog/dog_0253.jpg']
}

labels = list(dataset)
paths = dataset['airplane'], dataset['car'],dataset['dog']
result = dict(zip(labels,paths))
print(result)
# Out:
# {'airplane': ['/content/natural_images/airplane/airplane_0698.jpg', '/content/natural_images/airplane/airplane_0563.jpg'], 'car': ['/content/natural_images/car/car_0814.jpg', '/content/natural_images/car/car_0800.jpg'], 'dog': ['/content/natural_images/dog/dog_0431.jpg', '/content/natural_images/dog/dog_0253.jpg']}

# %% [markdown]
# ###문제 17

# %% [markdown]
# 아래 코드를 읽고 image_dict의 출력결과가 무엇일지 맞춰보세요.

# %%
image_1=['/content/natural_images/airplane/airplane_0698.jpg']
image_2=['/content/natural_images/car/car_0814.jpg']
image_3=['/content/natural_images/dog/dog_0253.jpg']

keys=[]
keys.append(image_1[0].split('/')[-2])
keys.append(image_2[0].split('/')[-2])
keys.append(image_3[0].split('/')[-2])

values=[image_1,image_2,image_3]
image_dict=dict(zip(keys,values))

image_dict
# Out:
# {'airplane': ['/content/natural_images/airplane/airplane_0698.jpg'],
#  'car': ['/content/natural_images/car/car_0814.jpg'],
#  'dog': ['/content/natural_images/dog/dog_0253.jpg']}

# %% [markdown]
# ###문제 18
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = [
    {'name': 'Apple iPhone 14', 'price': 1500000, 'stock': 50},
    {'name': 'Samsung Galaxy S23', 'price': 1450000, 'discount': 30}
]

new_data = list(dataset[1])
result = dict.fromkeys(new_data)
print(result)

# %% [markdown]
# ###문제 19
#  아래 코드를 읽고 dataset의 출력결과가 무엇일지 맞춰보세요.

# %%
dataset = {
    'Seoul': {
        'latitude': 37.5665,
        'longitude': 126.9780
    },
    'New York': {
        'latitude': 40.7128,
        'longitude': -74.0060
    },
    'Paris': {
        'latitude': 48.8566,
        'longitude': 2.3522
    }
}
data = list(dataset)
values=[{'Fine dust':'Bad'},{'Fine dust':'Good'},{'Fine dust':'Bad'}]
result = dict(zip(data,values))
dataset['Seoul'].update(result['Seoul'])
dataset['New York'].update(result['New York'])
dataset['Paris'].update(result['Paris'])

dataset
# Out:
# {'Seoul': {'latitude': 37.5665, 'longitude': 126.978, 'Fine dust': 'Bad'},
#  'New York': {'latitude': 40.7128, 'longitude': -74.006, 'Fine dust': 'Good'},
#  'Paris': {'latitude': 48.8566, 'longitude': 2.3522, 'Fine dust': 'Bad'}}

# %% [markdown]
# ###문제 20

# %% [markdown]
# 아래 코드를 읽고 Sword의 pirce, damage, weight 값이 각각 얼마가 될 것인지 맞춰보세요.

# %%
dataset = {
    'Sword': {'price': 100, 'damage': 20, 'weight': 5},
    'Shield': {'price': 50, 'defense': 15, 'weight': 10},
    'Potion': {'price': 30, 'healing': 10, 'weight': 1}
}

data = dataset['Shield']
num = [200, 100, 500]
result = dict(zip(data.keys(), num))
dataset['Sword']=result
print(dataset)

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
#  city_country의 key값만 추출하여 city 리스트에 저장해보세요.

# %%
city_country = {'Seoul' : 'Korea', 'New York' : 'USA' , 'Paris' :'France'}

# %%
#@title 정답
city_country = {'Seoul' : 'Korea', 'New York' : 'USA' , 'Paris' :'France'}

city = list(city_country)
print(city)

# %% [markdown]
# ###문제 22
#  주어진 딕셔너리의 키 값을 리스트로 할당해보세요.

# %%
dataset = {'hamburger': 3800, 'cheeseburger': 4500, 'french fries': 2100}

# %%
#@title 정답
dataset = {'hamburger': 3800, 'cheeseburger': 4500, 'french fries': 2100}
menu = list(dataset)
print(menu)

# %% [markdown]
# ###문제 23
#  주어진 딕셔너리를 활용하여 아래와 같은 결과가 출력되도록 코드를 작성해보세요.
#
#
# ```
# {'서울특별시': None, '인천광역시': None, '대전광역시': None, '부산광역시': None, '울산광역시': None, '대구광역시': None, '광주광역시': None}
# ```

# %%
area_code = { '서울특별시' : '02', '인천광역시' :'032','대전광역시' :'042',
              '부산광역시' :'051', '울산광역시' :'052','대구광역시' :'053','광주광역시':'062'}

# %%
#@title 정답
area_code = { '서울특별시' : '02', '인천광역시' :'032','대전광역시' :'042',
              '부산광역시' :'051', '울산광역시' :'052','대구광역시' :'053','광주광역시':'062'}

area = list(area_code)
result = dict.fromkeys(area)
print(result)

# %% [markdown]
# ###문제 24
#  주어진 딕셔너리를 활용하여 아래와 같은 결과를 출력보세요.
#
#
#
# ```
# {'green': 0, 'blue': 0, 'pink': 0}
# ```

# %%
dataset = {'green': '#00FF00', 'blue': '#0000FF', 'pink': 'FFC0CB'}

# %%
#@title 정답
dataset = {'green': '#00FF00', 'blue': '#0000FF', 'pink': 'FFC0CB'}
colors = list(dataset)

result = dict.fromkeys(colors, 0 )
print(result)

# %% [markdown]
# ###문제 25
#  주어진 리스트를 정렬하여 리스트의 원소가 딕셔너리의 키 값이 되도록 코드를 작성해보세요.

# %%
hero = ['토르', '아이언맨', '헐크', '캡틴아메리카']

# %%
#@title 정답
hero = ['토르', '아이언맨', '헐크', '캡틴아메리카']
hero.sort()

result = dict.fromkeys(hero)
print(result)

# %% [markdown]
# ###문제 26
#  주어진 data 리스트에서 'date'를 삭제하고 data 리스트의 요소를 키, num 리스트의 요소를 값으로 하는 딕셔너리를 생성해보세요.

# %%
data = ['apple', 'banana', 'cherry', 'date', 'elderberry']

# %%
#@title 정답
data = ['apple', 'banana', 'cherry', 'date', 'elderberry']
num = [5, 3, 4, 2]

del data[3]
dataset = dict(zip(data, num))
print(dataset)

# %% [markdown]
# ###문제 27
#  주어진 딕셔너리에서 아래와 같이 출력해보세요.
#
# ```
# {'가디언즈 오브 갤럭시': '15:30', '블랙 팬서': [], '어벤져스: 엔드게임': [], '스파이더맨: 노 웨이 홈': []}
# ```

# %%
movie_schedule = {
    '가디언즈 오브 갤럭시': '14:00',
    '블랙 팬서': '16:30',
    '어벤져스: 엔드게임': '18:45',
    '스파이더맨: 노 웨이 홈': '21:00'
}

# %%
#@title 정답
movie_schedule = {
    '가디언즈 오브 갤럭시': '14:00',
    '블랙 팬서': '16:30',
    '어벤져스: 엔드게임': '18:45',
    '스파이더맨: 노 웨이 홈': '21:00'
}

titles = list(movie_schedule)
dataset = dict.fromkeys(titles, [])

dataset['가디언즈 오브 갤럭시'] = '15:30'
print(dataset)

# %% [markdown]
# ###문제 28
#  주어진 문자열에서 아래와 같은 결과가 나오도록 코드를 작성해보세요.
#
#
# ```
# {'name': 'Pasta', 'type': None, 'rating': None, 'topping': None, 'price': 18000}
# ```

# %%
food_dict = {
    'name': 'Pizza',
    'type': 'Italian cuisine',
    'rating': 4.8,
    'topping': ['pepperoni', 'mushrooms', 'cheese'],
    'price': 12.99
}

# %%
#@title 정답
food_dict = {
    'name': 'Pizza',
    'type': 'Italian cuisine',
    'rating': 4.8,
    'topping': ['pepperoni', 'mushrooms', 'cheese'],
    'price': 12.99
}

data = list(food_dict)
dataset = dict.fromkeys(data)

dataset.update({'name' : 'Pasta', 'price': 18000} )
print(dataset)
# Out:
# {'name': None, 'type': None, 'rating': None, 'topping': None, 'price': None}
# {'name': 'Pasta', 'type': None, 'rating': None, 'topping': None, 'price': 18000}

# %% [markdown]
# ###문제 29
#  주어진 딕셔너리내에서 'style','item'의 키를 삭제하고, 마지막 키-값 쌍을 제거하고 난 뒤 아래와 같은 결과를 출력해보세요.
#
#
#
# ```
# {'brand': 'New balance', 'colors': 'Gray'}
# ```

# %%
dataset = {
    'item': 'Sneakers',
    'brand': 'Nike',
    'style': 'Athletic',
    'colors': ['Black', 'White', 'Red'],
    'price': 129000
}

# %%
#@title 정답
dataset = {
    'item': 'Sneakers',
    'brand': 'Nike',
    'style': 'Athletic',
    'colors': ['Black', 'White', 'Red'],
    'price': 129000
}

del dataset['style']
del dataset['item']
dataset.popitem()

keys = list(dataset)
values = ['New balance' , 'Gray']

new_dataset = dict(zip(keys,values))
new_dataset

# %% [markdown]
# ###문제 30

# %% [markdown]
# 최근 범죄도시4가 나온다는 소식에 영화관에서는 범죄도시 시리즈를 상영한다고 한다.
#
#  알바생 유리는 범죄도시1,2 현황정보는 알고 있었지만, 범죄도시3  정보와 기록 형식을 movie_info에서 새로 확인해야한다.
#  유리는 범죄도시3이 크게 흥행을 하며 티겟요금을 14000원으로 인상한다는 기사를 확인하고  movie_info의 범죄도시3 정보를 수정해 새로운 범죄도시 info판을 만들고자 한다.
#  movie_info 형식과 위 상황에 맞게 info 판이 새로 만들어질 수 있도록 코드를 작성해보세요.
#
# ```
# 결과값
# info = {
#     '범죄도시1': {'잔여석': 10, '티켓요금': 9000},
#     '범죄도시2': {'잔여석': 20, '티켓요금': 9000},
#     '범죄도시3': {'잔여석': 2, '티켓요금': 14000}}
# ```

# %%
movie_info = {
    '가디언즈 오브 갤럭시: Volume3': {'잔여석': 5, '티켓요금': 11000},
    '인어공주': {'잔여석': 7, '티켓요금': 11000},
    '분노의 질주: 라이드 오어 다이': {'잔여석': 3, '티켓요금': 11000},
    '범죄도시3': {'잔여석': 1, '티켓요금': 11000}
}

# 기록 형식 알아내는 코드
data = movie_info['범죄도시3']
num = [[],[]]
result1 = dict(zip(data.keys(), num))
result1
# Out:
# {'잔여석': [], '티켓요금': []}

# %%
#@title 정답
movie_info = {
    '가디언즈 오브 갤럭시: Volume3': {'잔여석': 5, '티켓요금': 11000},
    '인어공주': {'잔여석': 7, '티켓요금': 11000},
    '분노의 질주: 라이드 오어 다이': {'잔여석': 3, '티켓요금': 11000},
    '범죄도시3': {'잔여석': 1, '티켓요금': 11000}
}

key=['범죄도시1','범죄도시2','범죄도시3']
data = movie_info['범죄도시3']
num = [10, 9000]
result1 = dict(zip(data.keys(), num))
num = [20, 9000]
result2 = dict(zip(data.keys(), num))
num = [2, 14000]
result3 = dict(zip(data.keys(), num))
values=[result1,result2,result3]
info=dict(zip(key,values))
info
# Out:
# {'범죄도시1': {'잔여석': 10, '티켓요금': 9000},
#  '범죄도시2': {'잔여석': 20, '티켓요금': 9000},
#  '범죄도시3': {'잔여석': 2, '티켓요금': 14000}}
