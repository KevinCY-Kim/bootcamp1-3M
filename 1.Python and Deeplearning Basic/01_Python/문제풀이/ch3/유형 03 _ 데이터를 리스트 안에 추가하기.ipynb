# %% [markdown]
# # 유형 03 : 데이터를 리스트 안에 추가하기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ###문제 01
# 아래 코드를 수행한 뒤 dataset은 어떤 원소가 들어가 있을지 맞춰보세요.

# %%
a = '다'

dataset = ['가','나','라']
dataset.insert(2,a)

dataset
# Out:
# ['가', '나', '다', '라']

# %% [markdown]
# ###문제 02
# 아래 코드를 수행한 뒤 dataset은 어떤 원소가 들어가 있을지 맞춰보세요.

# %%
a = '다'

dataset = ['가','나','라']
dataset.append(a)

dataset
# Out:
# ['가', '나', '라', '다']

# %% [markdown]
# ###문제 03
# 아래 코드를 수행한 뒤 dataset은 어떤 원소가 들어가 있는지, 길이는 무엇일지 맞춰보세요.

# %%
d1, d2 = 3, 5

dataset = [1, 2, 4]
dataset.insert(2, d1)
dataset.append(d2)

dataset, len(dataset)
# Out:
# ([1, 2, 3, 4, 5], 5)

# %% [markdown]
# ###문제 04
# 아래 코드를 수행한 뒤 dataset의 원소와 길이를 맞춰보세요.

# %%
dataset = ['사과','배','오렌지','레몬']

dataset.insert(4, '딸기')
dataset, len(dataset)
# Out:
# (['사과', '배', '오렌지', '레몬', '딸기'], 5)

# %% [markdown]
# ###문제 05
# a = '딸기'일때, 위와 동일한 수행결과가 되도록 append()를 사용해보세요.

# %%
a = '딸기'
dataset = ['사과','배','오렌지','레몬']

#dataset.append(a)
#dataset
# Out:
# ['사과', '배', '오렌지', '레몬', '딸기']

# %% [markdown]
# ###문제 06
# a = '딸기'일 때, 위와 동일한 수행결과가 나오도록 extend()를 사용해보세요.

# %%
# extend 사용하여 위와 동일한 결과 나타내기
a ='딸기'
dataset = ['사과','배','오렌지','레몬']

# dataset.extend([a])
# dataset
# Out:
# ['사과', '배', '오렌지', '레몬', '딸기']

# %% [markdown]
# ###문제 07
# 아래 코드를 수행한 뒤 grades은 원소와 길이를 맞춰보세요.

# %%
grades = ['1학년','2학년','3학년']
grades.extend(['4학년','5학년','6학년'])
grades, len(grades)
# Out:
# (['1학년', '2학년', '3학년', '4학년', '5학년', '6학년'], 6)

# %% [markdown]
# ###문제 08
# 아래 코드를 읽고 수행결과가 무엇일지 맞춰보세요.

# %%
coins = ['10원','50원','100원','500원']
papers = ['천원','만원','오만원']

moneys = coins + papers
moneys.insert(5,'오천원')
moneys[::-1][-2]
# Out:
# ['10원', '50원', '100원', '500원', '천원', '만원', '오만원']
# '50원'

# %% [markdown]
# ###문제 09
# 아래 코드를 수행한 뒤 monyes의 원소와 길이를 맞춰보세요.

# %%
coins = ['10원','50원','100원','500원']
moneys = ['천원','오천원','만원','오만원']

moneys.insert(0,coins)
moneys, len(moneys)
# Out:
# ([['10원', '50원', '100원', '500원'], '천원', '오천원', '만원', '오만원'], 5)

# %% [markdown]
# ###문제 10
# 아래 코드를 수행한 뒤 result가 무엇일지 맞춰보세요.

# %%
coins = ['10원','50원','100원','500원']
monyes = ['천원','오천원','만원','오만원']

monyes.append(coins)
result = monyes, moneys[-2].count('원')
result
# Out:
# (['천원', '오천원', '만원', '오만원', ['10원', '50원', '100원', '500원']], 1)

# %% [markdown]
# ###문제 11
# 아래 코드를 수행한 뒤 result가 무엇일지 맞춰보세요.

# %%
coins = ['김철수','김영희','고영희']
names = ['김유리','오유진','김동희']

names.extend(coins)
result = names, len(names) , names.count('김')
result
# Out:
# (['김유리', '오유진', '김동희', '김철수', '김영희', '고영희'], 6, 0)

# %% [markdown]
# ###문제 12
# 아래 코드를 수행한 뒤 numbers의 원소와 numbers[-1]이 무엇일지 맞춰보세요.

# %%
a = [4, 5, 6]
b = [1, 2, 3]
c = 7

numbers = b + a
numbers.append(c)
numbers, numbers[-1]
# Out:
# ([1, 2, 3, 4, 5, 6, 7], 7)

# %% [markdown]
# ###문제 13
# 아래 코드를 수행한 뒤 result가 무엇일지 맞춰보세요.

# %%
a = [1,2,3]
b = 4

num = a * 3
num.insert(3, b)
result = num, len(num), num.count(4)
result
# Out:
# ([1, 2, 3, 4, 1, 2, 3, 1, 2, 3], 10, 1)

# %% [markdown]
# ###문제 14
# 아래 코드를 읽고 number의 길이와 10이 몇 개 있을지 맞춰보세요.

# %%
a = [5,10,15,20]
b = [2,4,6,8]

number = b * 2 + a
number.insert(4, 10)
len(number), number.count(10)
# Out:
# (13, 2)

# %% [markdown]
# ###문제 15
# 아래 코드를 수행한 뒤 result가 무엇일지 맞춰보세요.

# %%
weekday = ['월요일','화요일','목요일','금요일']
weekend = ['토요일','일요일']
wednesday = '수요일'

weekday.extend(weekend)
weekday.insert(2, wednesday)
result = weekday, weekend[-1].count('일')
result
# Out:
# (['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일'], 2)

# %% [markdown]
# ###문제 16
# 아래 코드를 읽고 수행결과가 무엇일지 맞춰보세요.

# %%
numbers = []
numbers.append('one')
numbers.append('three')
numbers.append('four')
numbers.append('five')
numbers.append('seven')
numbers.insert(1, 'two')
numbers, numbers[-1].count('e')
# Out:
# (['one', 'two', 'three', 'four', 'five', 'seven'], 2)

# %% [markdown]
# ###문제 17
# 아래 코드를 읽고 numbers의 리스트에 'six'를 순서에 맞게 추가해보세요.

# %%
numbers = []
numbers.append('one')
numbers.append('two')
numbers.append('three')
numbers.append('four')
numbers.append('five')
numbers.append('seven')

# numbers.insert(5, 'six')

# %% [markdown]
# ###문제 18
# 아래 코드를 수행한 뒤 menu의 원소와 menu중 4000이 몇 번째 인덱스에 있을 지 맞춰보세요.

# %%
menu = []
menu.append(['아메리카노',3500])
menu.extend(['카푸치노',4000])
menu.append(['카페라떼',4500])
menu.insert(4,'카페모카')
menu.insert(5,5000)

menu, menu.index(4000)
# Out:
# ([['아메리카노', 3500], '카푸치노', 4000, ['카페라떼', 4500], '카페모카', 5000], 2)

# %% [markdown]
# ###문제 19
# 아래 코드를 수행한 뒤 chinese_food의 원소, 길이, 탕수육은 몇 개가 있는지, 탕수육은 몇 번째에 있는지 맞춰보세요.

# %%
chinese_food = []
chinese_food.append('짜장면')
chinese_food.append('짬뽕')
chinese_food.extend(['탕수육'])
chinese_food.insert(2, '유린기')
chinese_food.extend('가지덮밥')

chinese_food , len(chinese_food), chinese_food.count('탕수육') , chinese_food.index('탕수육')
# Out:
# (['짜장면', '짬뽕', '유린기', '탕수육', '가', '지', '덮', '밥'], 8, 1, 3)

# %% [markdown]
# ###문제 20
# 아래 코드를 읽고 마지막줄의 수행결과가 무엇인지 맞춰보세요.

# %%
library = [
    ['도곡2동 작은도서관', '토/일', '09:00','17:00','', ''],
    ['논현도서관', '2,4화/일','09:00','18:00','09:00','17:00'],
    ['세곡마루도서관', '토/일','09:00','18:00','','']

]

library[0].insert(1,'3월')
library[0].append(['김유리','고현동','김철수'])
library[1].insert(1,'4월')
library[1].append(['신현준','박현식','고도연','김유리'])
library[2].insert(1,'5월')
library[2].append(['신동','이천','김유리','오원주'])
library.append(library[0][-1])
library[-1].extend(library[1][-1])
library[-1].extend(library[2][-1])

len(library[0][2]), library[0][1], library[-1].count('김유리') ,
# Out:
# (3, '3월', 3)

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ###문제 21
# d1,d2 = 'third','fifth'일 때, dataset = ['first','second','fourth']이다. d1,d2를 숫자순서에 맞게 추가하여 dataset의 원소와 길이를 확인할 수 있는 코드를 작성해주세요.

# %%
d1, d2 = 'third', 'fifth'
dataset = ['first', 'second', 'fourth']
# Out:
# (['first', 'second', 'third', 'fourth', 'fifth'], 5)

# %%
#@title 정답
d1, d2 = 'third', 'fifth'
dataset = ['first', 'second', 'fourth']

dataset.insert(2, d1)
dataset.append(d2)

dataset, len(dataset)

# %% [markdown]
# ###문제 22
# dataset = ['사과','배','오렌지','레몬']일 때, 아래와 같은 결과가 나오도록 코드를 작성해주세요.
#
# ```
# ['사과', '배', '오렌지', '레몬', ['딸기']]
# ```

# %%
dataset = ['사과','배','오렌지','레몬']

# %%
#@title 정답
dataset = ['사과','배','오렌지','레몬']
dataset.append(['딸기'])
dataset
# Out:
# ['사과', '배', '오렌지', '레몬', ['딸기']]

# %% [markdown]
# ###문제 23
# dataset = ['사과','배','오렌지','레몬']일 때, 아래와 같은 결과가 나오도록 코드를 작성해주세요. (단, extend()와 append()를 한번씩만 사용)
#
# ```
# ['사과', '배', '오렌지', '레몬', '딸기', ['블루베리']]
# ```

# %%
dataset = ['사과','배','오렌지','레몬']

# %%
#@title 정답
dataset = ['사과','배','오렌지','레몬']
dataset.extend(['딸기'])
dataset.append(['블루베리'])
dataset
# Out:
# ['사과', '배', '오렌지', '레몬', '딸기', ['블루베리']]

# %% [markdown]
# ###문제 24
# 다음은 2022년 라면 인기 순위를 나타낸 것이다. dataset은 라면이름의 리스트라고 할 때, 짜파게티를 순서에 맞게 넣어보세요.
#
# |2022년 라면 인기 순위|
# |:-----------------:|
#
# |순위|브랜드|이름|
# |:--:|:----:|:--:|
# |1위|농심|신라면|
# |2위|농심|짜파게티|
# |3위|농심|안성탕면|
# |4위|농심|육개장사발면|
# |5위|오뚜기|진라면(매)|
# |6위|농심|너구리|
# |7위|팔도|팔도비빔면|
# |8위|삼양식품|삼양라면|
# |9위|농심|신라면컵|
# |10위|오뚜기|진라면(순)|

# %%
dataset = ['신라면','안성탕면','육개장사발면','진라면(매)',
           '너구리','팔도비빔면','삼양라면','신라면컵','진라면(순)']

# %%
#@title 정답
dataset = ['신라면','안성탕면','육개장사발면','진라면(매)',
           '너구리','팔도비빔면','삼양라면','신라면컵','진라면(순)']
dataset.insert(1, '짜파게티')
dataset
# Out:
# ['신라면',
#  '짜파게티',
#  '안성탕면',
#  '육개장사발면',
#  '진라면(매)',
#  '너구리',
#  '팔도비빔면',
#  '삼양라면',
#  '신라면컵',
#  '진라면(순)']

# %% [markdown]
# ###문제 25
# a = [4,5,6], b = [3,2,1], c = 7일 때, numbers의 리스트가 아래와 동일하도록 코드를 작성해주세요.
#
# ```
# [1, 2, 3, 4, 5, 6, 7]
# ```

# %%
a = [4, 5, 6]
b = [3, 2, 1]
c = 7

# %%
#@title 정답
a = [4, 5, 6]
b = [3, 2, 1]
c = 7

numbers = b[::-1] + a
numbers.append(c)
numbers
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ###문제 26
# a,b = 2,3일 때,
#
# 1. num1은 a와 b를 더한 값
# 2. num2는 b에서 a를 뺀 값
# 3. num3는 a와 b를 곱한 값
# 4. num4는 a와 a를 곱한 값
#
# dataset = [a,b]라고 할 때, num1,num2,num3,num4를 차례대로 오름차순이 되도록 변수를 추가하는 코드를 작성해주세요.

# %%
a,b = 2,3
dataset = [a,b]

# %%
#@title 정답

a,b = 2,3
dataset = [a,b]

num1 = a + b
num2 = b - a
num3 = a * b
num4 = a * a

dataset.append(num1)
dataset.insert(0,num2)
dataset.append(num3)
dataset.insert(-2,num4)
dataset
# Out:
# 5 1 6 4
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ###문제 27
# a,b,c = 1,2,3일 때, number의 리스트는 아래와 같다. 이를 코드로 작성해보세요.
#
# ```
# [1,4,9,16,9,4,1]
# ```

# %%
a,b,c = 1,2,3

# %%
#@title 정답
a,b,c = 1,2,3

number = [a,b*2,c*3]
number = number + number[::-1]
number.insert(3,16)
number
# Out:
# [1, 4, 9, 16, 9, 4, 1]

# %% [markdown]
# ###문제 28
#
# neckline이라는 빈리스트가 있다.
# neckline의 리스트가 아래와 동일해지도록 코드를 작성하세요. (힌트 : extend)
#
# ```
# ['라운드넥', 'v넥', 'U넥', '립넥', '크루넥', '플로넥', '반폴라']
# ```

# %%
neckline = []

# %%
#@title 정답

neckline = []
neckline.extend(['라운드넥','v넥','U넥','립넥','크루넥','플로넥','반폴라'])
neckline
# Out:
# ['라운드넥', 'v넥', 'U넥', '립넥', '크루넥', '플로넥', '반폴라']

# %% [markdown]
# ###문제 29
# 다음은 2022년 세계 자동차 브랜드가치의 순위를 나타낸 표이다.
# 표를 참고하여 아래 리스트 내부에 부족한 정보들을 추가하여 완성해주세요.
#
# |2022년 세계 자동차 브랜드가치 순위|
# |:--------------------------------:|
#
# |순위|브랜드|브랜드가치(달러)|
# |:--:|:----:|:--------:|
# |1위|TOYOTA|597억 5700만|
# |2위|Mercedes-benz|561억 3000만|
# |3위|TESLA|480억 2000만|
# |4위|BMW|463억 3100만|
# |5위|HONDA|228억 3700만|
# |6위|HYUNDAI|173억 1400만|
# |7위|AUDI|149억 7600만|
# |8위|Volkswagen|148억 1900만|
# |9위|Ford|144억 3100만|
# |10위|PORSCHE|135억 5000만|
# |11위|NISSAN|122억 1200만|
# |12위|Ferrari|93억 6500만|
# |13위|KIA|66억 1200만|
# |14위|LANDROVER|55억 9300만|
# |15위|MINI|55억 7900만|

# %%
car_brand = [
    ['TOYOTA', '597억 5700만'],
    ['Mercedes-benz','561억 3000만'],
    ['480억 2000만'],
    ['BMW','463억 3100만'],
    ['HONDA','228억 3700만'],
    ['HYUNDAI','173억 1400만'],
    ['AUDI','149억 7600만'],
    ['Volkswagen','148억 1900만'],
    ['Ford'],
    ['PORSCHE','135억 5000만'],
    ['NISSAN','122억 1200만'],
    ['Ferrari','93억 6500만'],
    ['KIA','66억 1200만'],
    ['LANDROVER','55억 9300만'],
    ['MINI']
]

# %%
#@title 정답
car_brand = [
    ['TOYOTA', '597억 5700만'],
    ['Mercedes-benz','561억 3000만'],
    ['480억 2000만'],
    ['BMW','463억 3100만'],
    ['HONDA','228억 3700만'],
    ['HYUNDAI','173억 1400만'],
    ['AUDI','149억 7600만'],
    ['Volkswagen','148억 1900만'],
    ['Ford'],
    ['PORSCHE','135억 5000만'],
    ['NISSAN','122억 1200만'],
    ['Ferrari','93억 6500만'],
    ['KIA','66억 1200만'],
    ['LANDROVER','55억 9300만'],
    ['MINI']
]
car_brand[2].insert(0,'TESLA')
car_brand[8].extend(['144억 3100만'])
car_brand[-1].append('55억 7900만')
car_brand
# Out:
# [['TOYOTA', '597억 5700만'],
#  ['Mercedes-benz', '561억 3000만'],
#  ['TESLA', '480억 2000만'],
#  ['BMW', '463억 3100만'],
#  ['HONDA', '228억 3700만'],
#  ['HYUNDAI', '173억 1400만'],
#  ['AUDI', '149억 7600만'],
#  ['Volkswagen', '148억 1900만'],
#  ['Ford', '144억 3100만'],
#  ['PORSCHE', '135억 5000만'],
#  ['NISSAN', '122억 1200만'],
#  ['Ferrari', '93억 6500만'],
#  ['KIA', '66억 1200만'],
#  ['LANDROVER', '55억 9300만'],
#  ['MINI', '55억 7900만']]

# %% [markdown]
# ###문제 30
# car_brand라는 빈리스트에 Japan, Korea, USA, Germany, India, Italy
# 변수들을 차례대로 추가하여 아래의 결과가 나오도록 코드를 작성해보세요.
#
# ```
# [['TESLA', 'FORD'],
#  ['TOYOTA', 'HONDA', 'NISSAN'],
#  ['HYUNDAI', 'KIA'],
#  ['Ferrari'],
#  ['Mercedes-benz', 'BMW', 'AUDI', 'Volkswagen', 'PORSCHE', 'MINI'],
#  ['LANDROVER']]
# ```

# %%
car_brand = []

Japan = ['TOYOTA','HONDA','NISSAN']
Korea = ['HYUNDAI','KIA']
USA = ['TESLA','FORD']
Germany = ['Mercedes-benz','BMW','AUDI','Volkswagen','PORSCHE','MINI']
India = ['LANDROVER']
Italy = ['Ferrari']

# %%
#@title 정답
car_brand = []

Japan = ['TOYOTA','HONDA','NISSAN']
Korea = ['HYUNDAI','KIA']
USA = ['TESLA','FORD']
Germany = ['Mercedes-benz','BMW','AUDI','Volkswagen','PORSCHE','MINI']
India = ['LANDROVER']
Italy = ['Ferrari']

car_brand.append(Japan)
car_brand.append(Korea)
car_brand.insert(0,USA)
car_brand.append(Germany)
car_brand.extend([India])
car_brand.insert(-2,Italy)
car_brand
# Out:
# [['TESLA', 'FORD'],
#  ['TOYOTA', 'HONDA', 'NISSAN'],
#  ['HYUNDAI', 'KIA'],
#  ['Ferrari'],
#  ['Mercedes-benz', 'BMW', 'AUDI', 'Volkswagen', 'PORSCHE', 'MINI'],
#  ['LANDROVER']]
