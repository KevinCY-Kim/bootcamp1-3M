# %% [markdown]
# # 유형 06 : 변수의 타입 변환하기

# %%
int()
float()
str()
bool()
# Out:
# False

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ### 문제 01

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a = 3.3

result = int(a)
result
# Out:
# 3

# %% [markdown]
# ### 문제 02

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
b = -10.6

result = int(abs(b))

# %% [markdown]
# ### 문제 03

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
c = 0.125e+2

result = int(c)
result
# Out:
# 12

# %% [markdown]
# ### 문제 04

# %% [markdown]
# 다음은 int()의 기능에 대한 설명이다. (True/False)

# %%
# int()의 기능은 반올림하여 정수로 변환시켜주는 것이다 (    )

# %% [markdown]
# ### 문제 05

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a = 13
b = 12

result = float(a+b/2)

# %% [markdown]
# ### 문제 06

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a = 13
b = 12

result = float(a+b)/2

# %% [markdown]
# ### 문제 07

# %% [markdown]
# 문제 5번과 6번의 결과가 다른 이유는 무엇인가요?

# %%
# float()함수를 사용시 (괄호)안의 결과값이 출력 되기 때문에 유의

# %% [markdown]
# ### 문제 08

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
num = 123

result = str(num)
result
# Out:
# '123'

# %% [markdown]
# ### 문제 09

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
num1 = 123.5
num2 = 456.12

result = int(num1) + int(num2)
result
# Out:
# 579

# %% [markdown]
# ### 문제 10

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
str1 = '003'
str2 = '0'

result = int(str1)+int(str2)

# %% [markdown]
# ### 문제 11

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
str1 = '123'
str2 = '456'

result = int(str1) + int(str2)

# %% [markdown]
# ### 문제 12

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
num1 = 123
str1 = '123'

result = num1 + str1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fe1d01c92505> in <cell line: 0>()
#       2 str1 = '123'
#       3
# ----> 4 result = num1 + str1
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### 문제 13

# %% [markdown]
# 12번의 결과가 나온 이유와 해결방안은 무엇인지 빈칸을 완성하세요.

# %%
# 같은 (type)끼리만 연산 가능 ==> num1을 (str()) 로 변경하거나 str1을 (int())로 변경하여 연산해야한다.

# %% [markdown]
# ### 문제 14

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
num1 = 10
num2 = 0

result = print(bool(num1), bool(num2))
# Out:
# True False

# %% [markdown]
# ### 문제 15

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a = divmod(10,2)

result = print(bool(a[0]), bool(a[1]))
# Out:
# True False

# %% [markdown]
# ### 문제 16

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a = ''
b = ' '
c = 'Boolean'

a = bool(a)
b = bool(b)
c = bool(c)

result = print(a,b,c)
# Out:
# False True True

# %% [markdown]
# ### 문제 17

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a = '351'
b = True
c = 30
d = 0.134e2

a = bool(a)
b = bool(b)
c = bool(c)
d = bool(d)

result = print(a,b,c,d)
# Out:
# True True True True

# %% [markdown]
# ### 문제 18

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
txt1 = True
txt2 = False
num = True

result = txt1 + txt2 + num
result = bool(result)
result
# Out:
# True

# %% [markdown]
# ### 문제 19

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
a = "000"
b = "0000"
c = 0000

result = int(a) + int(b) + c
result = bool(result)
# Out:
# False

# %% [markdown]
# ### 문제 20

# %% [markdown]
# 아래 코드를 읽고 result가 몇일지 맞춰보세요.

# %%
#
a = "False"
b = "0000"
c = ' ' # 스페이스 하나만 있어도 bool(c) -> True

result = bool(a) + bool(b)*bool(c)
result
# Out:
# 2

# %%
# bool() vs 비교연산자 vs 논리연산자
# 1. bool() : True(참) , False(거짓) 판단
# 2. 비교연산자 : 두 값의 관계를 판단  => == , != , < , > <=, >=
# 3. 논리연산자 : 두 값의 논리값을 판단 ==> not, and, or 순서로 비교

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ### 문제 21

# %% [markdown]
# a = -5.6일 때,  abs와 round를 이용하여 result의 값이 6이 되도록 코드로 완성하세요.

# %%
a = -5.6

# %%
#@title 정답
a = -5.6

result = int(round(abs(a)))

# %% [markdown]
# ### 문제 22

# %% [markdown]
# a,b = 20,35일 때, result의 값은 37.5이다. 변수 타입함수를 이용해 코드를 작성하세요.

# %%
a,b = 20,35

# %%
#@title 정답
a,b = 20,35

result = float(a+b/2)

# %% [markdown]
# ### 문제 23

# %% [markdown]
# num1, num2 = 1250, 746일 때, 타입변환을 통해 result값이 1996 되도록 이를 코드로 작성하세요.

# %%
num1 = '1250'
num2 = 746

# %%
#@title 정답
num1 = '1250'
num2 = 746

result = int(num1) + num2
print(result)
# Out:
# 1996

# %% [markdown]
# ### 문제 24

# %% [markdown]
# str1 = '1250', str2 = '746'일 때, result값은 '1996'이 되도록 코드로 작성하세요.

# %%
str1 = '1250'
str2 = 746

# %%
#@title 정답
str1 = '1250'
str2 = 746

result = str(int(str1)+str2)
result
# Out:
# '1996'

# %% [markdown]
# ### 문제 25

# %% [markdown]
# str1 = '1250', str2 = '746'일 때, result값은 1996이다. 이를 코드로 작성하세요.

# %%
#@title 정답
str1 = '1250'
str2 = '746'

result = int(str1) + int(str2)
result
# Out:
# 1996

# %% [markdown]
# ### 문제 26

# %% [markdown]
# a와 b의 값이 35에 5를 나눈 몫과 나머지일 때, 몫과 나머지가 True/False일지 확인할 수 있는 코드를 작성하세요.

# %%
a, b = divmod(35,5)

# %%
#@title 정답

# true인지, false인지 확인하자 -> 0이 아닌지 0인지 확인하자
a, b = divmod(35,5)

result = print(bool(a), bool(b))
# Out:
# True False

# %% [markdown]
# ### 문제 27

# %% [markdown]
#  a = ' ', b = ' ', c = 'four' 일 때, a에는 a의 논리값, b에는 b의 논리값, c에는 [c의 길이가 4가 아니다]를 할당한다. result는 a,b,c를 print()했을 때의 코드를 작성하세요.

# %%
a = ''
b = ' '
c = 'four'

# %%
#@title 정답
a = ''
b = ' '
c = 'four'

a = bool(a)
b = bool(b)
c = len(c) != 4

result = print(a,b,c)
# Out:
# False True False

# %% [markdown]
# ### 문제 28

# %% [markdown]
# year 변수는  '2024' 값이 할당되어 있다.
# year 변수를 활용하여 2023,2022,2021 값을 출력하는 코드를 작성하세요.

# %%
year='2024'

# %%
#@title 정답
year='2024'
year=int(year)
print(year-1,year-2,year-3)
# Out:
# 2023 2022 2021

# %% [markdown]
# ### 문제 29

# %% [markdown]
#  각 a,b,c의 bool 연산과 사칙연산(더하기)을 적용해 출력값이 1이 되도록 코드를 작성하세요.

# %%
a= 10//3
b= 10 % 2
c= 1e5%10

# %%
#@title 정답
a= 10//3
b= 1024 % 256
c= 1.23e5%10

result=bool(a)+bool(b)+bool(c)
print(result)
# Out:
# 1

# %% [markdown]
# ### 문제 30

# %% [markdown]
# a = "000", b = "0000", c = 0000 일 때, result는 a,b,c를 더한 값의 논리값이 False이다. 이를 토대로 코드를 작성하세요.

# %%
a = "000"
b = "0000"
c = 0000

# %%
#@title 정답
a = "000"
b = "0000"
c = 0000

result = int(a) + int(b) + c
result = bool(result)
result
# Out:
# False
