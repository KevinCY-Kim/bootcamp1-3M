# %% [markdown]
# # 유형 02 : 특정 변수에 값이 존재할 때만 실행되는 코드 만들기

# %% [markdown]
# ## 읽기 영역

# %% [markdown]
# ### 문제 01
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
num1 = 1

if num1:
    print('num1은 1입니다')
# Out:
# num1은 1입니다

# %% [markdown]
# ### 문제 02
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
num = 10
denom = 5
result = 0

if denom:
    result = num/denom
print(result)
# Out:
# 2.0

# %% [markdown]
# ### 문제 03
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
# 결과 확인 (작동 x)
age = None

if age:
    print("나이는 ", age, "입니다.")

# %% [markdown]
# ### 문제 04
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
wishlist = ["사과", "바나나", "딸기", "오렌지"]
cart = []
""" 수정
if wishlist:
    item = wishlist[0]
    cart.append(item)
    wishlist = wishlist[1:]
"""
if wishlist:
    item = wishlist[0]
    cart.append(item)
    wishlist.remove(item)

print("위시리스트:", wishlist)
print("장바구니:", cart)
# Out:
# 위시리스트: ['바나나', '딸기', '오렌지']
# 장바구니: ['사과']

# %% [markdown]
# ### 문제 05
# 아래 코드를 읽고 출력물의 결과를 맞춰보세요

# %%
str1 = '문자열이 존재한다'
str2 = ''

if str2:
    print('문자열이 비어있습니다')
if str2 is not True:
    print('문자열이 존재하지 않습니다')
# Out:
# 문자열이 존재하지 않습니다

# %% [markdown]
# ### 문제 06
# 아래 코드를 읽고 출력물의 결과를 맞춰보세요

# %%
is_adult = False

if is_adult:
  print("성인입니다.")
if is_adult is False:
  print("미성년자입니다.")
# Out:
# 미성년자입니다.

# %% [markdown]
# ### 문제 07
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
colors = []

if not colors:
  print('색상 정보가 없습니다.')
# Out:
# 색상 정보가 없습니다.

# %% [markdown]
# ### 문제 08
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
person = {'name': '홍길동', 'age': 30, 'gender': 'male'}

if person:
  print(f'{person["name"]}님의 정보가 있습니다.')
# Out:
# 홍길동님의 정보가 있습니다.

# %% [markdown]
# ### 문제 09
# 아래 코드를 읽고 len(info)가 무엇일지 맞춰보세요

# %%
info = {
    'name': 'Alice',
    'age': 28,
    'job': 'Engineer'
}

if info:
    print(f'딕셔너리의 길이는 {len(info)}입니다.')
# Out:
# 딕셔너리의 길이는 3입니다.

# %% [markdown]
# ### 문제 10
# 아래 코드를 읽고 list_type이 무엇일지 맞춰보세요

# %%
params ={
        'ticket' : 'comic',
        'templateId' : 'webtoon',
        'lang' : 'ko',
        'pageSize' : 15,
        'listType' : 'OBJECT',
        'page' : 1,
        'sort' : 'NEW'
        }

if params:
    list_type = params['listType']
    print(f'데이터를 가져올 때 , 데이터 형식은 {list_type}로 JSON 형태로 가지고 옵니다.')
# Out:
# 데이터를 가져올 때 , 데이터 형식은 OBJECT로 JSON 형태로 가지고 옵니다.

# %% [markdown]
# ### 문제 11
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
folder_path = '/content/images/'
categories = ['cat','dog','chair','cup','laptop']

if categories:
  print(folder_path + categories[3]+ '/' + categories[3] +'.jpg')
# Out:
# /content/images/cup/cup.jpg

# %% [markdown]
# ### 문제 12
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
folder_path = '/content/images/animals/'
file_names = ['bird.png', 'cat.png', 'dog.png']

if folder_path:
    print(folder_path + file_names[0])
# Out:
# /content/images/animals/bird.png

# %% [markdown]
# ### 문제 13
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
folder_path = '/content/images/'

index2label = { 0 : 'airplane', 1 : 'car'  , 2 : 'cat' , 3 : 'dog',
               4 : 'flower', 5 : 'fruit', 6 : 'motorbike', 7 : 'person'}


if index2label:
    print(folder_path + index2label[2]+ '/' +index2label[2] + '.jpg')
# Out:
# /content/images/cat/cat.jpg

# %% [markdown]
# ### 문제 14
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
color_codes = {'red': '#FF0000', 'green': '#00FF00', 'blue': '#0000FF'}

if color_codes:
  print(color_codes['green'])
# Out:
# #00FF00

# %% [markdown]
# ### 문제 15
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
text = '멜로가,체질,외전에,UCC감성을,곁들인...생각없이,보면서,웃기,좋은,영화'

if text:
    text = text.replace(',', ' ')
print(text)
# Out:
# 멜로가 체질 외전에 UCC감성을 곁들인...생각없이 보면서 웃기 좋은 영화

# %% [markdown]
# ### 문제 16
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
text = '     개연성이.좀.떨어진다고.느껴졌지만.노래랑.영상미는.여전히.좋음   '

if text:
   text = text.strip()
   text = text.replace('.',' ')
print(text)
# Out:
# 개연성이 좀 떨어진다고 느껴졌지만 노래랑 영상미는 여전히 좋음

# %% [markdown]
# ### 문제 17
# 아래 코드를 읽고 max_price가 무엇일지 맞춰보세요

# %%
land_prices = {
    '강원도': 40,
    '경기도': 60,
    '경상남도': 35,
    '경상북도': 30,
    '광주광역시': 80,
    '대구광역시': 70,
    '대전광역시': 90,
    '부산광역시': 100,
    '서울특별시': 150,
    '세종특별자치시': 100,
    '울산광역시': 50,
    '인천광역시': 80,
    '전라남도': 20,
    '전라북도': 25,
    '제주특별자치도': 100,
    '충청남도': 30,
    '충청북도': 25,
}

if land_prices:
  max_price = max(land_prices.values())
  print(f'land_prices 리스트 안에서 가장 비싼 금액은 {max_price} 입니다')
# Out:
# land_prices 리스트 안에서 가장 비싼 금액은 150 입니다

# %% [markdown]
# ### 문제 18
# 아래 코드를 읽고 min_value와 min_key가 무엇일지 맞춰보세요.

# %%
province_prices = {
    '강원도': 40,
    '경기도': 60,
    '경상남도': 35,
    '경상북도': 30,
    '전라남도': 20,
    '전라북도': 25,
    '제주특별자치도': 100,
    '충청남도': 30,
    '충청북도': 25,
}

if province_prices:
  min_value = min(province_prices.values())
  min_key = min(province_prices, key=province_prices.get)
  print(f'대한민국 행정구역 중 9개의 도 중에서 가장 땅값이 싼 곳은 {min_key}이며 금액은 {min_value}이다')
# Out:
# 대한민국 행정구역 중 9개의 도 중에서 가장 땅값이 싼 곳은 전라남도이며 금액은 20이다

# %% [markdown]
# ### 문제 19
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
# 데이터: 지역, 면적, 가격
data = [
    ('강남구', 20, 100000000),
    ('서초구', 25, 120000000),
    ('송파구', 30, 150000000),
    ('강남구', 30, 130000000),
    ('서초구', 35, 160000000),
    ('송파구', 40, 180000000),
]

if data:
  print(f'{data[0][0]}의 면적 {data[0][1]}당 금액은 {data[0][2]} 입니다')
# Out:
# 강남구의 면적 20당 금액은 100000000 입니다

# %% [markdown]
# ### 문제 20
# 아래 코드를 읽고 print의 결과를 맞춰보세요

# %%
# 데이터: 지역, 면적, 가격
data = [
    ('강남구', 20, 100000000),
    ('서초구', 25, 120000000),
    ('송파구', 30, 150000000),
    ('강남구', 30, 130000000),
    ('서초구', 35, 160000000),
    ('송파구', 40, 180000000),
]

if data:
  print(f'{data[2][1]}평당 {data[2][2]}인 곳은 {data[2][0]} 입니다')
# Out:
# 30평당 150000000인 곳은 송파구 입니다

# %% [markdown]
# ## 쓰기 영역

# %% [markdown]
# ### 문제 21
# money의 값이 True일 때, "책을 구매한다."라는 메시지를 출력되도록 코드를 작성해보세요. (단, 조건문에서 '==' 연산자를 사용할 수 없습니다.)

# %% [markdown]
# ### 정답

# %%
money = True

if money:
    print("책을 구매한다")
# Out:
# 책을 구매한다.

# %% [markdown]
# ### 문제 22
# age = None일 때, '나이 정보가 없습니다'라고 출력되도록 코드를 작성해보세요. (단, 조건문에서 '==' 연산자를 사용할 수 없습니다.)

# %% [markdown]
# ### 정답

# %%
age = None

if not age:
  print('나이 정보가 없습니다')
# Out:
# 나이 정보가 없습니다

# %% [markdown]
# ### 문제 23
# weeks = ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun'] 일 때,리스트에 요소가 있다면
#
# 리스트의 두 번째 요소를 출력하는 코드를 작성해보세요. (단, 조건문에서 '==' 연산자를 사용할 수 없습니다.)

# %% [markdown]
# ### 정답

# %%
weeks = ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']

if weeks:
    print(weeks[1])
# Out:
# tue

# %% [markdown]
# ### 문제 24
# menu = ['아이스티', '라떼', '오렌지주스']이고 my_menu = '아메리카노'일 때, my_menu가 비어있지 않은 경우
#
# menu에 my_menu를 추가하고 menu를 출력하는 코드를 작성해보세요.

# %%
menu = ['아이스티', '라떼', '오렌지주스']
my_menu = '아메리카노'

if my_menu:
    menu.append(my_menu)
    print(menu)
# Out:
# ['아이스티', '라떼', '오렌지주스', '아메리카노']

# %% [markdown]
# ### 정답

# %%
menu = ['아이스티', '라떼', '오렌지주스']
my_menu = '아메리카노'

if my_menu:
    menu.append(my_menu)
    print(menu)
# Out:
# ['아이스티', '라떼', '오렌지주스', '아메리카노']

# %% [markdown]
# ### 문제 25
# 딕셔너리 user_status에는 사용자의 상태 정보가 저장되어 있습니다. 딕셔너리의 키 'online'은 사용자가 온라인 상태인지를 나타내며,
#
# True 또는 False 값을 가집니다. 프로그램을 작성하여, user_status 딕셔너리를 활용하여 다음 조건을 만족하는 메시지를 출력하세요.
#
# - online이 True인 경우: "사용자가 온라인 상태입니다."
# - online이 False인 경우: "사용자가 오프라인 상태입니다."

# %%
user_status = {'online': True}

if user_status == ['online']:
    print("사용자가 온라인 상태입니다.")
    if not user_status == ['online']:
        print("사용자가 오프라인 상태입니다.")

# %% [markdown]
# ### 정답

# %%
user_status = {'online': True}

if user_status['online']:
    print("사용자가 온라인 상태입니다.")
if not user_status['online']:
    print("사용자가 오프라인 상태입니다.")

# %% [markdown]
# ### 문제 26
#  user_info 딕셔너리에는 사용자의 정보가 저장되어 있습니다.
#
#  user_info = {'name': 'John', 'age': 25, 'email': 'john@example.com'}
#
#  - 사용자의 이름이 존재하는 경우, "사용자 이름이 존재합니다: {사용자 이름}"을 출력하세요.
#
# - 사용자의 나이가 18세 이상인 경우, "성인 사용자입니다."를 출력하세요.
#
# - 사용자의 이메일이 존재하는 경우, '@'앞부분까지만 출력하세요.

# %%
user_info = {'name': 'John', 'age': 25, 'email': 'john@example.com'}

if user_info['name']:
    print(f"사용자 이름이 존재합니다:{user_info['name']}")

    if user_info['age'] >= 18:
        print("성인 사용자입니다.")

        if user_info['email']:
            print(user_info['email'].split("@")[0])
# Out:
# 사용자 이름이 존재합니다:John
# 성인 사용자입니다.
# john

# %% [markdown]
# ### 정답

# %%
user_info = {'name': 'John', 'age': 25, 'email': 'john@example.com'}


if user_info['name']:
    print(f"사용자 이름이 존재합니다: {user_info['name']}")

if user_info['age'] >= 18:
    print("성인 사용자입니다.")

if user_info['email']:
    print(user_info['email'].split("@")[0])
# Out:
# 사용자 이름이 존재합니다: John
# 성인 사용자입니다.
# john

# %% [markdown]
# ### 문제 27
# index2label = { 0 : 'airplane', 1 : 'car'  , 2 : 'cat' , 3 : 'dog',
#                4 : 'flower', 5 : 'fruit', 6 : 'motorbike', 7 : 'person', 8 : None} 일 때,
#
# index2label[8]의 value가 없거나 None이면 '알 수 없음'으로 변경하고 index2label을 출력하는 코드를 작성해보세요.

# %%
index2label = { 0 : 'airplane', 1 : 'car' , 2 : 'cat' , 3 : 'dog', 4 : 'flower', 5 : 'fruit', 6 : 'motorbike', 7 : 'person', 8 : None}

index2label1 = []

if not index2label[8]: # None이거나 조건이 비어있으면 True 판정
    index2label[8] = "알수없음"
    print(index2label)
# Out:
# {0: 'airplane', 1: 'car', 2: 'cat', 3: 'dog', 4: 'flower', 5: 'fruit', 6: 'motorbike', 7: 'person', 8: '알수없음'}

# %% [markdown]
# ### 정답

# %%
index2label = { 0 : 'airplane', 1 : 'car' , 2 : 'cat' , 3 : 'dog', 4 : 'flower',
                5 : 'fruit', 6 : 'motorbike', 7 : 'person', 8 : None}

if not index2label[8]:
    index2label[8] = "알 수 없음"
    print(index2label)

# %% [markdown]
# ### 문제 28
# 주어진 text 변수의 값이 존재하는 경우, text 변수의 값에서 '.'과 'ㅋ'을 제외한 나머지 텍스트들을 출력하는 코드를 작성해보세요.

# %%
text = '스토리가 좀 아쉬운 느낌.. 대충 만든 느낌이라.. 전개가 되게 빠름ㅋㅋ'

if text:
    text = text.replace('.','') # 변수의 일부분을 없앨 때 사용
    text = text.replace('ㅋ','') # 변수의 일부분을 없앨 때 사용
    print(text)
# Out:
# 스토리가 좀 아쉬운 느낌 대충 만든 느낌이라 전개가 되게 빠름

# %% [markdown]
# ### 정답

# %%
text = '스토리가 좀 아쉬운 느낌.. 대충 만든 느낌이라.. 전개가 되게 빠름ㅋㅋ'

if text:
  text = text.replace('.', '')
  text = text.replace('ㅋ','')
print(text)

# %% [markdown]
# ### 문제 29
# 주어진 문자열 text를 사용하여 아래 제시한 순서대로 문제를 해결하세요.
#
# - 문자열 text를 \n 기준으로 분리(split)하여 text에 다시 저장합니다.
# - 저장된 text의 첫 번째 요소(text[1])가 빈 문자열이 아닌 경우 해당 요소를 출력합니다.
# - 만약 빈 문자열이면 "빈 문자열입니다."를 출력합니다.
#
# ```
# text = """죽을 위기에서 살아난 ‘존 윅’은 ‘최고 회의’를 쓰러트릴 방법을 찾아낸다. 비로소 완전한 자유의 희망을 보지만,\n
#           NEW 빌런 ‘그라몽 후작’과 전 세계의 최강 연합은‘존 윅’의 오랜 친구까지 적으로 만들어 버린다.\n
#           새로운 위기에 놓인 ‘존 윅’은 최후의 반격을 준비한다. 레전드 액션 블록버스터 <존 윅>의 새로운 챕터가 열린다!"""
# ```

# %%
text = """죽을 위기에서 살아난 ‘존 윅’은 ‘최고 회의’를 쓰러트릴 방법을 찾아낸다. 비로소 완전한 자유의 희망을 보지만,\n
          NEW 빌런 ‘그라몽 후작’과 전 세계의 최강 연합은‘존 윅’의 오랜 친구까지 적으로 만들어 버린다.\n
          새로운 위기에 놓인 ‘존 윅’은 최후의 반격을 준비한다. 레전드 액션 블록버스터 <존 윅>의 새로운 챕터가 열린다!"""

text = text.split('\n')

if not text[0] == '':
    print(text[0])
    if text[0] == '':
        print("빈 문자열입니다.")
# Out:
# 죽을 위기에서 살아난 ‘존 윅’은 ‘최고 회의’를 쓰러트릴 방법을 찾아낸다. 비로소 완전한 자유의 희망을 보지만,

# %% [markdown]
# ### 정답

# %%
text = """죽을 위기에서 살아난 ‘존 윅’은 ‘최고 회의’를 쓰러트릴 방법을 찾아낸다. 비로소 완전한 자유의 희망을 보지만,\n
          NEW 빌런 ‘그라몽 후작’과 전 세계의 최강 연합은‘존 윅’의 오랜 친구까지 적으로 만들어 버린다.\n
          새로운 위기에 놓인 ‘존 윅’은 최후의 반격을 준비한다. 레전드 액션 블록버스터 <존 윅>의 새로운 챕터가 열린다!"""

text = text.split('\n')

if text[1]:
    print(text[1])
if not text[1]:
    print("빈 문자열입니다.")
# Out:
# 빈 문자열입니다.

# %% [markdown]
# ### 문제 30
# ```
# movie_ratings = {'어벤져스: 엔드게임': 9.0, '라라랜드': 8.5, '인셉션': 9.2, '어바웃타임': 8.8}
# ```
# 다음은 영화와 평점 정보를 담은 딕셔너리입니다.
#
# 사용자가 확인하고 싶은 영화 제목이 **'인셉션'**일 때, 해당 영화가 딕셔너리에 존재하는지 확인하고
#
# 평점이 **9.0 이상**이면 영화제목과 평점을 출력하는 코드를 작성하세요.

# %%
movie_ratings = {'어벤져스: 엔드게임': 9.0, '라라랜드': 8.5, '인셉션': 9.2, '어바웃타임': 8.8}

movie_tile = '인셉션'

if movie_ratings[movie_title]:
    rating = movie_ratings[movie_title]
    if rating >= 9.0:
        print(f"{movie_title} : {rating}")
# Out:
# 인셉션 : 9.2

# %% [markdown]
# ### 정답

# %%
movie_ratings = {'어벤져스: 엔드게임': 9.0, '라라랜드': 8.5, '인셉션': 9.2, '어바웃타임': 8.8}

movie_title = '인셉션'

if movie_ratings[movie_title]:
    rating = movie_ratings[movie_title]
    if rating >= 9.0:
        print(f"{movie_title}: {rating}")
# Out:
# 인셉션: 9.2
