# %% [markdown]
# # javascript페이지-2유형
# 구글 이미지 100개 가져오기
# https://www.google.com/search?q=%EA%B0%95%EC%95%84%EC%A7%80&sxsrf=AJOqlzUaJI-Ub6xKm5eOURL-Wk7nYmmK1w:1674006641070&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj47MTZgND8AhV54DgGHXrtALEQ_AUoAXoECAEQAw&biw=1600&bih=810&dpr=1.2

# %% [markdown]
# ## 1) 강아지 이미지 구글 검색 결과에서 100장 가져오기
# - disable JS 를 하고 나서, 페이지가 바뀐 형태로 뜸
# - 바뀐 페이지에서 이미지 스크랩

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 총 5페이지를 순회하며 스크랩

# %% [markdown]
# ### JavaScript 가져오는 방법
# 1. JavaScript 판단하기
# 2. JavaScript URL 찾아나서기

# %% [markdown]
# 동적 기능이 부여되어있는 콘텐츠들은 JavaScript로 만들어진 녀석들이다.
# ### settings -> Debugger -> Disable JavaScript
# 자바스크립트를 비활성화해서, 자바스크립트 인지 아닌지 확인

# %% [markdown]
# 자바스크립트는 사라지고, HTML 로 만들어진 다른 이미지들이 남는다.
# 땡큐인 상황
# HTML 크롤링 수행하면 됨
