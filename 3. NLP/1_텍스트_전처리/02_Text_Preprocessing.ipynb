# %% [markdown]
# #텍스트 전처리(Text Preprocessing)

# %% [markdown]
# - 텍스트를 자연어 처리를 위해 용도에 맞도록 사전에 표준화 하는 작업
# - 텍스트 내 정보를 유지하고, 중복을 제거하여 분석 효율성을 높이기 위해 전처리를 수행
#
# 1) 토큰화(Tokenizing)
# - 텍스트를 자연어 처리를 위해 분리하는 것
# - 토큰화는 단어별로 분리하는 "단어 토큰화(Word Tokenization)"과 문장별로 분리하는 "문장 토큰화(Sentence Tokenization)"으로 구분
# => 이후 실습에서는 단어 토큰화를 "토큰화"로 통일하여 칭함
#
# 2) 품사 부착(Pos Tagging)
# - 각 토큰에 품사 정보를 추가
# - 분석시에 불필요한 품사를 제거하거나(예. 조사, 접속사 등) 필요한 품사를 필터링 하기 위해 사용
#
# 3) 개체명 인식(NER, Named Entity Recognition)
# - 각 토큰의 개체구분(기관, 인물, 지역, 날짜 등) 태그를 부착
# - 텍스트가 무엇과 관련되어 있는지 구분하기 위해 사용
# - 예를 들어, 과일의 apple과 기업의 apple을 구분하는 방법이 개체명 인식임.
#
# 4) 원형복원(Stemming & Lemmatization)
# - 각 토큰의 원형을 복원함으로써 토큰을 표준화 하여 불필요한 데이터 중복을 방지
# (= 단어의 수를 줄일 수 있어 연산 효율성을 높임)
#
#  - 어간추출(Stemming): 품사를 무시하고 규칙에 기반하여 어간을 추출
#  - 표제어 추출(Lemmatization): 품사정보를 유지하여 표제어 추출
#
# 5) 불용어 처리(Stopword)
#  - 자연어 처리를 위해 불필요한 요소를 제거하는 작업
#  - 불필요한 품사를 제거하는 작업과 불필요한 단어를 제거하는 작업으로 구성
#  - 불필요한 토큰을 제거함으로써 연산의 효율성을 높임

# %% [markdown]
# #1. 영문 전처리 연습

# %% [markdown]
# NLTK lib(https://www.nltk.org/)사용

# %% [markdown]
# ## 1.1 실습용 영문기사 수집
#
# 온라인 기사를 바로 수집하여 실습데이터로 사용
# https://www.forbes.com/sites/adrianbridgwater/2019/04/15/what-drove-the-ai-renaissance/#4a0130481f25

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.forbes.com/sites/adrianbridgwater/2019/04/15/what-drove-the-ai-renaissance/#4a0130481f25'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
eng_news = soup.select('p')
eng_text = eng_news[5].get_text()

eng_text
# Out:
# 'It is the present-day darling of the tech world. The current renaissance of Artificial Intelligence (AI) with its sister discipline Machine Learning (ML) has led every IT firm worth its salt to engineer some form of AI onto its platform, into its toolsets and throughout its software applications.'

# %% [markdown]
# ## 1.2 영문토큰화
# https://www.nltk.org/api/nltk.tokenize.html

# %%
import nltk
nltk.download('punkt') #영어 문장 분리에서 마침표를 기준으로 문장을 잘 나눠주는 규칙정보를 다운로드
nltk.download('punkt_tab') #토크나이저와 관련된 보조 데이터
nltk.download('omw-1.4') #Open Multilingual Wordnet --> WordNet은 단어의 뜻과 유의어/반의어등 다양한 단어들의 관계를 정리해 놓은 사전

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
word_tokens = word_tokenize(eng_text)
print(word_tokens)
# Out:
# ['It', 'is', 'the', 'present-day', 'darling', 'of', 'the', 'tech', 'world', '.', 'The', 'current', 'renaissance', 'of', 'Artificial', 'Intelligence', '(', 'AI', ')', 'with', 'its', 'sister', 'discipline', 'Machine', 'Learning', '(', 'ML', ')', 'has', 'led', 'every', 'IT', 'firm', 'worth', 'its', 'salt', 'to', 'engineer', 'some', 'form', 'of', 'AI', 'onto', 'its', 'platform', ',', 'into', 'its', 'toolsets', 'and', 'throughout', 'its', 'software', 'applications', '.']

# %%
#WordPunctTokenizer(): 알파벳과 알파벳이 아닌 문자를 문장 부호 단위에서 구분하여 토큰화
import nltk
from nltk.tokenize import WordPunctTokenizer

wordpuncttoken = WordPunctTokenizer().tokenize(eng_text)
print(wordpuncttoken)
# Out:
# ['It', 'is', 'the', 'present', '-', 'day', 'darling', 'of', 'the', 'tech', 'world', '.', 'The', 'current', 'renaissance', 'of', 'Artificial', 'Intelligence', '(', 'AI', ')', 'with', 'its', 'sister', 'discipline', 'Machine', 'Learning', '(', 'ML', ')', 'has', 'led', 'every', 'IT', 'firm', 'worth', 'its', 'salt', 'to', 'engineer', 'some', 'form', 'of', 'AI', 'onto', 'its', 'platform', ',', 'into', 'its', 'toolsets', 'and', 'throughout', 'its', 'software', 'applications', '.']

# %%
#TreebankWordTokenizer(): 정규표현식에 기반한 토큰화
import nltk
from nltk.tokenize import TreebankWordTokenizer

treebankwordtoken = TreebankWordTokenizer().tokenize(eng_text)
print(treebankwordtoken)
# Out:
# ['It', 'is', 'the', 'present-day', 'darling', 'of', 'the', 'tech', 'world.', 'The', 'current', 'renaissance', 'of', 'Artificial', 'Intelligence', '(', 'AI', ')', 'with', 'its', 'sister', 'discipline', 'Machine', 'Learning', '(', 'ML', ')', 'has', 'led', 'every', 'IT', 'firm', 'worth', 'its', 'salt', 'to', 'engineer', 'some', 'form', 'of', 'AI', 'onto', 'its', 'platform', ',', 'into', 'its', 'toolsets', 'and', 'throughout', 'its', 'software', 'applications', '.']

# %% [markdown]
# ## 1.3 영문 품사 부착(PoS tagging)

# %% [markdown]
# 분리한 토큰마다 품사를 부착한다.
# https://www.nltk.org/api/nltk.tag.html
#
# 태그목록: https://pythonprogramming.net/natural-language-toolkit-nltk-part-speech-tagging/

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger_eng') # 품사 태깅 정보

taggedToken = pos_tag(word_tokens)
print(taggedToken)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('James', 'NNP'), ('is', 'VBZ'), ('working', 'VBG'), ('at', 'IN'), ('Disney', 'NNP'), ('in', 'IN'), ('London', 'NNP')]

# %% [markdown]
# ##1.4 개체명 인식(NER, Named Entity Recognition)
# http://www.nltk.org/api/nltk.chunk.html

# %% [markdown]
# 개체명 인식(Named Entity Recognition)이란 말 그대로 이름을 가진 개체(named entity)를 인식하겠다는 것을 의미합니다.
# 즉, 어떤 이름을 의미하는 단어를 보고는 그 단어가 어떤 유형인지를 인식하는 것을 말합니다.

# %% [markdown]
# 예를 들어 제임스는 2018년에 골드만삭스에 입사했다. 라는 문장이 있을 때, 사람(person), 조직(organization), 시간(time)에 대해 개체명 인식을 수행하는 모델이라면 다음과 같은 결과를 보여줍니다.
#
# - 제임스 : 사람
# - 2018년 : 시간
# - 골드만삭스 : 조직

# %%
nltk.download('words') # 단어 리스트
nltk.download('maxent_ne_chunker') #NER 데이터
nltk.download('maxent_ne_chunker_tab') #NER 보조 데이터
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
from nltk import ne_chunk

text =  "James is working at Disney in London"

word_tokens = word_tokenize(text)
taggedToken = pos_tag(word_tokens)
neToken = ne_chunk(taggedToken)

print(neToken)
# Out:
# (S
#   (PERSON James/NNP)
#   is/VBZ
#   working/VBG
#   at/IN
#   (ORGANIZATION Disney/NNP)
#   in/IN
#   (GPE London/NNP))

# %% [markdown]
# James는 PERSON(사람), Disney는 조직(ORGANIZATION), London은 위치(GPE)

# %% [markdown]
# ## 1.5 원형복원
# 각 토큰의 원형을 복원하여 표준화한다

# %% [markdown]
# ### 1.5.1 어간추출(Stemming)
# - 규칙에 기반하여 토큰을 표준화
# - ing제거, ful제거 등
# http://www.nltk.org/api/nltk.chunk.html
#
# 규칙 상세: http://www.nltk.org/api/nltk.chunk.html

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
print("running -> " + ps.stem("running"))
print("believes -> "+ps.stem('believes'))
print('using ->' + ps.stem("using"))
print("conversation ->" + ps.stem('conversation'))
print('organization ->'+ ps.stem('organization'))
print('studies -> '+ ps.stem("studies"))
# Out:
# running -> run
# believes -> believ
# using ->use
# conversation ->convers
# organization ->organ
# studies -> studi

# %% [markdown]
# ### 1.5.2 표제어 추출(Lemmatization)
# - 품사정보를 보존하여 토큰을 표준화
#
# http://www.nltk.org/api/nltk.chunk.html

# %%
nltk.download('wordnet') # 단어 의미 사전
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
wl = WordNetLemmatizer()

# %%
print("running -> " + wl.lemmatize("running"))
print("believes -> "+wl.lemmatize('believes'))
print('using ->' + wl.lemmatize("using"))
print("conversation ->" + wl.lemmatize('conversation'))
print('organization ->'+ wl.lemmatize('organization'))
print('studies -> '+ wl.lemmatize("studies"))
# Out:
# running -> running
# believes -> belief
# using ->using
# conversation ->conversation
# organization ->organization
# studies -> study

# %% [markdown]
# ## 1.6 불용어 처리(Stopword)

# %%
stopPos = ["IN", "CC", "UH", "TO", "MD", "DT", "VBZ", "VBP"]

# 최빈어 조회: 최빈어를 조회하여 불용어 제거 대상을 선정
from collections import Counter
Counter(taggedToken).most_common()
# Out:
# [(('James', 'NNP'), 1),
#  (('is', 'VBZ'), 1),
#  (('working', 'VBG'), 1),
#  (('at', 'IN'), 1),
#  (('Disney', 'NNP'), 1),
#  (('in', 'IN'), 1),
#  (('London', 'NNP'), 1)]

# %%
stopWord = [",", "be", "able"]

# %%
word = []
for tag in taggedToken:
  if tag[1] not in stopPos:
    if tag[0] not in stopWord:
      word.append(tag[0])

print(word)
# Out:
# ['James', 'working', 'Disney', 'London']

# %% [markdown]
# ## 1.7 영문 텍스트 전처리 종합

# %%
import nltk

#다운로드는 되었다는 전제하에

from nltk.tokenize import TreebankWordTokenizer
token = TreebankWordTokenizer().tokenize("Obama loves fried chicken of KFC")
print('token:', token)

from nltk import pos_tag
TaggedToken = pos_tag(token)
print('tagged token:', TaggedToken)

from nltk.stem import PorterStemmer
ps = PorterStemmer()
print("loves -> " + ps.stem("loves"))
print("fried => " + ps.stem('fried'))

from nltk.stem import WordNetLemmatizer
wl = WordNetLemmatizer()
print("loves -> " + wl.lemmatize("loves"))
print("fried => " + wl.lemmatize('fried'))

#불용어 처리
StopPos = ['IN']
StopWord = ["fried"]

word = []
for tag in TaggedToken:
  if tag[1] not in StopPos:
    if tag[0] not in StopWord:
      word.append(wl.lemmatize(tag[0]))

print(word)
# Out:
# token: ['Obama', 'loves', 'fried', 'chicken', 'of', 'KFC']
# tagged token: [('Obama', 'NNP'), ('loves', 'VBZ'), ('fried', 'VBN'), ('chicken', 'NN'), ('of', 'IN'), ('KFC', 'NNP')]
# loves -> love
# fried => fri
# loves -> love
# fried => fried
# ['Obama', 'love', 'chicken', 'KFC']

# %% [markdown]
# #2. 한글 전처리 실습
#
# 영문은 공백으로 토큰화가 가능하지만, 한글의 경우 품사를 고려하여 토큰화해야 한다.

# %% [markdown]
# ## 2.1 실습용 한글기사 수집

# %% [markdown]
# - https://n.news.naver.com/mnews/article/016/0002032876?sid=105

# %%
kor_text = '''포스코ICT는 25일 경기도 판교 사옥에서 청소년들이 개발한 인공지능(AI) 기반 애플리케이션을 직접 선보이는 ‘2022 AI 유스 챌린지(Youth Challenge)’를 개최했다. 청소년들은 기성세대들이 생각하지 못했던 참신한 아이디어를 바탕으로 AI 시스템을 개발해 관심을 모았다.

예선을 거쳐 본선에 오른 전국 중·고교 7개팀은 지난 달부터 포스코ICT 소속 AI 엔지니어의 코칭 속에 개발한 AI 시스템을 직접 시연했다. 심사는 카이스트, 포스텍, 연세대 교수 등으로 구성된 평가위원들과 포스코ICT 직원들로 구성된 내부 평가위원들이 맡았다. 우수작은 과기정통부장관상(1팀), 포스코ICT사장상(1팀), 지능정보산업협회장상(1팀), 우수상(2팀), 장려상(2팀) 등으로 나눠 각각 시상했다. 포스코ICT는 AI 기술을 접목해 환경·안전·사회문제를 해결할 수 있는 청소년들의 아이디어를 발굴하기 위해 이번 공모전을 개최했다. 평소 AI 기술을 접할 기회가 부족했던 청소년들은 멘토링을 통해 산업현장에서 실제 활용되는 기술을 자연스럽게 체험하고 진로 결정에도 도움을 받을 수 있었다.

이번 공모전에 참여한 김희주 학생은 “막연히 생각했던 아이디어를 실제 AI 전문가들과 구체화해나가며 접하지 못했던 지식과 기술을 배울 수 있었고 AI 분야에 더 큰 관심을 가지게 됐다”고 말했다.

학생들의 멘토를 맡은 포스코ICT 최영철 연구원은 “학생들의 열정과 창의적인 아이디어를 접하며 새로운 자극을 받아 재미있게 멘토링에 참여했다”며 “그동안 AI 분야에서 쌓아온 재능을 기부해 AI 전문가를 꿈꾸는 청소년들에게 전해줄 수 있어 의미 있었다”고 밝혔다. 한편, 포스코ICT는 아주대학교 대학원과 ‘AI 전문인력 양성을 위한 업무협약’을 체결해 프로그램을 운영하고 있다. 지난 24일에는 인공지능학과 대학원 과정에 재학 중인 우수 인재를 선발해 장학금을 지급했다.

이번에 선발된 학생에게는 졸업 때까지 매달 장학금을 지급하고, 포스코ICT의 AI 전문가와의 1대1 멘토링 및 각종 기술 교육, 세미나 참석을 비롯해 채용 기회까지 제공할 계획이다. 김현일 기자'''

# %% [markdown]
# ## 2.2 한글 토큰화 및 형태소 분석

# %% [markdown]
# 한글 자연어 처리기 비교
# https://konlpy.org/ko/latest/morph/

# %% [markdown]
# #### 형태소 분석기별 메서드 정리
# 출처 : https://konlpy-ko.readthedocs.io/ko/v0.4.3/
#
# ---
# 1) Hannanum : KAIST에서 개발
# - analyze : 다양한 형태학적 후보를 반환
# - morphs : 형태소 토큰화
# - nouns : 명사 토큰만 반환
# - pos : 형태소에 품사 태깅하여 반환
# ---
# 2) Kkma : 서울대에서 개발
# - morphs : 형태소 토큰화
# - nouns : 명사 토큰만 반환
# - pos : 형태소에 품사 태깅하여 반환
# - sentences : 문장 토큰화
# ---
# 3) Komoran : Shineware팀에서 개발
# - morphs : 형태소 토큰화
# - nouns : 명사 토큰만 반환
# - pos : 형태소에 품사 태깅하여 반환
# ---
# 4) Mecab : 교토대에서 일본어용으로 개발된 분석기, 은전 프로젝트에 의해 한국어용 개발
# - morphs : 형태소 토큰화
# - nouns : 명사 토큰만 반환
# - pos : 형태소에 품사 태깅하여 반환
# ---
# 5) Okt(Twitter) : Will Hohyon Ryu가 개발
# - morphs : 형태소 토큰화
# - nouns : 명사 토큰만 반환
# - phrases : 다양한 형태학적 후보를 반환
# - pos : 형태소에 품사 태깅하여 반환

# %%
#konlpy 설치
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 89.3 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 37.7 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0

# %%
from konlpy.tag import Hannanum, Okt, Kkma

# %%
# 객체 생성
okt = Okt()

# %%
print(okt.morphs(kor_text)) # 형태소 분석기 : 형태소 단위로 쪼개기
# Out:
# ['포스코', 'ICT', '는', '25일', '경기도', '판교', '사옥', '에서', '청소년', '들', '이', '개발', '한', '인공', '지능', '(', 'AI', ')', '기반', '애플리케이션', '을', '직접', '선보이는', '‘', '2022', 'AI', '유스', '챌', '린지', '(', 'Youth', 'Challenge', ')’', '를', '개최', '했다', '.', '청소년', '들', '은', '기성세대', '들', '이', '생각', '하지', '못', '했던', '참신한', '아이디어', '를', '바탕', '으로', 'AI', '시스템', '을', '개발', '해', '관심', '을', '모았다', '.', '\n\n', '예선', '을', '거쳐', '본선', '에', '오른', '전국', '중', '·', '고교', '7', '개팀', '은', '지난', '달', '부터', '포스코', 'ICT', '소속', 'AI', '엔지니어', '의', '코칭', '속', '에', '개발', '한', 'AI', '시스템', '을', '직접', '시연', '했다', '.', '심사', '는', '카이스트', ',', '포스텍', ',', '연세대', '교수', '등', '으로', '구성', '된', '평가', '위원', '들', '과', '포스코', 'ICT', '직원', '들', '로', '구성', '된', '내부', '평가', '위원', '들', '이', '맡았다', '.', '우수', '작은', '과', '기', '정통부', '장관', '상', '(', '1', '팀', '),', '포스코', 'ICT', '사장', '상', '(', '1', '팀', '),', '지능', '정보산업', '협회장', '상', '(', '1', '팀', '),', '우수상', '(', '2', '팀', '),', '장려상', '(', '2', '팀', ')', '등', '으로', '나눠', '각각', '시상', '했다', '.', '포스코', 'ICT', '는', 'AI', '기술', '을', '접목', '해', '환경', '·', '안전', '·', '사회', '문제', '를', '해결', '할', '수', '있는', '청소년', '들', '의', '아이디어', '를', '발굴', '하기', '위해', '이번', '공모전', '을', '개최', '했다', '.', '평소', 'AI', '기술', '을', '접', '할', '기회', '가', '부족했던', '청소년', '들', '은', '멘토링', '을', '통해', '산업', '현장', '에서', '실제', '활용', '되는', '기술', '을', '자연', '스럽게', '체험', '하고', '진로', '결정', '에도', '도움', '을', '받을', '수', '있었다', '.', '\n\n', '이번', '공모전', '에', '참여', '한', '김희', '주', '학생', '은', '“', '막연히', '생각', '했던', '아이디어', '를', '실제', 'AI', '전문가', '들', '과', '구체화', '해', '나가며', '접', '하지', '못', '했던', '지식', '과', '기술', '을', '배울', '수', '있었고', 'AI', '분야', '에', '더', '큰', '관심', '을', '가지', '게', '됐다', '”', '고', '말', '했다', '.', '\n\n', '학생', '들', '의', '멘토', '를', '맡은', '포스코', 'ICT', '최영철', '연구원', '은', '“', '학생', '들', '의', '열정', '과', '창의', '적', '인', '아이디어', '를', '접', '하며', '새로운', '자극', '을', '받아', '재미있게', '멘토링', '에', '참여', '했다', '”', '며', '“', '그동안', 'AI', '분야', '에서', '쌓아', '온', '재능', '을', '기부', '해', 'AI', '전문가', '를', '꿈꾸는', '청소년', '들', '에게', '전', '해줄', '수', '있어', '의미', '있었다', '”', '고', '밝혔다', '.', '한편', ',', '포스코', 'ICT', '는', '아주대', '학교', '대학원', '과', '‘', 'AI', '전문', '인력', '양성', '을', '위', '한', '업무', '협약', '’', '을', '체결', '해', '프로그램', '을', '운영', '하고', '있다', '.', '지난', '24일', '에는', '인공', '지능', '학과', '대학원', '과정', '에', '재학', '중인', '우수', '인재', '를', '선발', '해', '장학금', '을', '지급', '했다', '.', '\n\n', '이번', '에', '선발', '된', '학생', '에게는', '졸업', '때', '까지', '매달', '장학금', '을', '지급', '하고', ',', '포스코', 'ICT', '의', 'AI', '전문가', '와의', '1', '대', '1', '멘토링', '및', '각종', '기술', '교육', ',', '세미나', '참석', '을', '비롯', '해', '채용', '기회', '까지', '제공', '할', '계획', '이다', '.', '김현', '일', '기자']

# %%
print(okt.nouns(kor_text)) # 명사 추출
# Out:
# ['포스코', '경기도', '판교', '사옥', '청소년', '개발', '인공', '지능', '기반', '애플리케이션', '직접', '유스', '린지', '를', '개최', '청소년', '기성세대', '생각', '아이디어', '바탕', '시스템', '개발', '관심', '예선', '본선', '오른', '전국', '중', '고교', '개팀', '지난', '달', '포스코', '소속', '엔지니어', '코칭', '속', '개발', '시스템', '직접', '시연', '심사', '카이스트', '포스텍', '연세대', '교수', '등', '구성', '평가', '위원', '포스코', '직원', '구성', '내부', '평가', '위원', '우수', '과', '정통부', '장관', '팀', '포스코', '사장', '팀', '지능', '정보산업', '협회장', '팀', '우수상', '팀', '장려상', '팀', '등', '각각', '시상', '포스코', '기술', '접목', '환경', '안전', '사회', '문제', '해결', '수', '청소년', '아이디어', '발굴', '위해', '이번', '공모전', '개최', '평소', '기술', '접', '기회', '청소년', '멘토링', '통해', '산업', '현장', '실제', '활용', '기술', '자연', '체험', '진로', '결정', '도움', '수', '이번', '공모전', '참여', '김희', '주', '학생', '생각', '아이디어', '실제', '전문가', '구체화', '접', '지식', '기술', '수', '분야', '더', '관심', '가지', '고', '말', '학생', '멘토', '포스코', '최영철', '연구원', '학생', '열정', '창의', '아이디어', '접', '자극', '멘토링', '참여', '며', '그동안', '분야', '온', '재능', '기부', '전문가', '청소년', '전', '수', '의미', '고', '한편', '포스코', '아주대', '학교', '대학원', '전문', '인력', '양성', '위', '업무', '협약', '체결', '프로그램', '운영', '지난', '인공', '지능', '학과', '대학원', '과정', '재학', '중인', '우수', '인재', '선발', '장학금', '지급', '이번', '선발', '학생', '졸업', '때', '매달', '장학금', '지급', '포스코', '의', '전문가', '멘토링', '및', '각종', '기술', '교육', '세미나', '참석', '비롯', '채용', '기회', '제공', '계획', '김현', '일', '기자']

# %%
print(okt.pos(kor_text)) # 품사 태깅
# Out:
# [('포스코', 'Noun'), ('ICT', 'Alpha'), ('는', 'Verb'), ('25일', 'Number'), ('경기도', 'Noun'), ('판교', 'Noun'), ('사옥', 'Noun'), ('에서', 'Josa'), ('청소년', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('개발', 'Noun'), ('한', 'Josa'), ('인공', 'Noun'), ('지능', 'Noun'), ('(', 'Punctuation'), ('AI', 'Alpha'), (')', 'Punctuation'), ('기반', 'Noun'), ('애플리케이션', 'Noun'), ('을', 'Josa'), ('직접', 'Noun'), ('선보이는', 'Verb'), ('‘', 'Foreign'), ('2022', 'Number'), ('AI', 'Alpha'), ('유스', 'Noun'), ('챌', 'Verb'), ('린지', 'Noun'), ('(', 'Punctuation'), ('Youth', 'Alpha'), ('Challenge', 'Alpha'), (')’', 'Punctuation'), ('를', 'Noun'), ('개최', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('청소년', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('기성세대', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('생각', 'Noun'), ('하지', 'Verb'), ('못', 'VerbPrefix'), ('했던', 'Verb'), ('참신한', 'Adjective'), ('아이디어', 'Noun'), ('를', 'Josa'), ('바탕', 'Noun'), ('으로', 'Josa'), ('AI', 'Alpha'), ('시스템', 'Noun'), ('을', 'Josa'), ('개발', 'Noun'), ('해', 'Verb'), ('관심', 'Noun'), ('을', 'Josa'), ('모았다', 'Verb'), ('.', 'Punctuation'), ('\n\n', 'Foreign'), ('예선', 'Noun'), ('을', 'Josa'), ('거쳐', 'Verb'), ('본선', 'Noun'), ('에', 'Josa'), ('오른', 'Noun'), ('전국', 'Noun'), ('중', 'Noun'), ('·', 'Punctuation'), ('고교', 'Noun'), ('7', 'Number'), ('개팀', 'Noun'), ('은', 'Josa'), ('지난', 'Noun'), ('달', 'Noun'), ('부터', 'Josa'), ('포스코', 'Noun'), ('ICT', 'Alpha'), ('소속', 'Noun'), ('AI', 'Alpha'), ('엔지니어', 'Noun'), ('의', 'Josa'), ('코칭', 'Noun'), ('속', 'Noun'), ('에', 'Josa'), ('개발', 'Noun'), ('한', 'Josa'), ('AI', 'Alpha'), ('시스템', 'Noun'), ('을', 'Josa'), ('직접', 'Noun'), ('시연', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('심사', 'Noun'), ('는', 'Josa'), ('카이스트', 'Noun'), (',', 'Punctuation'), ('포스텍', 'Noun'), (',', 'Punctuation'), ('연세대', 'Noun'), ('교수', 'Noun'), ('등', 'Noun'), ('으로', 'Josa'), ('구성', 'Noun'), ('된', 'Verb'), ('평가', 'Noun'), ('위원', 'Noun'), ('들', 'Suffix'), ('과', 'Josa'), ('포스코', 'Noun'), ('ICT', 'Alpha'), ('직원', 'Noun'), ('들', 'Suffix'), ('로', 'Josa'), ('구성', 'Noun'), ('된', 'Verb'), ('내부', 'Noun'), ('평가', 'Noun'), ('위원', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('맡았다', 'Verb'), ('.', 'Punctuation'), ('우수', 'Noun'), ('작은', 'Adjective'), ('과', 'Noun'), ('기', 'Modifier'), ('정통부', 'Noun'), ('장관', 'Noun'), ('상', 'Suffix'), ('(', 'Punctuation'), ('1', 'Number'), ('팀', 'Noun'), ('),', 'Punctuation'), ('포스코', 'Noun'), ('ICT', 'Alpha'), ('사장', 'Noun'), ('상', 'Suffix'), ('(', 'Punctuation'), ('1', 'Number'), ('팀', 'Noun'), ('),', 'Punctuation'), ('지능', 'Noun'), ('정보산업', 'Noun'), ('협회장', 'Noun'), ('상', 'Suffix'), ('(', 'Punctuation'), ('1', 'Number'), ('팀', 'Noun'), ('),', 'Punctuation'), ('우수상', 'Noun'), ('(', 'Punctuation'), ('2', 'Number'), ('팀', 'Noun'), ('),', 'Punctuation'), ('장려상', 'Noun'), ('(', 'Punctuation'), ('2', 'Number'), ('팀', 'Noun'), (')', 'Punctuation'), ('등', 'Noun'), ('으로', 'Josa'), ('나눠', 'Verb'), ('각각', 'Noun'), ('시상', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('포스코', 'Noun'), ('ICT', 'Alpha'), ('는', 'Verb'), ('AI', 'Alpha'), ('기술', 'Noun'), ('을', 'Josa'), ('접목', 'Noun'), ('해', 'Verb'), ('환경', 'Noun'), ('·', 'Punctuation'), ('안전', 'Noun'), ('·', 'Punctuation'), ('사회', 'Noun'), ('문제', 'Noun'), ('를', 'Josa'), ('해결', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('청소년', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('아이디어', 'Noun'), ('를', 'Josa'), ('발굴', 'Noun'), ('하기', 'Verb'), ('위해', 'Noun'), ('이번', 'Noun'), ('공모전', 'Noun'), ('을', 'Josa'), ('개최', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('평소', 'Noun'), ('AI', 'Alpha'), ('기술', 'Noun'), ('을', 'Josa'), ('접', 'Noun'), ('할', 'Verb'), ('기회', 'Noun'), ('가', 'Josa'), ('부족했던', 'Adjective'), ('청소년', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('멘토링', 'Noun'), ('을', 'Josa'), ('통해', 'Noun'), ('산업', 'Noun'), ('현장', 'Noun'), ('에서', 'Josa'), ('실제', 'Noun'), ('활용', 'Noun'), ('되는', 'Verb'), ('기술', 'Noun'), ('을', 'Josa'), ('자연', 'Noun'), ('스럽게', 'Josa'), ('체험', 'Noun'), ('하고', 'Josa'), ('진로', 'Noun'), ('결정', 'Noun'), ('에도', 'Josa'), ('도움', 'Noun'), ('을', 'Josa'), ('받을' ...

# %%
print(okt.morphs('갈 수도 있고 아닐 수도 있고', stem = True))
# Out:
# ['갈다', '수도', '있다', '아니다', '수도', '있다']

# %%
#코모란(Komoran) 토큰화

from konlpy.tag import Komoran
komoran = Komoran()
kor_text = "인간이 컴퓨터와 대화하고 있다는 것을 꺠닫지 못하고 인간과 대화를 계속할 수 있다면 컴퓨터는 지능적인 것으로 간주될 수 있다."
komoran_tokens = komoran.morphs(kor_text)
print(komoran_tokens)
# Out:
# ['인간', '이', '컴퓨터', '와', '대화', '하', '고', '있', '다는', '것', '을', '꺠닫지', '못하', '고', '인간', '과', '대화', '를', '계속', '하', 'ㄹ', '수', '있', '다면', '컴퓨터', '는', '지능', '적', '이', 'ㄴ', '것', '으로', '간주', '되', 'ㄹ', '수', '있', '다', '.']

# %%
#한나눔(hannanum) 토큰화
from konlpy.tag import Hannanum
hannanum = Hannanum()
kor_text = "인간이 컴퓨터와 대화하고 있다는 것을 꺠닫지 못하고 인간과 대화를 계속할 수 있다면 컴퓨터는 지능적인 것으로 간주될 수 있다."
hannanum_tokens = hannanum.morphs(kor_text)
print(hannanum_tokens)
# Out:
# ['인간', '이', '컴퓨터', '와', '대화', '하고', '있', '다는', '것', '을', '꺠닫지', '못하', '고', '인간', '과', '대화', '를', '계속', '하', 'ㄹ', '수', '있', '다면', '컴퓨터', '는', '지능적', '이', 'ㄴ', '것', '으로', '간주', '되', 'ㄹ', '수', '있', '다', '.']

# %%
#Okt 토큰화
from konlpy.tag import Okt
okt = Okt()
okt_tokens = okt.morphs(kor_text)
print(okt_tokens)
# Out:
# ['인간', '이', '컴퓨터', '와', '대화', '하고', '있다는', '것', '을', '꺠닫', '지', '못', '하고', '인간', '과', '대화', '를', '계속', '할', '수', '있다면', '컴퓨터', '는', '지능', '적', '인', '것', '으로', '간주', '될', '수', '있다', '.']

# %%
# Kkma 토큰화
from konlpy.tag import Kkma
kkma = Kkma()
kkma_tokens = kkma.morphs(kor_text)
print(kkma_tokens)
# Out:
# ['인간', '이', '컴퓨터', '와', '대화', '하', '고', '있', '다는', '것', '을', '꺠', '닫', '지', '못하', '고', '인간', '과', '대화', '를', '계속', '하', 'ㄹ', '수', '있', '다면', '컴퓨터', '는', '지능', '적', '이', 'ㄴ', '것', '으로', '간주', '되', 'ㄹ', '수', '있', '다', '.']

# %%
kor_text = '그래욬ㅋㅋㅋ잘해봅시다! 잘하고 있지만 더 잘해보면 좋지 않을까라고 생각하는 중'

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
print(okt.morphs(kor_text))
# Out:
# ['그래욬', 'ㅋㅋㅋ', '잘', '해봅시다', '!', '잘', '하고', '있지만', '더', '잘', '해보면', '좋지', '않을까', '라고', '생각', '하는', '중']

# %%
print(okt.morphs(kor_text, stem = True))
# Out:
# ['그래욬', 'ㅋㅋㅋ', '잘', '해보다', '!', '잘', '하다', '있다', '더', '잘', '해보다', '좋다', '않다', '라고', '생각', '하다', '중']

# %% [markdown]
# ## 2.3 한글 품사 부착(PoS Tagging)

# %% [markdown]
# Pos Tag 목록
# https://docs.google.com/spreadsheets/u/1/d/1OGAjUvalBuX-oZvZ_-9tEfYD2gQe7hTGsgUpiiBSXI8/edit#gid=0

# %%
# 코모란(Komoran) 품사 태깅
komoranTag = []
for token in komoran_tokens:
  komoranTag += komoran.pos(token)
print(komoranTag)
# Out:
# [('인간', 'NNG'), ('이', 'MM'), ('컴퓨터', 'NNG'), ('오', 'VV'), ('아', 'EC'), ('대화', 'NNG'), ('하', 'NNG'), ('고', 'MM'), ('있', 'VV'), ('달', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('을', 'NNG'), ('꺠닫지', 'NA'), ('못', 'MAG'), ('하', 'MAG'), ('고', 'MM'), ('인간', 'NNG'), ('과', 'NNG'), ('대화', 'NNG'), ('를', 'JKO'), ('계속', 'MAG'), ('하', 'NNG'), ('ㄹ', 'NA'), ('수', 'NNB'), ('있', 'VV'), ('다면', 'NNG'), ('컴퓨터', 'NNG'), ('늘', 'VV'), ('ㄴ', 'ETM'), ('지능', 'NNP'), ('적', 'NNB'), ('이', 'MM'), ('ㄴ', 'JX'), ('것', 'NNB'), ('으로', 'JKB'), ('간주', 'NNG'), ('되', 'NNB'), ('ㄹ', 'NA'), ('수', 'NNB'), ('있', 'VV'), ('다', 'MAG'), ('.', 'SF')]

# %%
# 한나눔(Hannanum) 품사 태깅
hannanum_Tag = []
for token in hannanum_tokens:
  hannanum_Tag += hannanum.pos(token)

print(hannanum_Tag)
# Out:
# [('인간', 'N'), ('이', 'M'), ('컴퓨터', 'N'), ('와', 'I'), ('대화', 'N'), ('하', 'P'), ('고', 'E'), ('있', 'N'), ('다', 'M'), ('는', 'J'), ('것', 'N'), ('을', 'N'), ('꺠닫지', 'N'), ('못하', 'P'), ('어', 'E'), ('고', 'M'), ('인간', 'N'), ('과', 'N'), ('대화', 'N'), ('를', 'N'), ('계속', 'M'), ('하', 'I'), ('ㄹ', 'N'), ('수', 'N'), ('있', 'N'), ('다면', 'N'), ('컴퓨터', 'N'), ('늘', 'P'), ('ㄴ', 'E'), ('지능적', 'N'), ('이', 'M'), ('ㄴ', 'N'), ('것', 'N'), ('으', 'N'), ('로', 'J'), ('간주', 'N'), ('되', 'N'), ('ㄹ', 'N'), ('수', 'N'), ('있', 'N'), ('다', 'M'), ('.', 'S')]

# %%
# Okt 품사 태깅
oktTag = []
for token in okt_tokens:
  oktTag += okt.pos(token)
print(oktTag)
# Out:
# [('인간', 'Noun'), ('이', 'Noun'), ('컴퓨터', 'Noun'), ('와', 'Verb'), ('대화', 'Noun'), ('하고', 'Verb'), ('있다는', 'Adjective'), ('것', 'Noun'), ('을', 'Josa'), ('꺠닫', 'Noun'), ('지', 'Verb'), ('못', 'Noun'), ('하고', 'Verb'), ('인간', 'Noun'), ('과', 'Noun'), ('대화', 'Noun'), ('를', 'Noun'), ('계속', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있다면', 'Adjective'), ('컴퓨터', 'Noun'), ('는', 'Verb'), ('지능', 'Noun'), ('적', 'Noun'), ('인', 'Noun'), ('것', 'Noun'), ('으로', 'Josa'), ('간주', 'Noun'), ('될', 'Verb'), ('수', 'Noun'), ('있다', 'Adjective'), ('.', 'Punctuation')]

# %%
#Kkma 품사 태깅
kkmaTag = []
for token in kkma_tokens:
  kkmaTag += kkma.pos(token)
print(kkmaTag)
# Out:
# [('인간', 'NNG'), ('이', 'NNG'), ('컴퓨터', 'NNG'), ('오', 'VA'), ('아', 'ECS'), ('대화', 'NNG'), ('하', 'NNG'), ('고', 'NNG'), ('있', 'VA'), ('달', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('을', 'NNG'), ('꺠', 'UN'), ('닫', 'VV'), ('지', 'NNG'), ('못하', 'VX'), ('고', 'NNG'), ('인간', 'NNG'), ('과', 'NNG'), ('대화', 'NNG'), ('를', 'UN'), ('계속', 'MAG'), ('하', 'NNG'), ('ㄹ', 'NNG'), ('수', 'NNG'), ('있', 'VA'), ('다면', 'NNG'), ('컴퓨터', 'NNG'), ('늘', 'VA'), ('ㄴ', 'ETD'), ('지능', 'NNG'), ('적', 'NNG'), ('이', 'NNG'), ('ㄴ', 'NNG'), ('것', 'NNB'), ('으', 'UN'), ('로', 'JKM'), ('간주', 'NNG'), ('되', 'VA'), ('ㄹ', 'NNG'), ('수', 'NNG'), ('있', 'VA'), ('다', 'NNG'), ('.', 'SF')]

# %% [markdown]
# ## 2.4 불용어 처리(StopWord) 처리

# %% [markdown]
# 분석에 불필요한 품사를 제거하고, 불필요한 단어(불용어)를 제거한다.

# %%
# 불용어 처리
stopPos = ['Suffix','Punctuation','Josa','Foreign','Alpha','Number']

# %%
#최빈어 조회: 최빈어를 조회하여 불용어 제거 대상을 선정
from collections import Counter
Counter(oktTag).most_common()
# Out:
# [(('인간', 'Noun'), 2),
#  (('컴퓨터', 'Noun'), 2),
#  (('대화', 'Noun'), 2),
#  (('하고', 'Verb'), 2),
#  (('것', 'Noun'), 2),
#  (('수', 'Noun'), 2),
#  (('이', 'Noun'), 1),
#  (('와', 'Verb'), 1),
#  (('있다는', 'Adjective'), 1),
#  (('을', 'Josa'), 1),
#  (('꺠닫', 'Noun'), 1),
#  (('지', 'Verb'), 1),
#  (('못', 'Noun'), 1),
#  (('과', 'Noun'), 1),
#  (('를', 'Noun'), 1),
#  (('계속', 'Noun'), 1),
#  (('할', 'Verb'), 1),
#  (('있다면', 'Adjective'), 1),
#  (('는', 'Verb'), 1),
#  (('지능', 'Noun'), 1),
#  (('적', 'Noun'), 1),
#  (('인', 'Noun'), 1),
#  (('으로', 'Josa'), 1),
#  (('간주', 'Noun'), 1),
#  (('될', 'Verb'), 1),
#  (('있다', 'Adjective'), 1),
#  (('.', 'Punctuation'), 1)]

# %%
stopWord = ['의','이','로','두고','들','를','은','과','수','했다','것','있는','한다','하는','그','있다']

# %%
word =[]
for tag in oktTag:
  if tag[1] not in stopPos:
    if tag[0] not in stopWord:
      word.append(tag[0])

print(word)
# Out:
# ['인간', '컴퓨터', '와', '대화', '하고', '있다는', '꺠닫', '지', '못', '하고', '인간', '대화', '계속', '할', '있다면', '컴퓨터', '는', '지능', '적', '인', '간주', '될']
